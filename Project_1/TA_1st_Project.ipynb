# %%
import re
import os
import string
from nltk import sent_tokenize, word_tokenize, download
from IPython.display import clear_output
from collections import Counter
import gc
import pickle
from nltk.tokenize import RegexpTokenizer
from nltk.util import ngrams
"""
# Save objects
with open('object_name', 'wb') as f:
    pickle.dump(object_variable, f)

# Load objects
with open('object_name', 'rb') as f:
    object_variable = pickle.load(f)
"""
from pprint import pprint
print("Imports Completed")
# Out:
# Imports Completed

# %%
download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/datum/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
def clean_text(text):
    """ 
    1. Remove html like text from europarl e.g. <Chapter 1>
    2. Remove line breaks
    3. Reduce all whitespaces to 1
    4. turn everything to lower case
    """
    clean = re.compile('<.*?>')
    
    out = text.replace('\n', ' ') # Remove line breaks
    out = re.sub(clean, ' ', out) # Remove tagged text e.g. <Chapter 1>
    out = re.sub(' +', ' ', out) # Reduce whitespace down to one
    
    out = out.lower() # Turn everything to lower case
    
    return out

# %%
abs_path = os.getcwd()
path = abs_path + '/en/'
text = ''
corpus_clean = []
sentences = []
corpus_original = ''
total = len(os.listdir(path)) # Total files
count = 0

for file in os.listdir(path):
    f = open(path + file, 'r', encoding="utf-8")
    file_text = f.read()
    corpus_original = corpus_original + file_text
    f.close()

    regex = re.compile('[%s]' % re.escape(string.punctuation))
    file_sentences = [regex.sub('', sent).strip() for sent in sent_tokenize(clean_text(file_text))]

    corpus_clean = corpus_clean + file_sentences
    count += 1
    
    clear_output(wait = True)
    print('File ' + file + ' finished. Completed ' + str(round(count*100/total,2)) + '%')
# Out:
# File ep-99-04-14.txt finished. Completed 100.0%

# %%
"""
demo corpus file:
------------------------------------------------------------------
original text: <class 'str'>
<CHAPTER ID="005">
Voting time
<SPEAKER ID="104" NAME="President">
The next item is the vote.
<P>
(For the results and other details on the vote: see Minutes)
------------------------------------------------------------------
Its clean_text(text): <class 'str'>
 voting time the next item is the vote. (for the results and other details on the vote: see minutes) 
------------------------------------------------------------------
Its sent_tokenize(clean_text(text)): <class 'list'>
[' voting time the next item is the vote.', '(for the results and other details on the vote: see minutes)']
------------------------------------------------------------------
Its sentences = [sent.strip() for sent in sent_tokenize(clean_text(text))]: <class 'list'>
['voting time the next item is the vote.', '(for the results and other details on the vote: see minutes)']
------------------------------------------------------------------
"""

# %%
# Save the basic objects:
with open('corpus_original', 'wb') as f:
    pickle.dump(corpus_original, f)
with open('corpus_clean', 'wb') as f:
    pickle.dump(corpus_clean, f)

# %%
regex = re.compile('[%s]' % re.escape(string.punctuation))
corpus_clean_string = regex.sub('', clean_text(corpus_original))

print('-------------------------')
print('corpus_clean_string created.')
print('-------------------------')

with open('corpus_clean_string', 'wb') as f:
    pickle.dump(corpus_clean_string, f)

del corpus_original
# Out:
# -------------------------
# corpus_clean_string created.
# -------------------------

# %%
gc.collect()
# Out:
# 317

# %%
AllWords = word_tokenize(corpus_clean_string)
print('-------------------------')
print('Words Tokenized.')
print('-------------------------')

vocabulary = set(AllWords)
print('Vocabulary Created.')
print('-------------------------')

WordCounts = Counter(AllWords)
print('WordCounts Calculated.')
print('-------------------------')

with open('AllWords', 'wb') as f:
    pickle.dump(AllWords, f) 

with open('vocabulary', 'wb') as f:
    pickle.dump(vocabulary, f) 
    
with open('WordCounts', 'wb') as f:
    pickle.dump(WordCounts, f) 

del corpus_clean_string, AllWords
# Out:
# -------------------------
# Words Tokenized.
# -------------------------
# Vocabulary Created.
# -------------------------
# WordCounts Calculated.
# -------------------------

# %%
gc.collect()
# Out:
# 0

# %% [markdown]
# #### Early starting point: Instead of all the above..

# %%
corpus_clean = None
WordCounts = None
vocabulary = None

# Load objects

with open('corpus_clean', 'rb') as f:
    corpus_clean = pickle.load(f)

with open('vocabulary', 'rb') as f:
    vocabulary = pickle.load(f)
    
with open('WordCounts', 'rb') as f:
    WordCounts = pickle.load(f)
    
with open('AllWords', 'rb') as f:
    AllWords = pickle.load(f)

# %%
# Ignore low frequency words
valid_vocabulary = [k for k,v in WordCounts.items() if v > 10]
invalid_vocabulary = [k for k,v in WordCounts.items() if v <= 10]
print("valid voc", len(valid_vocabulary))
print("invalid voc", len(invalid_vocabulary))

with open('valid_vocabulary', 'wb') as f:
    pickle.dump(valid_vocabulary, f) 
    
with open('invalid_vocabulary', 'wb') as f:
    pickle.dump(invalid_vocabulary, f)
# Out:
# valid voc 32678
# invalid voc 109653

# %%
# Replace OOV words in sentences

def split_sentence(sentence):
    PATTERN = '\w+|\(|\)|\.|\,'
    tokenizer = RegexpTokenizer(pattern=PATTERN) 
    return tokenizer.tokenize(sentence)
dummy_count = 0
total = len(corpus_clean)
for i in range(0,len(corpus_clean)):
    sentence = ''.join(corpus_clean[i]) # make it string
    splitted_sent = split_sentence(sentence)    
    new_sent = []
    for word in splitted_sent:
        new_word = 'UNK' if word not in valid_vocabulary else word
        new_sent.append(new_word)
        corpus_clean[i] = new_sent
    clear_output(wait = True)
    print('Sentences processed ' + str(i+1) + ' out of ' + str(total))
    dummy_count = dummy_count + 1
    if 1000 < dummy_count:
        break

# Have it here, in order to not to forget to save after the big computation burden.
with open('corpus_clean_no_OOV', 'wb') as f:
    pickle.dump(corpus_clean, f)
# Out:
# Sentences processed 1001 out of 2217535

# %%
# Deprecated (slower)
#
# Replace OOV words in sentences
# total = len(corpus_clean)
# for i in range(0,len(corpus_clean)):
#    for word in valid_vocabulary:
#        corpus_clean[i].replace(word, 'UNK')
#   clear_output(wait = True)
#   print('Sentences processed ' + str(i+1) + ' out of ' + str(total) )

# %%
# Creating the n-grams is actually not needed!! Only counting them is!!
#
# tokens = AllWords
# bigrams = [ gram for gram in ngrams(tokens, 2) ]
# trigrams = [ gram for gram in ngrams(tokens, 3) ]
# #pprint(bigrams)
# with open('bigrams', 'wb') as f:
#     pickle.dump(bigrams, f)
# with open('trigrams', 'wb') as f:
#    pickle.dump(bigrams, f)

# %%
# Creating the n-grams is actually not needed!! Only counting them is!!
#
# import sys, numpy as np
# print("AllWords:", np.round(sys.getsizeof(AllWords)/1024/1024/1024,2)," GBs")
# print("Bigrams:", np.round(sys.getsizeof(bigrams)/1024/1024/1024,2)," GBs")
# print("Trigrams:", np.round(sys.getsizeof(trigrams)/1024/1024/1024,2)," GBs")

# %% [markdown]
# #### Regular Starting Point

# %%
corpus_clean = None
WordCounts = None
vocabulary = None
corpus_clean_no_OOV = None

# Load objects

#with open('corpus_clean', 'rb') as f:
#    corpus_clean = pickle.load(f)

#with open('vocabulary', 'rb') as f:
#    vocabulary = pickle.load(f)
    
#with open('WordCounts', 'rb') as f:
#    WordCounts = pickle.load(f)
    
with open('AllWords', 'rb') as f:
    AllWords = pickle.load(f)
    
with open('corpus_clean_no_OOV', 'rb') as f:
    corpus_clean_no_OOV = pickle.load(f)

# %%
print(corpus_clean_no_OOV.__class__)
print(corpus_clean_no_OOV[0])
print(corpus_clean_no_OOV[0].__class__)
print(corpus_clean_no_OOV[0][0].__class__)
# Out:
# <class 'list'>
# ['voting', 'time', 'the', 'next', 'item', 'is', 'the', 'vote']
# <class 'list'>
# <class 'str'>

# %%
print(AllWords.__class__)
print(AllWords[0])
print(AllWords[0].__class__)
print(AllWords[0:10])
# Out:
# <class 'list'>
# voting
# <class 'str'>
# ['voting', 'time', 'the', 'next', 'item', 'is', 'the', 'vote', 'for', 'the']

# %%
gc.collect()
# Out:
# 0

# %% [markdown]
# #### Counting n-grams

# %%
# Single sentence, for testing corpus_clean_no_OOV:
unigram_counter = Counter()
unigram_counter.update([gram for gram in ngrams(corpus_clean_no_OOV[0], 1, pad_left=True, pad_right=True,
                                                   left_pad_symbol='<s>',right_pad_symbol='<e>') ])
pprint(corpus_clean_no_OOV[0])
pprint(unigram_counter)
# Out:
# ['voting', 'time', 'the', 'next', 'item', 'is', 'the', 'vote']
# Counter({('the',): 2,
#          ('voting',): 1,
#          ('time',): 1,
#          ('next',): 1,
#          ('item',): 1,
#          ('is',): 1,
#          ('vote',): 1})

# %%
# Single sentence for testing AllWords:
unigram_counter = Counter()
unigram_counter.update([gram for gram in ngrams(AllWords[0:10], 1, pad_left=True, pad_right=True,
                                                   left_pad_symbol='<s>',right_pad_symbol='<e>') ])
pprint(AllWords[0:10])
pprint(unigram_counter)
# Out:
# ['voting', 'time', 'the', 'next', 'item', 'is', 'the', 'vote', 'for', 'the']
# Counter({('the',): 3,
#          ('voting',): 1,
#          ('time',): 1,
#          ('next',): 1,
#          ('item',): 1,
#          ('is',): 1,
#          ('vote',): 1,
#          ('for',): 1})

# %%
unigram_counter = Counter()
sample = corpus_clean_no_OOV[0:1000]

for sent in sample:   
    unigram_counter.update([gram for gram in ngrams(sent, 1, pad_left=True, pad_right=True,
                                                   left_pad_symbol='<s>',right_pad_symbol='<e>') ])
pprint(unigram_counter)
# Out:
# Counter({('the',): 1574,
#          ('of',): 839,
#          ('to',): 749,
#          ('and',): 619,
#          ('in',): 527,
#          ('a',): 420,
#          ('is',): 407,
#          ('that',): 395,
#          ('we',): 313,
#          ('i',): 303,
#          ('for',): 279,
#          ('it',): 247,
#          ('energy',): 241,
#          ('this',): 229,
#          ('on',): 224,
#          ('nuclear',): 216,
#          ('be',): 209,
#          ('not',): 190,
#          ('which',): 176,
#          ('european',): 162,
#          ('are',): 158,
#          ('UNK',): 157,
#          ('as',): 153,
#          ('have',): 138,
#          ('with',): 131,
#          ('by',): 117,
#          ('should',): 115,
#          ('mr',): 108,
#          ('report',): 106,
#          ('would',): 104,
#          ('at',): 101,
#          ('power',): 100,
#          ('also',): 95,
#          ('all',): 86,
#          ('but',): 86,
#          ('will',): 81,
#          ('has',): 80,
#          ('from',): 77,
#          ('our',): 76,
#          ('an',): 74,
#          ('can',): 74,
#          ('there',): 73,
#          ('renewable',): 73,
#          ('you',): 72,
#          ('must',): 72,
#          ('president',): 65,
#          ('do',): 63,
#          ('so',): 63,
#          ('no',): 62,
#          ('sources',): 62,
#          ('if',): 61,
#          ('countries',): 60,
#          ('very',): 57,
#          ('or',): 55,
#          ('union',): 52,
#          ('only',): 51,
#          ('states',): 51,
#          ('my',): 50,
#          ('commission',): 49,
#          ('what',): 49,
#          ('say',): 48,
#          ('us',): 48,
#          ('their',): 48,
#          ('member',): 47,
#          ('policy',): 46,
#          ('was',): 45,
#          ('its',): 45,
#          ('because',): 45,
#          ('time',): 44,
#          ('about',): 44,
#          ('industry',): 44,
#          ('one',): 43,
#          ('safety',): 43,
#          ('vote',): 42,
#          ('been',): 42,
#          ('like',): 42,
#          ('europe',): 41,
#          ('other',): 40,
#          ('here',): 40,
#          ('more',): 39,
#          ('up',): 38,
#          ('parliament',): 37,
#          ('waste',): 37,
#          ('these',): 36,
#          ('years',): 36,
#          ('research',): 36,
#          ('new',): 33,
#          ('into',): 32,
#          ('question',): 32,
#          ('those',): 32,
#          ('stations',): 32,
#          ('use',): 32,
#          ('me',): 32,
#          ('they',): 31,
#          ('technology',): 31,
#          ('now',): 30,
#          ('way',): 30,
#          ('any',): 30,
#          ('know',): 30,
#          ('am',): 30,
#          ('need',): 30,
#          ('committee',): 30,
#          ('development',): 30,
#          ('future',): 30,
#          ('paper',): 30,
#          ('just',): 29,
#          ('therefore',): 29,
#          ('against',): 29,
#          ('such',): 28,
#          ('want',): 28,
#          ('make',): 28,
#          ('support',): 28,
#          ('were',): 27,
#          ('when',): 27,
#          ('mrs',): 27,
#          ('debate',): 27,
#          ('think',): 27,
#          ('without',): 27,
#          ('point',): 27,
#          ('community',): 26,
#          ('let',): 25,
#          ('soulier',): 25,
#          ('amendments',): 25,
#          ('important',): 25,
#          ('group',): 25,
#          ('being',): 25,
#          ('quite',): 24,
#          ('some',): 24,
#          ('market',): 24,
#          ('commissioner',): 24,
#          ('rapporteur',): 24,
#          ('agree',): 24,
#          ('why',): 24,
#          ('wish',): 23,
#          ('out',): 23,
#          ('really',): 23,
#          ('area',): 23,
#          ('towards',): 23,
#          ('people',): 22,
#          ('most',): 22,
#          ('than',): 22,
#          ('green',): 22,
#          ('take',): 22,
#          ('same',): 22,
#          ('could',): 22,
#          ('had',): 21,
#          ('treaty',): 21,
#          ('particular',): 21,
#          ('view',): 21,
#          ('common',): 21,
#          ('defence',): 21,
#          ('security',): 20,
#          ('two',): 20,
#          ('economic',): 20,
#          ('whole',): 19,
#          ('fact',): 19,
#          ('house',): 19,
#          ('many',): 19,
#          ('them',): 19,
#          ('your',): 19,
#          ('who',): 19,
#          ('programme',): 19,
#          ('how',): 19,
#          ('eu',): 19,
#          ('does',): 19,
#          ('believe',): 19,
#          ('give',): 19,
#          ('even',): 19,
#          ('first',): 18,
#          ('said',): 18,
#          ('come',): 18,
#          ('however',): 18,
#          ('course',): 18,
#          ('environment',): 18,
#          ('today',): 17,
#          ('own',): 17,
#          ('possible',): 17,
#          ('within',): 17,
#          ('case',): 17,
#          ('going',): 17,
#          ('order',): 17,
#          ('measures',): 17,
#          ('last',): 16,
#          ('every',): 16,
#          ('world',): 16,
#          ('money',): 16,
#          ('then',): 16,
#          ('great',): 16,
#          ('set',): 16,
#          ('sector',): 16,
#          ('political',): 16,
#          ('proposal',): 16,
#          ('agreements',): 16,
#          ('strategy',): 16,
#          ('biomass',): 16,
#          ('members',): 15,
#          ('well',): 15,
#          ('unfortunately',): 15,
#          ('since',): 15,
#          ('resources',): 15,
#          ('subject',): 15,
#          ('long',): 15,
#          ('progress',): 15,
#          ('favour',): 15,
#          ('present',): 15,
#          ('put',): 15,
#          ('necessary',): 15,
#          ('issue',): 15,
#          ('electricity',): 15,
#          ('too',): 15,
#          ('cooperation',): 15,
#          ('voting',): 14,
#          ('see',): 14,
#          ('once',): 14,
#          ('least',): 14,
#          ('over',): 14,
#          ('country',): 14,
#          ('after',): 14,
#          ('made',): 14,
#          ('together',): 14,
#          ('means',): 14,
#          ('clear',): 14,
#          ('certain',): 14,
#          ('each',): 14,
#          ('technological',): 14,
#          ('public',): 14,
#          ('terms',): 14,
#          ('still',): 14,
#          ('work',): 14,
#          ('ask',): 14,
#          ('whether',): 14,
#          ('transport',): 14,
#          ('programmes',): 14,
#          ('needs',): 14,
#          ('yet',): 14,
#          ('military',): 14,
#          ('voted',): 14,
#          ('again',): 13,
#          ('where',): 13,
#          ('state',): 13,
#          ('congratulate',): 13,
#          ('another',): 13,
#          ('national',): 13,
#          ('euratom',): 13,
#          ('ladies',): 13,
#          ('gentlemen',): 13,
#          ('opinion',): 13,
#          ('eastern',): 13,
#          ('resolution',): 13,
#          ('weapons',): 13,
#          ('votes',): 13,
#          ('citizens',): 12,
#          ('hope',): 12,
#          ('authorities',): 12,
#          ('rules',): 12,
#          ('taken',): 12,
#          ('plan',): 12,
#          ('central',): 12,
#          ('under',): 12,
#          ('titley',): 12,
#          ('interests',): 12,
#          ('particularly',): 12,
#          ('real',): 12,
#          ('her',): 12,
#          ('amendment',): 12,
#          ('finally',): 12,
#          ('action',): 12,
#          ('efforts',): 12,
#          ('costs',): 12,
#          ('framework',): 12,
#          ('part',): 12,
#          ('better',): 12,
#          ('continue',): 11,
#          ('during',): 11,
#          ('his',): 11,
#          ('place',): 11,
#          ('matter',): 11,
#          ('number',): 11,
#          ('free',): 11,
#          ('done',): 11,
#          ('through',): 11,
#          ('level',): 11,
#          ('second',): 11,
#          ('between',): 11,
#          ('rather',): 11,
#          ('areas',): 11,
#          ('gas',): 11,
#          ('points',): 11,
#          ('available',): 11,
#          ('speaker',): 11,
#          ('radioactive',): 11,
#          ('excellent',): 11,
#          ('reactors',): 11,
#          ('look',): 11,
#          ('station',): 11,
#          ('based',): 11,
#          ('commissions',): 11,
#          ('installations',): 11,
#          ('projects',): 11,
#          ('cost',): 11,
#          ('far',): 11,
#          ('rothe',): 11,
#          ('analysis',): 11,
#          ('recent',): 10,
#          ('concerned',): 10,
#          ('rule',): 10,
#          ('decided',): 10,
#          ('best',): 10,
#          ('ensure',): 10,
#          ('given',): 10,
#          ('tabled',): 10,
#          ('choice',): 10,
#          ('secondly',): 10,
#          ('although',): 10,
#          ('end',): 10,
#          ('go',): 10,
#          ('form',): 10,
#          ('promote',): 10,
#          ('used',): 10,
#          ('storage',): 10,
#          ('production',): 10,
#          ('paragraph',): 10,
#          ('different',): 10,
#          ('makes',): 10,
#          ('white',): 10,
#          ('supply',): 10,
#          ('clearly',): 10,
#          ('objective',): 10,
#          ('much',): 10,
#          ('already',): 10,
#          ('disposal',): 10,
#          ('read',): 10,
#          ('change',): 9,
#          ('situation',): 9,
#          ('council',): 9,
#          ('refer',): 9,
#          ('statement',): 9,
#          ('right',): 9,
#          ('conditions',): 9,
#          ('unions',): 9,
#          ('risks',): 9,
#          ('knowledge',): 9,
#          ('supplies',): 9,
#          ('get',): 9,
#          ('always',): 9,
#          ('difficult',): 9,
#          ('shall',): 9,
#          ('individual',): 9,
#          ('environmental',): 9,
#          ('promotion',): 9,
#          ('build',): 9,
#          ('year',): 9,
#          ('forms',): 9,
#          ('says',): 9,
#          ('15',): 9,
#          ('may',): 9,
#          ('he',): 9,
#          ('principle',): 9,
#          ('approach',): 9,
#          ('trade',): 9,
#          ('nothing',): 9,
#          ('back',): 9,
#          ('developing',): 9,
#          ('wastes',): 9,
#          ('wind',): 9,
#          ('armaments',): 9,
#          ('france',): 8,
#          ('independence',): 8,
#          ('something',): 8,
#          ('she',): 8,
#          ('few',): 8,
#          ('call',): 8,
#          ('nature',): 8,
#          ('40',): 8,
#          ('groups',): 8,
#          ('before',): 8,
#          ('high',): 8,
#          ('internal',): 8,
#          ('single',): 8,
#          ('keep',): 8,
#          ('investment',): 8,
#          ('produced',): 8,
#          ('liberalization',): 8,
#          ('decide',): 8,
#          ('account',): 8,
#          ('agreement',): 8,
#          ('seems',): 8,
#          ('example',): 8,
#          ('competition',): 8,
#          ('seriously',): 8,
#          ('export',): 8,
#          ('information',): 8,
#          ('simply',): 8,
#          ('aid',): 8,
#          ('co2',): 8,
#          ('ago',): 8,
#          ('nor',): 8,
#          ('sense',): 8,
#          ('funds',): 8,
#          ('basis',): 8,
#          ('legal',): 8,
#          ('1',): 8,
#          ('peace',): 8,
#          ('along',): 8,
#          ('international',): 8,
#          ('next',): 7,
#          ('plenary',): 7,
#          ('adopted',): 7,
#          ('peoples',): 7,
#          ('procedure',): 7,
#          ('parliaments',): 7,
#          ('improve',): 7,
#          ('following',): 7,
#          ('entirely',): 7,
#          ('contribute',): 7,
#          ('united',): 7,
#          ('various',): 7,
#          ('good',): 7,
#          ('problems',): 7,
#          ('both',): 7,
#          ('become',): 7,
#          ('questions',): 7,
#          ('energies',): 7,
#          ('jobs',): 7,
#          ('conclusion',): 7,
#          ('emphasis',): 7,
#          ('ageing',): 7,
#          ('everyone',): 7,
#          ('totally',): 7,
#          ('thank',): 7,
#          ('health',): 7,
#          ('including',): 7,
#          ('words',): 7,
#          ('increase',): 7,
#          ('price',): 7,
#          ('wrong',): 7,
#          ('source',): 7,
#          ('increased',): 7,
#          ('balanced',): 7,
#          ('concern',): 7,
#          ('happen',): 7,
#          ('major',): 7,
#          ('involved',): 7,
#          ('either',): 7,
#          ('contribution',): 7,
#          ('little',): 7,
#          ('regional',): 7,
#          ('specific',): 7,
#          ('themselves',): 7,
#          ('especially',): 7,
#          ('role',): 7,
#          ('employment',): 7,
#          ('perhaps',): 7,
#          ('offer',): 7,
#          ('problem',): 7,
#          ('food',): 7,
#          ('remain',): 7,
#          ('speak',): 7,
#          ('develop',): 7,
#          ('system',): 7,
#          ('renewables',): 7,
#          ('sun',): 7,
#          ('rural',): 7,
#          ('rollcall',): 7,
#          ('decision',): 7,
#          ('minutes',): 6,
#          ('turkey',): 6,
#          ('000',): 6,
#          ('among',): 6,
#          ('four',): 6,
#          ('applause',): 6,
#          ('democratic',): 6,
#          ('result',): 6,
#          ('relation',): 6,
#          ('create',): 6,
#          ('around',): 6,
#          ('government',): 6,
#          ('working',): 6,
#          ('indeed',): 6,
#          ('policies',): 6,
#          ('small',): 6,
#          ('thing',): 6,
#          ('industrial',): 6,
#          ('efficiency',): 6,
#          ('type',): 6,
#          ('reactor',): 6,
#          ('scientific',): 6,
#          ('mcnally',): 6,
#          ('sovereign',): 6,
#          ('keeping',): 6,
#          ('answer',): 6,
#          ('third',): 6,
#          ('maintain',): 6,
#          ('currently',): 6,
#          ('down',): 6,
#          ('less',): 6,
#          ('save',): 6,
#          ('proposals',): 6,
#          ('accept',): 6,
#          ('aim',): 6,
#          ('aware',): 6,
#          ('existing',): 6,
#          ('longer',): 6,
#          ('certainly',): 6,
#          ('directive',): 6,
#          ('alternative',): 6,
#          ('potential',): 6,
#          ('did',): 6,
#          ('understand',): 6,
#          ('takes',): 6,
#          ('respect',): 6,
#          ('final',): 6,
#          ('partly',): 6,
#          ('types',): 6,
#          ('responsibility',): 6,
#          ('opportunity',): 6,
#          ('built',): 6,
#          ('governments',): 6,
#          ('developed',): 6,
#          ('longterm',): 6,
#          ('offers',): 6,
#          ('linked',): 6,
#          ('social',): 6,
#          ('supporting',): 6,
#          ('operation',): 6,
#          ('dismantling',): 6,
#          ('fuel',): 6,
#          ('emissions',): 6,
#          ('produce',): 6,
#          ('consider',): 6,
#          ('while',): 6,
#          ('equipment',): 6,
#          ('services',): 6,
#          ('others',): 6,
#          ('reduce',): 6,
#          ('fusion',): 6,
#          ('fuels',): 6,
#          ('building',): 6,
#          ('responsible',): 6,
#          ('try',): 6,
#          ('took',): 6,
#          ('taking',): 6,
#          ('commitment',): 6,
#          ('2010',): 6,
#          ('12',): 6,
#          ('century',): 6,
#          ('instead',): 6,
#          ('suggest',): 6,
#          ('fisheries',): 6,
#          ('text',): 6,
#          ('block',): 6,
#          ('results',): 5,
#          ('statements',): 5,
#          ('beginning',): 5,
#          ('days',): 5,
#          ('50',): 5,
#          ('10',): 5,
#          ('talks',): 5,
#          ('three',): 5,
#          ('arms',): 5,
#          ('ones',): 5,
#          ('act',): 5,
#          ('ought',): 5,
#          ('industries',): 5,
#          ('according',): 5,
#          ('article',): 5,
#          ('comes',): 5,
#          ('30',): 5,
#          ('war',): 5,
#          ('threat',): 5,
#          ('asked',): 5,
#          ('mention',): 5,
#          ('enable',): 5,
#          ('enough',): 5,
#          ('able',): 5,
#          ('making',): 5,
#          ('committees',): 5,
#          ('chance',): 5,
#          ('unable',): 5,
#          ('objectives',): 5,
#          ('hand',): 5,
#          ('never',): 5,
#          ('aspect',): 5,
#          ('bring',): 5,
#          ('germany',): 5,
#          ('shows',): 5,
#          ('beyond',): 5,
#          ('air',): 5,
#          ('achieve',): 5,
#          ('help',): 5,
#          ('active',): 5,
#          ('protection',): 5,
#          ('field',): 5,
#          ('extremely',): 5,
#          ('myself',): 5,
#          ('activities',): 5,
#          ('importance',): 5,
#          ('deal',): 5,
#          ('provide',): 5,
#          ('population',): 5,
#          ('sustainable',): 5,
#          ('reply',): 5,
#          ('definitely',): 5,
#          ('document',): 5,
#          ('principles',): 5,
#          ('calling',): 5,
#          ('treatment',): 5,
#          ('guarantee',): 5,
#          ('surely',): 5,
#          ('nonsense',): 5,
#          ('instance',): 5,
#          ('100',): 5,
#          ('per',): 5,
#          ('cycle',): 5,
#          ('sweden',): 5,
#          ('majority',): 5,
#          ('noone',): 5,
#          ('find',): 5,
#          ('expect',): 5,
#          ('vital',): 5,
#          ('giving',): 5,
#          ('term',): 5,
#          ('true',): 5,
#          ('element',): 5,
#          ('neither',): 5,
#          ('huge',): 5,
#          ('materials',): 5,
#          ('throughout',): 5,
#          ('management',): 5,
#          ('plant',): 5,
#          ('project',): 5,
#          ('consideration',): 5,
#          ('share',): 5,
#          ('concerning',): 5,
#          ('despite',): 5,
#          ('normally',): 5,
#          ('communitys',): 5,
#          ('direction',): 5,
#          ('mainly',): 5,
#          ('implementation',): 5,
#          ('appropriate',): 5,
#          ('noon',): 5,
#          ('financial',): 5,
#          ('oil',): 5,
#          ('tax',): 5,
#          ('million',): 5,
#          ('kind',): 5,
#          ('ecu',): 5,
#          ('detailed',): 5,
#          ('value',): 5,
#          ('target',): 5,
#          ('former',): 5,
#          ('motion',): 5,
#          ('force',): 5,
#          ('partners',): 5,
#          ('impose',): 5,
#          ('american',): 5,
#          ('rights',): 5,
#          ('zaire',): 5,
#          ('item',): 4,
#          ('several',): 4,
#          ('things',): 4,
#          ('session',): 4,
#          ('week',): 4,
#          ('victims',): 4,
#          ('forget',): 4,
#          ('behalf',): 4,
#          ('tragedy',): 4,
#          ('11',): 4,
#          ('march',): 4,
#          ('1990',): 4,
#          ('congratulations',): 4,
#          ('fellow',): 4,
#          ('attitude',): 4,
#          ('him',): 4,
#          ('else',): 4,
#          ('brussels',): 4,
#          ('belgium',): 4,
#          ('current',): 4,
#          ('special',): 4,
#          ('provided',): 4,
#          ('held',): 4,
#          ('concerns',): 4,
#          ('personal',): 4,
#          ('debating',): 4,
#          ('sure',): 4,
#          ('goods',): 4,
#          ('mostly',): 4,
#          ('remind',): 4,
#          ('french',): 4,
#          ('communication',): 4,
#          ('apart',): 4,
#          ('africa',): 4,
#          ('measure',): 4,
#          ('moderate',): 4,
#          ('trust',): 4,
#          ('conclusions',): 4,
#          ('reasons',): 4,
#          ('respected',): 4,
#          ('extend',): 4,
#          ('above',): 4,
#          ('technical',): 4,
#          ('greater',): 4,
#          ('doubt',): 4,
#          ('directly',): 4,
#          ('mean',): 4,
#          ('duty',): 4,
#          ('probably',): 4,
#          ('trying',): 4,
#          ('alone',): 4,
#          ('issues',): 4,
#          ('decommissioning',): 4,
#          ('purpose',): 4,
#          ('plants',): 4,
#          ('effort',): 4,
#          ('eus',): 4,
#          ('western',): 4,
#          ('party',): 4,
#          ('show',): 4,
#          ('written',): 4,
#          ('forward',): 4,
#          ('indicative',): 4,
#          ('lot',): 4,
#          ('accidents',): 4,
#          ('reason',): 4,
#          ('requirements',): 4,
#          ('dangerous',): 4,
#          ('considerable',): 4,
#          ('main',): 4,
#          ('advantage',): 4,
#          ('knowhow',): 4,
#          ('referred',): 4,
#          ('reducing',): 4,
#          ('radioactivity',): 4,
#          ('doing',): 4,
#          ('process',): 4,
#          ('controversial',): 4,
#          ('parts',): 4,
#          ('external',): 4,
#          ('picture',): 4,
#          ('puts',): 4,
#          ('growing',): 4,
#          ('needed',): 4,
#          ('welcome',): 4,
#          ('ideological',): 4,
#          ('context',): 4,
#          ('choices',): 4,
#          ('risk',): 4,
#          ('drafted',): 4,
#          ('water',): 4,
#          ('normal',): 4,
#          ('running',): 4,
#          ('safe',): 4,
#          ('recital',): 4,
#          ('whereas',): 4,
#          ('reduction',): 4,
#          ('carried',): 4,
#          ('using',): 4,
#          ('effective',): 4,
#          ('colleagues',): 4,
#          ('maximum',): 4,
#          ('demand',): 4,
#          ('stability',): 4,
#          ('prices',): 4,
#          ('remember',): 4,
#          ('undertaken',): 4,
#          ('calls',): 4,
#          ('whose',): 4,
#          ('base',): 4,
#          ('operations',): 4,
#          ('start',): 4,
#          ('efficient',): 4,
#          ('pressure',): 4,
#          ('credible',): 4,
#          ('further',): 4,
#          ('significant',): 4,
#          ('happened',): 4,
#          ('packaging',): 4,
#          ('achieved',): 4,
#          ('possibility',): 4,
#          ('prospects',): 4,
#          ('debates',): 4,
#          ('6',): 4,
#          ('consumption',): 4,
#          ('until',): 4,
#          ('allocated',): 4,
#          ('appropriations',): 4,
#          ('ambitious',): 4,
#          ('ie',): 4,
#          ('land',): 4,
#          ('coordinate',): 4,
#          ('21st',): 4,
#          ('technologies',): 4,
#          ('priority',): 4,
#          ('move',): 4,
#          ('full',): 4,
#          ('protests',): 4,
#          ('followed',): 4,
#          ('blocks',): 4,
#          ('rejected',): 4,
#          ('upon',): 4,
#          ('mistake',): 4,
#          ('fyrom',): 4,
#          ('fishery',): 4,
#          ('fishing',): 4,
#          ('local',): 4,
#          ('nato',): 4,
#          ('refugees',): 4,
#          ('wto',): 4,
#          ('violence',): 4,
#          ('luxembourg',): 4,
#          ('agricultural',): 3,
#          ('forestry',): 3,
#          ('natural',): 3,
#          ('earthquake',): 3,
#          ('across',): 3,
#          ('whom',): 3,
#          ('cases',): 3,
#          ('expressions',): 3,
#          ('families',): 3,
#          ('death',): 3,
#          ('anything',): 3,
#          ('thousands',): 3,
#          ('solidarity',): 3,
#          ('soviet',): 3,
#          ('declare',): 3,
#          ('china',): 3,
#          ('begin',): 3,
#          ('representatives',): 3,
#          ('pursuant',): 3,
#          ('period',): 3,
#          ('theft',): 3,
#          ('premises',): 3,
#          ('belgian',): 3,
#          ('tell',): 3,
#          ('hard',): 3,
#          ('approval',): 3,
#          ('dramatic',): 3,
#          ('untrue',): 3,
#          ('assure',): 3,
#          ('yesterday',): 3,
#          ('similar',): 3,
#          ('approved',): 3,
#          ('consult',): 3,
#          ('shown',): 3,
#          ('consultation',): 3,
#          ('decisions',): 3,
#          ('word',): 3,
#          ('passed',): 3,
#          ('contrary',): 3,
#          ('thought',): 3,
#          ('russia',): 3,
#          ('east',): 3,
#          ('run',): 3,
#          ('dependent',): 3,
#          ('rate',): 3,
#          ('remark',): 3,
#          ('japan',): 3,
#          ('levels',): 3,
#          ('replaced',): 3,
#          ('society',): 3,
#          ('eliminate',): 3,
#          ('funding',): 3,
#          ('agriculture',): 3,
#          ('short',): 3,
#          ('bit',): 3,
#          ('previous',): 3,
#          ('include',): 3,
#          ('suggestions',): 3,
#          ('prime',): 3,
#          ('maastricht',): 3,
#          ('invest',): 3,
#          ('task',): 3,
#          ('introduction',): 3,
#          ('tried',): 3,
#          ('admit',): 3,
#          ('old',): 3,
#          ('figures',): 3,
#          ('paid',): 3,
#          ('knowing',): 3,
#          ('big',): 3,
#          ('potentially',): 3,
#          ('position',): 3,
#          ('20',): 3,
#          ('proportion',): 3,
#          ('rapidly',): 3,
#          ('greenhouse',): 3,
#          ('agreed',): 3,
#          ('cis',): 3,
#          ('away',): 3,
#          ('highly',): 3,
#          ('shortterm',): 3,
#          ('formulated',): 3,
#          ('reference',): 3,
#          ('consequences',): 3,
#          ('strengthen',): 3,
#          ('liberal',): 3,
#          ('realistic',): 3,
#          ('becoming',): 3,
#          ('human',): 3,
#          ('unacceptable',): 3,
#          ('papoutsis',): 3,
#          ('europes',): 3,
#          ('express',): 3,
#          ('safeguard',): 3,
#          ('distort',): 3,
#          ('presented',): 3,
#          ('advantages',): 3,
#          ('dependence',): 3,
#          ('permanent',): 3,
#          ('left',): 3,
#          ('propose',): 3,
#          ('encourage',): 3,
#          ('access',): 3,
#          ('facts',): 3,
#          ('half',): 3,
#          ('actually',): 3,
#          ('megawatt',): 3,
#          ('five',): 3,
#          ('times',): 3,
#          ('conventional',): 3,
#          ('fifth',): 3,
#          ('wonder',): 3,
#          ('firstly',): 3,
#          ('tonnes',): 3,
#          ('mox',): 3,
#          ('prove',): 3,
#          ('fossil',): 3,
#          ('carbondioxide',): 3,
#          ('systems',): 3,
#          ('chernobyl',): 3,
#          ('accident',): 3,
#          ('guarantees',): 3,
#          ('chamber',): 3,
#          ('exactly',): 3,
#          ('enormous',): 3,
#          ('add',): 3,
#          ('overall',): 3,
#          ('bases',): 3,
#          ('play',): 3,
#          ('obligations',): 3,
#          ('portugal',): 3,
#          ('talking',): 3,
#          ('pay',): 3,
#          ('closed',): 3,
#          ('coal',): 3,
#          ('ensures',): 3,
#          ('reaching',): 3,
#          ('light',): 3,
#          ('prevent',): 3,
#          ('attention',): 3,
#          ('pursue',): 3,
#          ('improved',): 3,
#          ('basic',): 3,
#          ('resolved',): 3,
#          ('difficulties',): 3,
#          ('processing',): 3,
#          ('german',): 3,
#          ('personally',): 3,
#          ('warm',): 3,
#          ('low',): 3,
#          ('itself',): 3,
#          ('continuing',): 3,
#          ('examples',): 3,
#          ('disarmament',): 3,
#          ('stocks',): 3,
#          ('reality',): 3,
#          ('civil',): 3,
#          ('solid',): 3,
#          ('america',): 3,
#          ('list',): 3,
#          ('encouragement',): 3,
#          ('unit',): 3,
#          ('having',): 3,
#          ('might',): 3,
#          ('study',): 3,
#          ('frontiers',): 3,
#          ('dinosaurs',): 3,
#          ('wants',): 3,
#          ('saving',): 3,
#          ('combined',): 3,
#          ('spend',): 3,
#          ('remaining',): 3,
#          ('sensible',): 3,
#          ('generation',): 3,
#          ('sometimes',): 3,
#          ('initiative',): 3,
#          ('applied',): 3,
#          ('idea',): 3,
#          ('adopt',): 3,
#          ('application',): 3,
#          ('peaceful',): 3,
#          ('institutional',): 3,
#          ('conference',): 3,
#          ('orders',): 3,
#          ('section',): 3,
#          ('specifically',): 3,
#          ('developments',): 3,
#          ('secure',): 3,
#          ('relate',): 3,
#          ('joint',): 3,
#          ('limited',): 3,
#          ('recall',): 3,
#          ('reprocessing',): 3,
#          ('prepared',): 3,
#          ('lead',): 3,
#          ('specifications',): 3,
#          ('define',): 3,
#          ('lines',): 3,
#          ('strategic',): 3,
#          ('nobody',): 3,
#          ('aiming',): 3,
#          ('1996',): 3,
#          ('financing',): 3,
#          ('obligation',): 3,
#          ('urgent',): 3,
#          ('regions',): 3,
#          ('amount',): 3,
#          ('transfer',): 3,
#          ('wood',): 3,
#          ('positive',): 3,
#          ('budget',): 3,
#          ('stress',): 3,
#          ('concrete',): 3,
#          ('rothes',): 3,
#          ('robles',): 3,
#          ('piquer',): 3,
#          ('sort',): 3,
#          ('urban',): 3,
#          ('lack',): 3,
#          ('went',): 3,
#          ('introduce',): 3,
#          ('serious',): 3,
#          ('climate',): 3,
#          ('finance',): 3,
#          ('etc',): 3,
#          ('spent',): 3,
#          ('encouraging',): 3,
#          ('capacity',): 3,
#          ('general',): 3,
#          ('aims',): 3,
#          ('farreaching',): 3,
#          ('established',): 3,
#          ('status',): 3,
#          ('starting',): 3,
#          ('socialist',): 3,
#          ('birthday',): 3,
#          ('known',): 3,
#          ('wanted',): 3,
#          ('cfsp',): 3,
#          ('macedonia',): 3,
#          ('cohnbendit',): 3,
#          ('democracy',): 3,
#          ('recommended',): 3,
#          ('reports',): 3,
#          ('fish',): 3,
#          ('crampton',): 3,
#          ('nonaligned',): 3,
#          ('restructuring',): 3,
#          ('foreign',): 3,
#          ('completely',): 3,
#          ('transatlantic',): 3,
#          ('balkans',): 3,
#          ('yugoslavia',): 3,
#          ('options',): 3,
#          ('bananas',): 3,
#          ('dictatorship',): 3,
#          ('diplomacy',): 3,
#          ('wrongs',): 3,
#          ('border',): 3,
#          ('details',): 2,
#          ('inform',): 2,
#          ('died',): 2,
#          ('nearly',): 2,
#          ('300',): 2,
#          ('caused',): 2,
#          ('60',): 2,
#          ('nations',): 2,
#          ('join',): 2,
#          ('marks',): 2,
#          ('20th',): 2,
#          ('anniversary',): 2,
#          ('lithuanian',): 2,
#          ('lithuania',): 2,
#          ('declaration',): 2,
#          ('estonia',): 2,
#          ('popular',): 2,
#          ('uprising',): 2,
#          ('80',): 2,
#          ('leave',): 2,
#          ('regularly',): 2,
#          ('appeal',): 2,
#          ('republic',): 2,
#          ('dialogue',): 2,
#          ('remarks',): 2,
#          ('farage',): 2,
#          ('spoken',): 2,
#          ('daily',): 2,
#          ('acting',): 2,
#          ('knows',): 2,
#          ('institutions',): 2,
#          ('official',): 2,
#          ('police',): 2,
#          ('22',): 2,
#          ('treating',): 2,
#          ('sitting',): 2,
#          ('distributed',): 2,
#          ('comments',): 2,
#          ('7',): 2,
#          ('lobbyist',): 2,
#          ('merchants',): 2,
#          ('line',): 2,
#          ('irish',): 2,
#          ('meet',): 2,
#          ('claim',): 2,
#          ('southern',): 2,
#          ('spanish',): 2,
#          ('condemn',): 2,
#          ('circulation',): 2,
#          ('attacks',): 2,
#          ('protest',): 2,
#          ('movement',): 2,
#          ('illustrative',): 2,
#          ('bound',): 2,
#          ('provisions',): 2,
#          ('remarkable',): 2,
#          ('politicians',): 2,
#          ('institution',): 2,
#          ('ours',): 2,
#          ('changed',): 2,
#          ('prosperity',): 2,
#          ('north',): 2,
#          ('gulf',): 2,
#          ('theoretical',): 2,
#          ('interest',): 2,
#          ('modest',): 2,
#          ('farranging',): 2,
#          ('recognised',): 2,
#          ('opt',): 2,
#          ('wishes',): 2,
#          ('ban',): 2,
#          ('coming',): 2,
#          ('danger',): 2,
#          ('advanced',): 2,
#          ('replace',): 2,
#          ('moment',): 2,
#          ('indirectly',): 2,
#          ('unlike',): 2,
#          ('finish',): 2,
#          ('deserve',): 2,
#          ('equivalent',): 2,
#          ('stake',): 2,
#          ('placed',): 2,
#          ('fight',): 2,
#          ('almost',): 2,
#          ('face',): 2,
#          ('procedures',): 2,
#          ('ambitions',): 2,
#          ('buy',): 2,
#          ('bureau',): 2,
#          ('rapporteurs',): 2,
#          ('success',): 2,
#          ('surprises',): 2,
#          ('thus',): 2,
#          ('revised',): 2,
#          ('associated',): 2,
#          ('desirable',): 2,
#          ('improvement',): 2,
#          ('accordance',): 2,
#          ('affair',): 2,
#          ('concentrated',): 2,
#          ('appreciated',): 2,
#          ('age',): 2,
#          ('expectations',): 2,
#          ('hopes',): 2,
#          ('realized',): 2,
#          ('past',): 2,
#          ('constant',): 2,
#          ('applies',): 2,
#          ('intention',): 2,
#          ('realize',): 2,
#          ('enterprises',): 2,
#          ('expertise',): 2,
#          ('18',): 2,
#          ('solutions',): 2,
#          ('regret',): 2,
#          ('fulfil',): 2,
#          ('onethird',): 2,
#          ('continued',): 2,
#          ('created',): 2,
#          ('traditional',): 2,
#          ('carbon',): 2,
#          ('dioxide',): 2,
#          ('effect',): 2,
#          ('emission',): 2,
#          ('rio',): 2,
#          ('comprehensively',): 2,
#          ('congratulating',): 2,
#          ('provides',): 2,
#          ('projections',): 2,
#          ('adopts',): 2,
#          ('competitiveness',): 2,
#          ('regards',): 2,
#          ('fundamental',): 2,
#          ('stated',): 2,
#          ('option',): 2,
#          ('previously',): 2,
#          ('examine',): 2,
#          ('moves',): 2,
#          ('quickly',): 2,
#          ('fields',): 2,
#          ('considered',): 2,
#          ('connection',): 2,
#          ('drafting',): 2,
#          ('clean',): 2,
#          ('safer',): 2,
#          ('cheap',): 2,
#          ('error',): 2,
#          ('material',): 2,
#          ('involves',): 2,
#          ('england',): 2,
#          ('solution',): 2,
#          ('subsidising',): 2,
#          ('date',): 2,
#          ('1997',): 2,
#          ('avoiding',): 2,
#          ('fears',): 2,
#          ('matters',): 2,
#          ('rightly',): 2,
#          ('poses',): 2,
#          ('35',): 2,
#          ('large',): 2,
#          ('elimination',): 2,
#          ('implement',): 2,
#          ('guaranteeing',): 2,
#          ('generations',): 2,
#          ('greens',): 2,
#          ('opposition',): 2,
#          ('opposed',): 2,
#          ('straitjacket',): 2,
#          ('coordination',): 2,
#          ('obey',): 2,
#          ('quality',): 2,
#          ('nevertheless',): 2,
#          ('mix',): 2,
#          ('expensive',): 2,
#          ('cheaper',): 2,
#          ('modern',): 2,
#          ('mistakes',): 2,
#          ('contain',): 2,
#          ('contaminated',): 2,
#          ('accepted',): 2,
#          ('namely',): 2,
#          ('six',): 2,
#          ('correct',): 2,
#          ('thousand',): 2,
#          ('plutonium',): 2,
#          ('uranium',): 2,
#          ('bad',): 2,
#          ('safely',): 2,
#          ('drawn',): 2,
#          ('contributes',): 2,
#          ('grams',): 2,
#          ('enrichment',): 2,
#          ('mineral',): 2,
#          ('alternatives',): 2,
#          ('turbines',): 2,
#          ('commend',): 2,
#          ('discussion',): 2,
#          ('leaks',): 2,
#          ('broad',): 2,
#          ('closely',): 2,
#          ('foreseeable',): 2,
#          ('abandon',): 2,
#          ('austria',): 2,
#          ('radiation',): 2,
#          ('evidence',): 2,
#          ('anyone',): 2,
#          ('believes',): 2,
#          ('fully',): 2,
#          ('quiet',): 2,
#          ('decisive',): 2,
#          ('abandoning',): 2,
#          ('generally',): 2,
#          ('growth',): 2,
#          ('famous',): 2,
#          ('exert',): 2,
#          ('consequently',): 2,
#          ('creation',): 2,
#          ('rest',): 2,
#          ('insists',): 2,
#          ('perform',): 2,
#          ('companies',): 2,
#          ('exploit',): 2,
#          ('engineering',): 2,
#          ('greatly',): 2,
#          ('enhance',): 2,
#          ('admits',): 2,
#          ('hour',): 2,
#          ('obsolete',): 2,
#          ('complementary',): 2,
#          ('andré',): 2,
#          ('creates',): 2,
#          ('qualified',): 2,
#          ('satisfactory',): 2,
#          ('glosses',): 2,
#          ('effectiveness',): 2,
#          ('opposite',): 2,
#          ('relating',): 2,
#          ('collected',): 2,
#          ('avoid',): 2,
#          ('yes',): 2,
#          ('room',): 2,
#          ('changing',): 2,
#          ('absolute',): 2,
#          ('secret',): 2,
#          ('explain',): 2,
#          ('capita',): 2,
#          ('denmark',): 2,
#          ('turning',): 2,
#          ('often',): 2,
#          ('dated',): 2,
#          ('utter',): 2,
#          ('goes',): 2,
#          ('worldwide',): 2,
#          ('hold',): 2,
#          ('willing',): 2,
#          ('close',): 2,
#          ('history',): 2,
#          ('portuguese',): 2,
#          ('halt',): 2,
#          ('storing',): 2,
#          ('inclusion',): 2,
#          ('chapter',): 2,
#          ('perspective',): 2,
#          ('ministers',): 2,
#          ('supported',): 2,
#          ('kozloduy',): 2,
#          ('bulgaria',): 2,
#          ('brought',): 2,
#          ('papers',): 2,
#          ('announced',): 2,
#          ('tomorrow',): 2,
#          ('answered',): 2,
#          ('relevant',): 2,
#          ('canadian',): 2,
#          ('company',): 2,
#          ('confine',): 2,
#          ('effects',): 2,
#          ('documents',): 2,
#          ('departure',): 2,
#          ('manner',): 2,
#          ('satisfying',): 2,
#          ('demands',): 2,
#          ('eg',): 2,
#          ('idealised',): 2,
#          ('essential',): 2,
#          ('ourselves',): 2,
#          ('tasks',): 2,
#          ('strongest',): 2,
#          ('exists',): 2,
#          ('mankind',): 2,
#          ('equally',): 2,
#          ('standards',): 2,
#          ('looking',): 2,
#          ('via',): 2,
#          ('assume',): 2,
#          ('attach',): 2,
#          ('commissioners',): 2,
#          ('criticism',): 2,
#          ('uses',): 2,
#          ('intergovernmental',): 2,
#          ('maintained',): 2,
#          ('acceptable',): 2,
#          ('independent',): 2,
#          ('allow',): 2,
#          ('centre',): 2,
#          ('substantial',): 2,
#          ('addition',): 2,
#          ('replacing',): 2,
#          ('gained',): 2,
#          ('raw',): 2,
#          ('origin',): 2,
#          ('though',): 2,
#          ('competitive',): 2,
#          ('bodies',): 2,
#          ('proceed',): 2,
#          ('speakers',): 2,
#          ('methods',): 2,
#          ('category',): 2,
#          ('follows',): 2,
#          ('recently',): 2,
#          ('july',): 2,
#          ('incompatible',): 2,
#          ('ensuring',): 2,
#          ('defined',): 2,
#          ('supplied',): 2,
#          ('covering',): 2,
#          ('challenge',): 2,
#          ('coordinated',): 2,
#          ('step',): 2,
#          ('accompanying',): 2,
#          ('ecological',): 2,
#          ('compete',): 2,
#          ('urgently',): 2,
#          ('transitional',): 2,
#          ('fund',): 2,
#          ('obligatory',): 2,
#          ('licence',): 2,
#          ('mechanisms',): 2,
#          ('altener',): 2,
#          ('roofs',): 2,
#          ('open',): 2,
#          ('opportunities',): 2,
#          ('apply',): 2,
#          ('please',): 2,
#          ('genuine',): 2,
#          ('225',): 2,
#          ('structural',): 2,
#          ('establishing',): 2,
#          ('manage',): 2,
#          ('euwide',): 2,
#          ('cultivation',): 2,
#          ('crops',): 2,
#          ('additional',): 2,
#          ('billion',): 2,
#          ('setaside',): 2,
#          ('income',): 2,
#          ('utilized',): 2,
#          ('environmentfriendly',): 2,
#          ('cap',): 2,
#          ('primary',): 2,
#          ('regard',): 2,
#          ('corresponding',): 2,
#          ('awareness',): 2,
#          ('distribution',): 2,
#          ('earth',): 2,
#          ('alibi',): 2,
#          ('initiatives',): 2,
#          ('apparent',): 2,
#          ('obtain',): 2,
#          ('earlier',): 2,
#          ('morning',): 2,
#          ('tremendous',): 2,
#          ('added',): 2,
#          ('called',): 2,
#          ('crosses',): 2,
#          ('parties',): 2,
#          ('greek',): 2,
#          ('deprive',): 2,
#          ('photovoltaic',): 2,
#          ('mills',): 2,
#          ('hydraulic',): 2,
#          ('useful',): 2,
#          ('day',): 2,
#          ('mentioned',): 2,
#          ('referring',): 2,
#          ('deserves',): 2,
#          ('easy',): 2,
#          ('increasing',): 2,
#          ('separately',): 2,
#          ('effectively',): 2,
#          ('standard',): 2,
#          ('suggestion',): 2,
#          ('sufficient',): 2,
#          ('repeated',): 2,
#          ('requests',): 2,
#          ('benefits',): 2,
#          ('stone',): 2,
#          ('separate',): 2,
#          ('valuable',): 2,
#          ('berlin',): 2,
#          ('markets',): 2,
#          ('count',): 2,
#          ('occasion',): 2,
#          ('imposing',): 2,
#          ('concentrating',): 2,
#          ('note',): 2,
#          ('serve',): 2,
#          ('conversion',): 2,
#          ('private',): 2,
#          ('widespread',): 2,
#          ('similarly',): 2,
#          ('thanks',): 2,
#          ('budgetary',): 2,
#          ('outside',): 2,
#          ('endorse',): 2,
#          ('asia',): 2,
#          ('practice',): 2,
#          ('mediumsized',): 2,
#          ('benefit',): 2,
#          ('hardly',): 2,
#          ('promoted',): 2,
#          ('disseminate',): 2,
#          ('imagine',): 2,
#          ('introduced',): 2,
#          ('acknowledge',): 2,
#          ('aimed',): 2,
#          ('remains',): 2,
#          ('listening',): 2,
#          ('farmers',): 2,
#          ('highlighted',): 2,
#          ('afraid',): 2,
#          ('sorry',): 2,
#          ('pm',): 2,
#          ('respects',): 2,
#          ('felt',): 2,
#          ('1155',): 2,
#          ('24',): 2,
#          ('radical',): 2,
#          ('arose',): 2,
#          ('jointly',): 2,
#          ('relations',): 2,
#          ('led',): 2,
#          ('referral',): 2,
#          ('blocking',): 2,
#          ('claudia',): 2,
#          ('roth',): 2,
#          ('contents',): 2,
#          ('missed',): 2,
#          ('entitled',): 2,
#          ('follow',): 2,
#          ('misunderstanding',): 2,
#          ('items',): 2,
#          ('impossible',): 2,
#          ('ridiculous',): 2,
#          ('pse',): 2,
#          ('repeal',): 2,
#          ('absence',): 2,
#          ('zones',): 2,
#          ('bringing',): 2,
#          ('inevitable',): 2,
#          ('fleets',): 2,
#          ('helping',): 2,
#          ('retain',): 2,
#          ('tuna',): 2,
#          ('positions',): 2,
#          ('control',): 2,
#          ('products',): 2,
#          ('strictly',): 2,
#          ('condition',): 2,
#          ('identity',): 2,
#          ('turn',): 2,
#          ('proposes',): 2,
#          ('electronics',): 2,
#          ('neutral',): 2,
#          ('producers',): 2,
#          ('upgrading',): 2,
#          ('un',): 2,
#          ('record',): 2,
#          ('providing',): 2,
#          ('alarm',): 2,
#          ('setting',): 2,
#          ('desires',): 2,
#          ('liberalism',): 2,
#          ('detriment',): 2,
#          ('series',): 2,
#          ('failure',): 2,
#          ('disastrous',): 2,
#          ('agency',): 2,
#          ('launched',): 2,
#          ('proposed',): 2,
#          ('rationalization',): 2,
#          ('merger',): 2,
#          ('lend',): 2,
#          ('strong',): 2,
#          ('sovereignty',): 2,
#          ('dominated',): 2,
#          ('forces',): 2,
#          ('atlantic',): 2,
#          ('223',): 2,
#          ('entrusted',): 2,
#          ('negative',): 2,
#          ('preservation',): 2,
#          ('balkan',): 2,
#          ('albania',): 2,
#          ('influence',): 2,
#          ('inviolability',): 2,
#          ('recovery',): 2,
#          ('respective',): 2,
#          ('constitute',): 2,
#          ('law',): 2,
#          ('populations',): 2,
#          ('behind',): 2,
#          ('names',): 2,
#          ('intends',): 2,
#          ('banana',): 2,
#          ('arbitrary',): 2,
#          ('remained',): 2,
#          ('unsaid',): 2,
#          ('committed',): 2,
#          ('increasingly',): 2,
#          ('authority',): 2,
#          ('mobutu',): 2,
#          ('wiped',): 2,
#          ('probable',): 2,
#          ('rwandan',): 2,
#          ('zairean',): 2,
#          ('sufferings',): 2,
#          ('refugee',): 2,
#          ('camps',): 2,
#          ('realism',): 2,
#          ('crisis',): 2,
#          ('revealed',): 2,
#          ('nowadays',): 2,
#          ('3',): 1,
#          ('lighting',): 1,
#          ('devices',): 1,
#          ('wheeled',): 1,
#          ('tractors',): 1,
#          ('codified',): 1,
#          ('version',): 1,
#          ('opening',): 1,
#          ('tragic',): 1,
#          ('disasters',): 1,
#          ('occurred',): 1,
#          ('57',): 1,
#          ('chile',): 1,
#          ('claimed',): 1,
#          ('storms',): 1,
#          ('raging',): 1,
#          ('deaths',): 1,
#          ('furthermore',): 1,
#          ('haiti',): 1,
#          ('latest',): 1,
#          ('toll',): 1,
#          ('january',): 1,
#          ('excess',): 1,
#          ('sent',): 1,
#          ('condolences',): 1,
#          ('sympathy',): 1,
#          ('unexpected',): 1,
#          ('premature',): 1,
#          ('numbered',): 1,
#          ('tens',): 1,
#          ('hundreds',): 1,
#          ('entire',): 1,
#          ('send',): 1,
#          ('hit',): 1,
#          ('thursday',): 1,
#          ('restoration',): 1,
#          ('bloc',): 1,
#          ('ussr',): 1,
#          ('signatories',): 1,
#          ('congress',): 1,
#          ('provisional',): 1,
#          ('reestablishment',): 1,
#          ('occupation',): 1,
#          ('wednesday',): 1,
#          ('tibet',): 1,
#          ('dalai',): 1,
#          ('lama',): 1,
#          ('tibetans',): 1,
#          ('tibetan',): 1,
#          ('nation',): 1,
#          ('fruitful',): 1,
#          ('minisession',): 1,
#          ('penalise',): 1,
#          ('withholding',): 1,
#          ('subsistence',): 1,
#          ('allowance',): 1,
#          ('suffered',): 1,
#          ('proximity',): 1,
#          ('engaged',): 1,
#          ('durant',): 1,
#          ('zone',): 1,
#          ('intensive',): 1,
#          ('meetings',): 1,
#          ('straight',): 1,
#          ('meeting',): 1,
#          ('arranged',): 1,
#          ('page',): 1,
#          ('speech',): 1,
#          ('ms',): 1,
#          ('mckenna',): 1,
#          ('editions',): 1,
#          ('literature',): 1,
#          ('ford',): 1,
#          ('lobbyists',): 1,
#          ('accusations',): 1,
#          ('anybody',): 1,
#          ('bolton',): 1,
#          ('advocate',): 1,
#          ('taxpayer',): 1,
#          ('whatsoever',): 1,
#          ('newsletter',): 1,
#          ('widely',): 1,
#          ('kingdom',): 1,
#          ('libellous',): 1,
#          ('fruit',): 1,
#          ('vegetables',): 1,
#          ('attacked',): 1,
#          ('destroyed',): 1,
#          ('aggression',): 1,
#          ('transit',): 1,
#          ('witness',): 1,
#          ('echo',): 1,
#          ('protect',): 1,
#          ('workers',): 1,
#          ('elegance',): 1,
#          ('manners',): 1,
#          ('worked',): 1,
#          ('men',): 1,
#          ('scientists',): 1,
#          ('industrialists',): 1,
#          ('intermediary',): 1,
#          ('comment',): 1,
#          ('geopolitical',): 1,
#          ('signing',): 1,
#          ('1950',): 1,
#          ('1980',): 1,
#          ('crucial',): 1,
#          ('1989',): 1,
#          ('somewhat',): 1,
#          ('unsafe',): 1,
#          ('unstable',): 1,
#          ('petrol',): 1,
#          ('middle',): 1,
#          ('inaccessible',): 1,
#          ('showed',): 1,
#          ('west',): 1,
#          ('quick',): 1,
#          ('intervene',): 1,
#          ('yardstick',): 1,
#          ('pragmatic',): 1,
#          ('inventions',): 1,
#          ('judgment',): 1,
#          ('experts',): 1,
#          ('findings',): 1,
#          ('oppose',): 1,
#          ('contradicted',): 1,
#          ('initial',): 1,
#          ('bear',): 1,
#          ('mind',): 1,
#          ('advances',): 1,
#          ('banned',): 1,
#          ('suppressed',): 1,
#          ('sufficiently',): 1,
#          ('extract',): 1,
#          ('employs',): 1,
#          ('400',): 1,
#          ('rid',): 1,
#          ('hates',): 1,
#          ('vacuums',): 1,
#          ('continent',): 1,
#          ('brief',): 1,
#          ('interested',): 1,
#          ('cynicism',): 1,
#          ('ukraine',): 1,
#          ('domain',): 1,
#          ('issued',): 1,
#          ('unreserved',): 1,
#          ('win',): 1,
#          ('biological',): 1,
#          ('phenomenon',): 1,
#          ('slowed',): 1,
#          ('currency',): 1,
#          ('banning',): 1,
#          ('fantasy',): 1,
#          ('rich',): 1,
#          ('pipe',): 1,
#          ('dream',): 1,
#          ('mans',): 1,
#          ('lenient',): 1,
#          ('prefer',): 1,
#          ('speeches',): 1,
#          ('finishing',): 1,
#          ('tempting',): 1,
#          ('extension',): 1,
#          ('thanking',): 1,
#          ('persuade',): 1,
#          ('tabling',): 1,
#          ('spirit',): 1,
#          ('logical',): 1,
#          ('consequence',): 1,
#          ('arising',): 1,
#          ('impressed',): 1,
#          ('tightening',): 1,
#          ('affects',): 1,
#          ('savings',): 1,
#          ('factual',): 1,
#          ('optimistic',): 1,
#          ('celebrate',): 1,
#          ('signed',): 1,
#          ('1957',): 1,
#          ('bears',): 1,
#          ('hallmarks',): 1,
#          ('philosophy',): 1,
#          ('applicable',): 1,
#          ('fired',): 1,
#          ('actual',): 1,
#          ('requirement',): 1,
#          ('publication',): 1,
#          ('smallest',): 1,
#          ('piece',): 1,
#          ('intentions',): 1,
#          ('practically',): 1,
#          ('nil',): 1,
#          ('dispose',): 1,
#          ('shaken',): 1,
#          ('publics',): 1,
#          ('faith',): 1,
#          ('cope',): 1,
#          ('installation',): 1,
#          ('culture',): 1,
#          ('minister',): 1,
#          ('rational',): 1,
#          ('funded',): 1,
#          ('front',): 1,
#          ('inability',): 1,
#          ('proved',): 1,
#          ('investments',): 1,
#          ('compared',): 1,
#          ('overwhelming',): 1,
#          ('compatibility',): 1,
#          ('pollute',): 1,
#          ('accelerates',): 1,
#          ('helps',): 1,
#          ('limits',): 1,
#          ('summit',): 1,
#          ('suitability',): 1,
#          ('powers',): 1,
#          ('weaken',): 1,
#          ('solving',): 1,
#          ('charter',): 1,
#          ('aside',): 1,
#          ('monitored',): 1,
#          ('destruction',): 1,
#          ('places',): 1,
#          ('kept',): 1,
#          ('temporary',): 1,
#          ('moreover',): 1,
#          ('genuinely',): 1,
#          ('harmoniously',): 1,
#          ('themes',): 1,
#          ('applying',): 1,
#          ('hasty',): 1,
#          ('forming',): 1,
#          ('adverse',): 1,
# ...
#          ('fulfilled',): 1,
#          ('europewide',): 1,
#          ('mediterranean',): 1,
#          ('latin',): 1,
#          ('accounting',): 1,
#          ('millions',): 1,
#          ('simplification',): 1,
#          ('payment',): 1,
#          ('clearing',): 1,
#          ('8',): 1,
#          ('undertakings',): 1,
#          ('institutes',): 1,
#          ('derive',): 1,
#          ('preparations',): 1,
#          ('filling',): 1,
#          ('preparation',): 1,
#          ('profits',): 1,
#          ('awaiting',): 1,
#          ('receive',): 1,
#          ('buildings',): 1,
#          ('strasbourg',): 1,
#          ('unanimous',): 1,
#          ('compliments',): 1,
#          ('restore',): 1,
#          ('illusions',): 1,
#          ('pretending',): 1,
#          ('dispute',): 1,
#          ('tidal',): 1,
#          ('describes',): 1,
#          ('avail',): 1,
#          ('startup',): 1,
#          ('ec',): 1,
#          ('supports',): 1,
#          ('slightly',): 1,
#          ('schierhuber',): 1,
#          ('significantly',): 1,
#          ('positively',): 1,
#          ('rebalancing',): 1,
#          ('deficit',): 1,
#          ('below',): 1,
#          ('generating',): 1,
#          ('sugar',): 1,
#          ('beet',): 1,
#          ('cereals',): 1,
#          ('seeds',): 1,
#          ('hemp',): 1,
#          ('cultivate',): 1,
#          ('ongoing',): 1,
#          ('sellafield',): 1,
#          ('prevailing',): 1,
#          ('counts',): 1,
#          ('lies',): 1,
#          ('corner',): 1,
#          ('startingpoint',): 1,
#          ('grief',): 1,
#          ('conclude',): 1,
#          ('floor',): 1,
#          ('delay',): 1,
#          ('fairly',): 1,
#          ('complex',): 1,
#          ('suspend',): 1,
#          ('resume',): 1,
#          ('congratulated',): 1,
#          ('bells',): 1,
#          ('ringing',): 1,
#          ('corridor',): 1,
#          ('accustomed',): 1,
#          ('1220',): 1,
#          ('clock',): 1,
#          ('confused',): 1,
#          ('178',): 1,
#          ('table',): 1,
#          ('dutybound',): 1,
#          ('morris',): 1,
#          ('listen',): 1,
#          ('announcement',): 1,
#          ('received',): 1,
#          ('191',): 1,
#          ('sentence',): 1,
#          ('request',): 1,
#          ('alliance',): 1,
#          ('115',): 1,
#          ('allows',): 1,
#          ('31',): 1,
#          ('confronted',): 1,
#          ('described',): 1,
#          ('129',): 1,
#          ('endorsed',): 1,
#          ('handle',): 1,
#          ('rise',): 1,
#          ('caters',): 1,
#          ('deliberately',): 1,
#          ('possibly',): 1,
#          ('abuse',): 1,
#          ('requesting',): 1,
#          ('roll',): 1,
#          ('justified',): 1,
#          ('tactics',): 1,
#          ('avoided',): 1,
#          ('fair',): 1,
#          ('discretion',): 1,
#          ('distressed',): 1,
#          ('angry',): 1,
#          ('happy',): 1,
#          ('debated',): 1,
#          ('165',): 1,
#          ('identical',): 1,
#          ('regarded',): 1,
#          ('unpleasant',): 1,
#          ('unnecessary',): 1,
#          ('tactic',): 1,
#          ('roths',): 1,
#          ('nicole',): 1,
#          ('pery',): 1,
#          ('vicepresidents',): 1,
#          ('reading',): 1,
#          ('withdrawing',): 1,
#          ('withdraw',): 1,
#          ('seppänen',): 1,
#          ('advise',): 1,
#          ('paragraphs',): 1,
#          ('36',): 1,
#          ('reverted',): 1,
#          ('b',): 1,
#          ('reconsider',): 1,
#          ('falconer',): 1,
#          ('scot',): 1,
#          ('obviously',): 1,
#          ('explained',): 1,
#          ('interpretations',): 1,
#          ('relates',): 1,
#          ('competent',): 1,
#          ('prior',): 1,
#          ('amsterdam',): 1,
#          ('contradiction',): 1,
#          ('decides',): 1,
#          ('agenda',): 1,
#          ('acted',): 1,
#          ('correctly',): 1,
#          ('solely',): 1,
#          ('farce',): 1,
#          ('expedite',): 1,
#          ('business',): 1,
#          ('absolutely',): 1,
#          ('operated',): 1,
#          ('notice',): 1,
#          ('informing',): 1,
#          ('intend',): 1,
#          ('informed',): 1,
#          ('advised',): 1,
#          ('named',): 1,
#          ('recognized',): 1,
#          ('breath',): 1,
#          ('kosovo',): 1,
#          ('vojvodina',): 1,
#          ('emphatically',): 1,
#          ('johannes',): 1,
#          ('swoboda',): 1,
#          ('told',): 1,
#          ('deleted',): 1,
#          ('misplaced',): 1,
#          ('stupid',): 1,
#          ('wise',): 1,
#          ('pack',): 1,
#          ('happens',): 1,
#          ('live',): 1,
#          ('organization',): 1,
#          ('translation',): 1,
#          ('confusion',): 1,
#          ('indications',): 1,
#          ('alter',): 1,
#          ('excessively',): 1,
#          ('lose',): 1,
#          ('loud',): 1,
#          ('offence',): 1,
#          ('minuted',): 1,
#          ('pleased',): 1,
#          ('adoption',): 1,
#          ('disapproval',): 1,
#          ('primarily',): 1,
#          ('global',): 1,
#          ('involve',): 1,
#          ('indirect',): 1,
#          ('severely',): 1,
#          ('restricted',): 1,
#          ('unfortunate',): 1,
#          ('consulted',): 1,
#          ('reached',): 1,
#          ('systematic',): 1,
#          ('failing',): 1,
#          ('pose',): 1,
#          ('reminds',): 1,
#          ('extending',): 1,
#          ('200',): 1,
#          ('miles',): 1,
#          ('95',): 1,
#          ('coastal',): 1,
#          ('jurisdiction',): 1,
#          ('negotiate',): 1,
#          ('survival',): 1,
#          ('deepsea',): 1,
#          ('vacant',): 1,
#          ('fleet',): 1,
#          ('soon',): 1,
#          ('competing',): 1,
#          ('backed',): 1,
#          ('shipowners',): 1,
#          ('tune',): 1,
#          ('balance',): 1,
#          ('feel',): 1,
#          ('boats',): 1,
#          ('contract',): 1,
#          ('evolution',): 1,
#          ('careful',): 1,
#          ('distinction',): 1,
#          ('selfsufficiency',): 1,
#          ('competitors',): 1,
#          ('fishermen',): 1,
#          ('distortions',): 1,
#          ('generalise',): 1,
#          ('acp',): 1,
#          ('abundant',): 1,
#          ('highquality',): 1,
#          ('dedicate',): 1,
#          ('acquire',): 1,
#          ('senegal',): 1,
#          ('network',): 1,
#          ('species',): 1,
#          ('seafood',): 1,
#          ('overfished',): 1,
#          ('lacks',): 1,
#          ('inherent',): 1,
#          ('search',): 1,
#          ('consensus',): 1,
#          ('reduced',): 1,
#          ('treated',): 1,
#          ('controlled',): 1,
#          ('nos',): 1,
#          ('41',): 1,
#          ('43',): 1,
#          ('object',): 1,
#          ('payers',): 1,
#          ('k',): 1,
#          ('utterly',): 1,
#          ('organisation',): 1,
#          ('foundations',): 1,
#          ('non',): 1,
#          ('aligned',): 1,
#          ('subordinate',): 1,
#          ('driven',): 1,
#          ('views',): 1,
#          ('larger',): 1,
#          ('dominant',): 1,
#          ('justify',): 1,
#          ('saying',): 1,
#          ('credibility',): 1,
#          ('wreck',): 1,
#          ('includes',): 1,
#          ('overwhelmingly',): 1,
#          ('focusing',): 1,
#          ('armies',): 1,
#          ('amongst',): 1,
#          ('exporters',): 1,
#          ('serving',): 1,
#          ('army',): 1,
#          ('peacekeeping',): 1,
#          ('mandates',): 1,
#          ('proud',): 1,
#          ('ireland',): 1,
#          ('soldiers',): 1,
#          ('news',): 1,
#          ('spending',): 1,
#          ('fallen',): 1,
#          ('total',): 1,
#          ('sale',): 1,
#          ('mines',): 1,
#          ('apprehension',): 1,
#          ('super',): 1,
#          ('recommending',): 1,
#          ('interesting',): 1,
#          ('federalist',): 1,
#          ('ultraliberal',): 1,
#          ('opens',): 1,
#          ('profitability',): 1,
#          ('preserve',): 1,
#          ('name',): 1,
#          ('cult',): 1,
#          ('asymmetry',): 1,
#          ('doctrine',): 1,
#          ('europeans',): 1,
#          ('continuously',): 1,
#          ('armament',): 1,
#          ('protected',): 1,
#          ('sorts',): 1,
#          ('ways',): 1,
#          ('recommends',): 1,
#          ('symmetrical',): 1,
#          ('purchase',): 1,
#          ('integrated',): 1,
#          ('method',): 1,
#          ('variable',): 1,
#          ('geometry',): 1,
#          ('lost',): 1,
#          ('abortive',): 1,
#          ('specificity',): 1,
#          ('overspending',): 1,
#          ('planned',): 1,
#          ('amounts',): 1,
#          ('rigid',): 1,
#          ('corporation',): 1,
#          ('artificial',): 1,
#          ('procedural',): 1,
#          ('activism',): 1,
#          ('precise',): 1,
#          ('correspondence',): 1,
#          ('progressively',): 1,
#          ('pragmatically',): 1,
#          ('countrys',): 1,
#          ('illsuited',): 1,
#          ('laissezfaire',): 1,
#          ('compromises',): 1,
#          ('nonexistent',): 1,
#          ('seen',): 1,
#          ('media',): 1,
#          ('none',): 1,
#          ('barely',): 1,
#          ('francogerman',): 1,
#          ('1995',): 1,
#          ('generalization',): 1,
#          ('intraeuropean',): 1,
#          ('properly',): 1,
#          ('completed',): 1,
#          ('finds',): 1,
#          ('coherent',): 1,
#          ('preferred',): 1,
#          ('aeronautics',): 1,
#          ('pool',): 1,
#          ('desirability',): 1,
#          ('twofold',): 1,
#          ('implications',): 1,
#          ('involvement',): 1,
#          ('touches',): 1,
#          ('essence',): 1,
#          ('relinquished',): 1,
#          ('lightly',): 1,
#          ('contrast',): 1,
#          ('leaves',): 1,
#          ('space',): 1,
#          ('connections',): 1,
#          ('concept',): 1,
#          ('demonstrates',): 1,
#          ('detract',): 1,
#          ('ample',): 1,
#          ('justification',): 1,
#          ('strengthening',): 1,
#          ('combat',): 1,
#          ('improper',): 1,
#          ('standardising',): 1,
#          ('industrys',): 1,
#          ('noted',): 1,
#          ('unrealistic',): 1,
#          ('liberalisation',): 1,
#          ('select',): 1,
#          ('firms',): 1,
#          ('abolishing',): 1,
#          ('consolidate',): 1,
#          ('mutual',): 1,
#          ('harmonious',): 1,
#          ('coexistence',): 1,
#          ('cultural',): 1,
#          ('essentially',): 1,
#          ('contributed',): 1,
#          ('decisively',): 1,
#          ('dissolution',): 1,
#          ('outbreak',): 1,
#          ('abnormal',): 1,
#          ('determined',): 1,
#          ('troops',): 1,
#          ('bosnia',): 1,
#          ('multinational',): 1,
#          ('facilities',): 1,
#          ('alien',): 1,
#          ('creating',): 1,
#          ('securing',): 1,
#          ('minorities',): 1,
#          ('facilitating',): 1,
#          ('resettlement',): 1,
#          ('reestablishing',): 1,
#          ('healthy',): 1,
#          ('actively',): 1,
#          ('contributions',): 1,
#          ('besides',): 1,
#          ('responsibilities',): 1,
#          ('yugoslavian',): 1,
#          ('accepting',): 1,
#          ('trends',): 1,
#          ('autonomy',): 1,
#          ('cover',): 1,
#          ('southeast',): 1,
#          ('owing',): 1,
#          ('similarity',): 1,
#          ('region',): 1,
#          ('disagree',): 1,
#          ('radically',): 1,
#          ('discriminatory',): 1,
#          ('perpetuation',): 1,
#          ('division',): 1,
#          ('discrimination',): 1,
#          ('fomenting',): 1,
#          ('confrontations',): 1,
#          ('focuses',): 1,
#          ('conflict',): 1,
#          ('distribute',): 1,
#          ('equality',): 1,
#          ('republics',): 1,
#          ('quo',): 1,
#          ('particularities',): 1,
#          ('controlling',): 1,
#          ('leaving',): 1,
#          ('fate',): 1,
#          ('standpoint',): 1,
#          ('imposition',): 1,
#          ('regimes',): 1,
#          ('savage',): 1,
#          ('capitalism',): 1,
#          ('pretext',): 1,
#          ('marshall',): 1,
#          ('conformity',): 1,
#          ('criterion',): 1,
#          ('excuse',): 1,
#          ('punish',): 1,
#          ('dictates',): 1,
#          ('avert',): 1,
#          ('tensions',): 1,
#          ('conventions',): 1,
#          ('frontier',): 1,
#          ('militarization',): 1,
#          ('encounter',): 1,
#          ('objections',): 1,
#          ('hiding',): 1,
#          ('deceptive',): 1,
#          ('crespo',): 1,
#          ('organisational',): 1,
#          ('rapprochement',): 1,
#          ('weu',): 1,
#          ('allowing',): 1,
#          ('veto',): 1,
#          ('contravenes',): 1,
#          ('swedish',): 1,
#          ('sphere',): 1,
#          ('reluctance',): 1,
#          ('resort',): 1,
#          ('arbitration',): 1,
#          ('condemning',): 1,
#          ('tricky',): 1,
#          ('lobbies',): 1,
#          ('importers',): 1,
#          ('entry',): 1,
#          ('meat',): 1,
#          ('spite',): 1,
#          ('mad',): 1,
#          ('cows',): 1,
#          ('opinions',): 1,
#          ('failed',): 1,
#          ('complain',): 1,
#          ('violation',): 1,
#          ('helmsburton',): 1,
#          ('embargo',): 1,
#          ('cuba',): 1,
#          ('arrest',): 1,
#          ('businessman',): 1,
#          ('crime',): 1,
#          ('indulging',): 1,
#          ('island',): 1,
#          ('transnationals',): 1,
#          ('dollar',): 1,
#          ('harm',): 1,
#          ('madeira',): 1,
#          ('analyzed',): 1,
#          ('subservience',): 1,
#          ('references',): 1,
#          ('globalized',): 1,
#          ('brakes',): 1,
#          ('deepening',): 1,
#          ('addressed',): 1,
#          ('textiles',): 1,
#          ('morocco',): 1,
#          ('seem',): 1,
#          ('switched',): 1,
#          ('rhetoric',): 1,
#          ('lagging',): 1,
#          ('predict',): 1,
#          ('getting',): 1,
#          ('ready',): 1,
#          ('enter',): 1,
#          ('kinshasa',): 1,
#          ('liberated',): 1,
#          ('manoeuvre',): 1,
#          ('marshal',): 1,
#          ('executions',): 1,
#          ('persecutions',): 1,
#          ('corruption',): 1,
#          ('excessive',): 1,
#          ('legitimate',): 1,
#          ('judge',): 1,
#          ('latter',): 1,
#          ('stabilisation',): 1,
#          ('assist',): 1,
#          ('civilian',): 1,
#          ('laurent',): 1,
#          ('kabila',): 1,
#          ('trial',): 1,
#          ('1994',): 1,
#          ('hostage',): 1,
#          ('execution',): 1,
#          ('rear',): 1,
#          ('kigali',): 1,
#          ('deaf',): 1,
#          ('ears',): 1,
#          ('timebomb',): 1,
#          ('ever',): 1,
#          ('listened',): 1,
#          ('warnings',): 1,
#          ('blindness',): 1,
#          ('guarantor',): 1,
#          ('territorial',): 1,
#          ('integrity',): 1,
#          ('stretching',): 1,
#          ('sudan',): 1,
#          ('reveals',): 1,
#          ('complete',): 1,
#          ('conspicuous',): 1,
#          ('settlement',): 1,
#          ('incapable',): 1,
#          ('minimum',): 1,
#          ('degree',): 1,
#          ('dictatorships',): 1,
#          ('maximalist',): 1,
#          ('emerging',): 1,
#          ('devastated',): 1,
#          ('painful',): 1,
#          ('review',): 1,
#          ('lakes',): 1,
#          ('submitted',): 1,
#          ('discuss',): 1,
#          ('decrease',): 1,
#          ('concentrate',): 1,
#          ('thoughts',): 1,
#          ('challenges',): 1,
#          ('structures',): 1,
#          ('uncontrolled',): 1,
#          ('imperative',): 1,
#          ('willingly',): 1,
#          ('inevitably',): 1,
#          ('tackled',): 1,
#          ('guaranteed',): 1,
#          ('coresponsibility',): 1,
#          ('1970s',): 1,
#          ('river',): 1,
#          ('moselle',): 1,
#          ('broadly',): 1,
#          ('socialists',): 1,
#          ('afterwards',): 1,
#          ('neighbour',): 1,
#          ('asking',): 1,
#          ('toplevel',): 1,
#          ('visits',): 1,
#          ('countless',): 1,
#          ('diplomatic',): 1,
#          ('interventions',): 1,
#          ('albeit',): 1,
#          ('install',): 1,
#          ('mentioning',): 1,
#          ('kilometres',): 1,
#          ('reserve',): 1,
#          ('tourism',): 1,
#          ('railway',): 1,
#          ('lorraine',): 1,
#          ('convoys',): 1,
#          ('trains',): 1,
#          ('transporting',): 1,
#          ('anyones',): 1,
#          ('transportation',): 1,
#          ('communities',): 1,
#          ('overnight',): 1,
#          ('practised',): 1,
#          ('nuance',): 1,
#          ('everything',): 1,
#          ('dangers',): 1,
#          ('profoundly',): 1,
#          ('amend',): 1,
#          ('relic',): 1,
#          ('admiration',): 1})

# %%
bigram_counter = Counter()
sample = corpus_clean_no_OOV[0:1000]

for sent in sample:
    bigram_counter.update([gram for gram in ngrams(sent, 2, pad_left=True, pad_right=True,
                                                   left_pad_symbol='<s>',right_pad_symbol='<e>') ])
pprint(bigram_counter)
# Out:
# Counter({('of', 'the'): 208,
#          ('in', 'the'): 142,
#          ('<s>', 'i'): 109,
#          ('the', 'european'): 96,
#          ('to', 'the'): 94,
#          ('it', 'is'): 90,
#          ('<s>', 'the'): 87,
#          ('nuclear', 'power'): 82,
#          ('for', 'the'): 76,
#          ('on', 'the'): 70,
#          ('<s>', 'it'): 68,
#          ('<s>', 'we'): 66,
#          ('that', 'the'): 64,
#          ('and', 'the'): 63,
#          ('mr', 'president'): 60,
#          ('<s>', 'mr'): 58,
#          ('renewable', 'energy'): 57,
#          ('energy', 'sources'): 51,
#          ('to', 'be'): 50,
#          ('of', 'nuclear'): 45,
#          ('is', 'a'): 44,
#          ('nuclear', 'energy'): 44,
#          ('<s>', 'in'): 42,
#          ('european', 'union'): 42,
#          ('by', 'the'): 41,
#          ('that', 'is'): 40,
#          ('we', 'are'): 39,
#          ('member', 'states'): 39,
#          ('i', 'would'): 38,
#          ('the', 'commission'): 38,
#          ('with', 'the'): 37,
#          ('<s>', 'that'): 37,
#          ('and', 'i'): 36,
#          ('that', 'we'): 35,
#          ('<s>', 'this'): 35,
#          ('of', 'energy'): 34,
#          ('we', 'have'): 33,
#          ('at', 'the'): 32,
#          ('energy', '<e>'): 32,
#          ('there', 'is'): 31,
#          ('in', 'this'): 31,
#          ('power', 'stations'): 31,
#          ('i', 'am'): 29,
#          ('like', 'to'): 28,
#          ('is', 'not'): 27,
#          ('do', 'not'): 27,
#          ('the', 'nuclear'): 26,
#          ('we', 'should'): 25,
#          ('from', 'the'): 25,
#          ('which', 'is'): 25,
#          ('the', 'report'): 25,
#          ('use', 'of'): 25,
#          ('as', 'a'): 24,
#          ('report', '<e>'): 24,
#          ('this', 'is'): 24,
#          ('is', 'the'): 23,
#          ('would', 'be'): 23,
#          ('of', 'a'): 23,
#          ('<s>', 'if'): 23,
#          ('should', 'be'): 23,
#          ('there', 'are'): 22,
#          ('of', 'renewable'): 22,
#          ('if', 'we'): 22,
#          ('have', 'to'): 21,
#          ('wish', 'to'): 21,
#          ('of', 'this'): 21,
#          ('we', 'must'): 21,
#          ('<s>', 'and'): 21,
#          ('president', 'i'): 20,
#          ('i', 'have'): 20,
#          ('european', 'parliament'): 20,
#          ('mr', 'soulier'): 20,
#          ('<s>', 'but'): 20,
#          ('the', 'same'): 20,
#          ('for', 'a'): 19,
#          ('want', 'to'): 19,
#          ('will', 'be'): 19,
#          ('<s>', 'there'): 19,
#          ('i', 'should'): 19,
#          ('question', 'of'): 18,
#          ('the', 'rapporteur'): 18,
#          ('nuclear', 'industry'): 18,
#          ('must', 'be'): 18,
#          ('green', 'paper'): 18,
#          ('to', 'say'): 17,
#          ('on', 'this'): 17,
#          ('policy', '<e>'): 17,
#          ('we', 'can'): 17,
#          ('of', 'course'): 17,
#          ('and', 'that'): 17,
#          ('in', 'a'): 17,
#          ('are', 'not'): 17,
#          ('can', 'be'): 17,
#          ('this', 'report'): 17,
#          ('and', 'we'): 16,
#          ('i', 'think'): 16,
#          ('the', 'committee'): 16,
#          ('energy', 'policy'): 16,
#          ('as', 'the'): 16,
#          ('the', 'member'): 16,
#          ('the', 'use'): 16,
#          ('agree', 'with'): 16,
#          ('the', 'eu'): 16,
#          ('all', 'the'): 16,
#          ('<s>', 'for'): 15,
#          ('have', 'been'): 15,
#          ('<s>', 'as'): 15,
#          ('in', 'particular'): 15,
#          ('say', 'that'): 15,
#          ('not', 'to'): 15,
#          ('a', 'very'): 15,
#          ('the', 'environment'): 15,
#          ('<s>', 'so'): 15,
#          ('we', 'need'): 15,
#          ('going', 'to'): 15,
#          ('such', 'as'): 15,
#          ('and', 'in'): 14,
#          ('to', 'make'): 14,
#          ('that', 'i'): 14,
#          ('is', 'no'): 14,
#          ('committee', 'on'): 14,
#          ('should', 'like'): 14,
#          ('in', 'favour'): 14,
#          ('the', 'future'): 14,
#          ('energy', 'is'): 14,
#          ('let', 'me'): 14,
#          ('with', 'a'): 14,
#          ('the', 'green'): 14,
#          ('is', 'also'): 13,
#          ('has', 'been'): 13,
#          ('need', 'to'): 13,
#          ('the', 'euratom'): 13,
#          ('euratom', 'treaty'): 13,
#          ('ladies', 'and'): 13,
#          ('and', 'gentlemen'): 13,
#          ('that', 'this'): 13,
#          ('the', 'question'): 13,
#          ('which', 'we'): 13,
#          ('is', 'why'): 13,
#          ('which', 'have'): 12,
#          ('should', 'not'): 12,
#          ('the', 'countries'): 12,
#          ('of', 'all'): 12,
#          ('not', 'only'): 12,
#          ('that', 'in'): 12,
#          ('in', 'europe'): 12,
#          ('the', 'world'): 12,
#          ('favour', 'of'): 12,
#          ('fact', 'that'): 12,
#          ('the', 'energy'): 12,
#          ('it', 'would'): 12,
#          ('does', 'not'): 12,
#          ('is', 'an'): 12,
#          ('i', 'believe'): 12,
#          ('in', 'order'): 12,
#          ('can', 'only'): 12,
#          ('at', 'least'): 11,
#          ('the', 'UNK'): 11,
#          ('is', 'that'): 11,
#          ('we', 'want'): 11,
#          ('i', 'wish'): 11,
#          ('in', 'my'): 11,
#          ('number', 'of'): 11,
#          ('the', 'community'): 11,
#          ('union', '<e>'): 11,
#          ('UNK', '<e>'): 11,
#          ('to', 'do'): 11,
#          ('and', 'it'): 11,
#          ('point', 'of'): 11,
#          ('which', 'are'): 11,
#          ('the', 'fact'): 11,
#          ('we', 'UNK'): 11,
#          ('that', 'would'): 11,
#          ('power', '<e>'): 11,
#          ('my', 'group'): 11,
#          ('power', 'station'): 11,
#          ('order', 'to'): 11,
#          ('a', 'common'): 11,
#          ('here', '<e>'): 11,
#          ('the', 'vote'): 10,
#          ('in', 'which'): 10,
#          ('would', 'also'): 10,
#          ('which', 'has'): 10,
#          ('but', 'also'): 10,
#          ('the', 'house'): 10,
#          ('we', 'do'): 10,
#          ('because', 'the'): 10,
#          ('technological', 'development'): 10,
#          ('of', 'their'): 10,
#          ('think', 'that'): 10,
#          ('sources', '<e>'): 10,
#          ('energy', 'and'): 10,
#          ('and', 'a'): 10,
#          ('european', 'commission'): 10,
#          ('not', 'be'): 10,
#          ('states', '<e>'): 10,
#          ('within', 'the'): 10,
#          ('white', 'paper'): 10,
#          ('believe', 'that'): 10,
#          ('<s>', 'my'): 10,
#          ('<s>', 'a'): 10,
#          ('based', 'on'): 10,
#          ('that', 'nuclear'): 10,
#          ('development', 'of'): 10,
#          ('the', 'commissions'): 10,
#          ('of', 'UNK'): 10,
#          ('what', 'is'): 10,
#          ('to', 'give'): 10,
#          ('on', 'renewable'): 10,
#          ('mrs', 'rothe'): 10,
#          ('of', 'european'): 10,
#          ('a', 'european'): 10,
#          ('the', 'whole'): 9,
#          ('<s>', 'let'): 9,
#          ('let', 'us'): 9,
#          ('and', 'also'): 9,
#          ('the', 'last'): 9,
#          ('by', 'a'): 9,
#          ('the', 'debate'): 9,
#          ('debate', 'on'): 9,
#          ('this', 'house'): 9,
#          ('i', 'can'): 9,
#          ('president', 'ladies'): 9,
#          ('a', 'whole'): 9,
#          ('european', 'unions'): 9,
#          ('but', 'we'): 9,
#          ('the', 'amendments'): 9,
#          ('that', 'it'): 9,
#          ('eastern', 'europe'): 9,
#          ('in', 'that'): 9,
#          ('against', 'the'): 9,
#          ('it', '<e>'): 9,
#          ('it', 'should'): 9,
#          ('the', 'promotion'): 9,
#          ('the', 'safety'): 9,
#          ('safety', 'of'): 9,
#          ('to', 'build'): 9,
#          ('to', 'nuclear'): 9,
#          ('<s>', 'at'): 9,
#          ('nuclear', 'waste'): 9,
#          ('in', 'any'): 9,
#          ('be', 'a'): 9,
#          ('i', 'do'): 9,
#          ('has', 'to'): 9,
#          ('is', 'being'): 9,
#          ('the', 'area'): 9,
#          ('vote', 'on'): 9,
#          ('titley', 'report'): 9,
#          ('and', 'to'): 8,
#          ('during', 'the'): 8,
#          ('as', 'well'): 8,
#          ('parliament', '<e>'): 8,
#          ('the', 'best'): 8,
#          ('development', 'and'): 8,
#          ('and', 'energy'): 8,
#          ('to', 'see'): 8,
#          ('terms', 'of'): 8,
#          ('one', '<e>'): 8,
#          ('have', 'the'): 8,
#          ('of', 'view'): 8,
#          ('us', 'to'): 8,
#          ('europe', '<e>'): 8,
#          ('countries', 'of'): 8,
#          ('to', 'take'): 8,
#          ('stations', '<e>'): 8,
#          ('they', 'are'): 8,
#          ('be', 'the'): 8,
#          ('<s>', 'however'): 8,
#          ('to', 'promote'): 8,
#          ('be', 'used'): 8,
#          ('promotion', 'of'): 8,
#          ('is', 'very'): 8,
#          ('of', 'that'): 8,
#          ('to', 'this'): 8,
#          ('that', 'there'): 8,
#          ('form', 'of'): 8,
#          ('for', 'this'): 8,
#          ('the', 'new'): 8,
#          ('this', 'sector'): 8,
#          ('on', 'a'): 8,
#          ('hope', 'that'): 8,
#          ('the', 'development'): 8,
#          ('on', 'energy'): 8,
#          ('technology', '<e>'): 8,
#          ('of', 'our'): 8,
#          ('i', 'also'): 8,
#          ('i', 'must'): 8,
#          ('support', 'the'): 8,
#          ('<s>', 'here'): 8,
#          ('<s>', 'commissioner'): 8,
#          ('which', 'the'): 8,
#          ('part', 'of'): 8,
#          ('could', 'be'): 8,
#          ('for', 'renewable'): 8,
#          ('vote', 'in'): 8,
#          ('the', 'titley'): 8,
#          ('and', 'UNK'): 7,
#          ('once', 'again'): 7,
#          ('members', 'of'): 7,
#          ('we', 'also'): 7,
#          ('by', 'mr'): 7,
#          ('i', 'know'): 7,
#          ('know', 'that'): 7,
#          ('not', 'a'): 7,
#          ('and', 'which'): 7,
#          ('would', 'like'): 7,
#          ('make', 'it'): 7,
#          ('<s>', 'unfortunately'): 7,
#          ('first', 'of'): 7,
#          ('this', 'debate'): 7,
#          ('this', '<e>'): 7,
#          ('when', 'it'): 7,
#          ('is', 'quite'): 7,
#          ('in', 'terms'): 7,
#          ('the', 'second'): 7,
#          ('since', 'the'): 7,
#          ('about', 'the'): 7,
#          ('we', 'would'): 7,
#          ('years', '<e>'): 7,
#          ('<s>', 'on'): 7,
#          ('by', 'mrs'): 7,
#          ('against', 'nuclear'): 7,
#          ('power', 'in'): 7,
#          ('would', 'say'): 7,
#          ('at', 'present'): 7,
#          ('up', 'to'): 7,
#          ('time', '<e>'): 7,
#          ('so', 'that'): 7,
#          ('a', 'number'): 7,
#          ('waste', 'and'): 7,
#          ('up', 'the'): 7,
#          ('central', 'and'): 7,
#          ('and', 'eastern'): 7,
#          ('in', 'other'): 7,
#          ('report', 'and'): 7,
#          ('for', 'nuclear'): 7,
#          ('the', 'liberalization'): 7,
#          ('liberalization', 'of'): 7,
#          ('of', 'electricity'): 7,
#          ('we', 'will'): 7,
#          ('do', 'so'): 7,
#          ('i', 'hope'): 7,
#          ('energy', 'in'): 7,
#          ('industry', 'and'): 7,
#          ('must', 'not'): 7,
#          ('be', 'taken'): 7,
#          ('because', 'it'): 7,
#          ('any', 'case'): 7,
#          ('because', 'of'): 7,
#          ('on', 'all'): 7,
#          ('seems', 'to'): 7,
#          ('as', 'for'): 7,
#          ('of', 'each'): 7,
#          ('UNK', 'and'): 7,
#          ('safety', 'and'): 7,
#          ('<s>', 'yet'): 7,
#          ('nuclear', 'installations'): 7,
#          ('<s>', 'to'): 7,
#          ('back', 'to'): 7,
#          ('to', 'vote'): 7,
#          ('the', 'case'): 7,
#          ('the', 'council'): 7,
#          ('know', 'what'): 7,
#          ('research', 'and'): 7,
#          ('if', 'the'): 7,
#          ('wastes', '<e>'): 7,
#          ('report', 'UNK'): 7,
#          ('renewable', 'sources'): 7,
#          ('way', 'we'): 7,
#          ('defence', 'industry'): 7,
#          ('in', 'recent'): 6,
#          ('most', 'of'): 6,
#          ('in', 'all'): 6,
#          ('more', 'than'): 6,
#          ('countries', 'which'): 6,
#          ('result', 'of'): 6,
#          ('in', 'relation'): 6,
#          ('relation', 'to'): 6,
#          ('the', 'rules'): 6,
#          ('also', 'like'): 6,
#          ('around', 'the'): 6,
#          ('well', 'as'): 6,
#          ('not', 'just'): 6,
#          ('all', '<e>'): 6,
#          ('refer', 'to'): 6,
#          ('as', 'to'): 6,
#          ('so', 'i'): 6,
#          ('the', 'united'): 6,
#          ('a', 'certain'): 6,
#          ('the', 'need'): 6,
#          ('to', 'ensure'): 6,
#          ('countries', 'in'): 6,
#          ('european', 'countries'): 6,
#          ('you', 'have'): 6,
#          ('right', 'to'): 6,
#          ('over', 'the'): 6,
#          ('40', 'years'): 6,
#          ('without', 'any'): 6,
#          ('should', 'have'): 6,
#          ('be', 'in'): 6,
#          ('the', 'risks'): 6,
#          ('<s>', 'what'): 6,
#          ('we', 'know'): 6,
#          ('must', 'also'): 6,
#          ('and', 'its'): 6,
#          ('tabled', 'by'): 6,
#          ('mrs', 'mcnally'): 6,
#          ('and', 'therefore'): 6,
#          ('renewable', 'energies'): 6,
#          ('<s>', 'finally'): 6,
#          ('for', 'us'): 6,
#          ('but', 'i'): 6,
#          ('waste', '<e>'): 6,
#          ('a', 'single'): 6,
#          ('to', 'have'): 6,
#          ('i', 'shall'): 6,
#          ('of', 'radioactive'): 6,
#          ('the', 'union'): 6,
#          ('the', 'other'): 6,
#          ('in', 'nuclear'): 6,
#          ('sources', 'and'): 6,
#          ('a', 'new'): 6,
#          ('how', 'to'): 6,
#          ('i', 'UNK'): 6,
#          ('forms', 'of'): 6,
#          ('mr', 'UNK'): 6,
#          ('excellent', 'report'): 6,
#          ('the', 'economic'): 6,
#          ('UNK', 'be'): 6,
#          ('same', 'time'): 6,
#          ('from', 'a'): 6,
#          ('europe', 'and'): 6,
#          ('and', 'of'): 6,
#          ('of', 'waste'): 6,
#          ('the', 'framework'): 6,
#          ('framework', 'of'): 6,
#          ('the', 'white'): 6,
#          ('paper', 'on'): 6,
#          ('partly', 'because'): 6,
#          ('types', 'of'): 6,
#          ('so', 'we'): 6,
#          ('look', 'at'): 6,
#          ('a', 'great'): 6,
#          ('be', 'done'): 6,
#          ('to', 'congratulate'): 6,
#          ('it', 'in'): 6,
#          ('my', 'opinion'): 6,
#          ('linked', 'to'): 6,
#          ('commission', 'is'): 6,
#          ('me', 'say'): 6,
#          ('that', '<e>'): 6,
#          ('that', 'will'): 6,
#          ('our', 'energy'): 6,
#          ('the', 'time'): 6,
#          ('cost', 'of'): 6,
#          ('<s>', 'all'): 6,
#          ('are', 'still'): 6,
#          ('should', 'also'): 6,
#          ('one', 'of'): 6,
#          ('of', 'my'): 6,
#          ('to', 'speak'): 6,
#          ('to', 'develop'): 6,
#          ('a', 'few'): 6,
#          ('this', 'would'): 6,
#          ('only', 'be'): 6,
#          ('to', 'put'): 6,
#          ('european', 'citizens'): 6,
#          ('a', 'community'): 6,
#          ('necessary', 'to'): 6,
#          ('with', 'me'): 6,
#          ('sources', 'of'): 6,
#          ('union', 'is'): 6,
#          ('needs', 'to'): 6,
#          ('european', 'defence'): 6,
#          ('time', 'the'): 5,
#          ('the', 'next'): 5,
#          ('vote', '<e>'): 5,
#          ('the', 'president'): 5,
#          ('such', 'a'): 5,
#          ('the', 'first'): 5,
#          ('to', 'our'): 5,
#          ('<s>', 'applause'): 5,
#          ('a', 'result'): 5,
#          ('UNK', 'of'): 5,
#          ('decided', 'to'): 5,
#          ('commission', 'and'): 5,
#          ('to', 'improve'): 5,
#          ('a', 'matter'): 5,
#          ('my', 'report'): 5,
#          ('make', 'a'): 5,
#          ('house', '<e>'): 5,
#          ('am', 'not'): 5,
#          ('time', 'to'): 5,
#          ('recent', 'years'): 5,
#          ('ought', 'to'): 5,
#          ('<s>', 'parliament'): 5,
#          ('report', 'by'): 5,
#          ('according', 'to'): 5,
#          ('so', '<e>'): 5,
#          ('that', 'you'): 5,
#          ('it', 'comes'): 5,
#          ('comes', 'to'): 5,
#          ('level', 'of'): 5,
#          ('do', 'we'): 5,
#          ('we', 'really'): 5,
#          ('the', 'public'): 5,
#          ('to', 'us'): 5,
#          ('a', 'nuclear'): 5,
#          ('report', 'is'): 5,
#          ('type', 'of'): 5,
#          ('this', 'subject'): 5,
#          ('or', 'against'): 5,
#          ('in', 'keeping'): 5,
#          ('keeping', 'with'): 5,
#          ('progress', '<e>'): 5,
#          ('<s>', 'secondly'): 5,
#          ('no', '<e>'): 5,
#          ('of', 'those'): 5,
#          ('united', 'states'): 5,
#          ('is', 'our'): 5,
#          ('able', 'to'): 5,
#          ('area', '<e>'): 5,
#          ('the', 'necessary'): 5,
#          ('emphasis', 'on'): 5,
#          ('the', 'ageing'): 5,
#          ('internal', 'market'): 5,
#          ('future', '<e>'): 5,
#          ('here', 'in'): 5,
#          ('in', 'fact'): 5,
#          ('unable', 'to'): 5,
#          ('countries', 'and'): 5,
#          ('is', 'to'): 5,
#          ('are', 'the'): 5,
#          ('radioactive', 'waste'): 5,
#          ('but', 'it'): 5,
#          ('not', 'the'): 5,
#          ('and', 'so'): 5,
#          ('<s>', 'you'): 5,
#          ('it', 'was'): 5,
#          ('was', 'a'): 5,
#          ('some', 'of'): 5,
#          ('if', 'they'): 5,
#          ('build', 'a'): 5,
#          ('UNK', 'the'): 5,
#          ('his', 'report'): 5,
#          ('research', 'into'): 5,
#          ('to', 'decide'): 5,
#          ('as', 'it'): 5,
#          ('the', 'most'): 5,
#          ('most', 'important'): 5,
#          ('<s>', 'from'): 5,
#          ('of', 'central'): 5,
#          ('research', '<e>'): 5,
#          ('rapporteur', 'mr'): 5,
#          ('industry', 'in'): 5,
#          ('very', 'important'): 5,
#          ('the', 'field'): 5,
#          ('field', 'of'): 5,
#          ('member', 'state'): 5,
#          ('with', 'mr'): 5,
#          ('has', 'not'): 5,
#          ('<s>', 'nuclear'): 5,
#          ('is', 'what'): 5,
#          ('means', 'that'): 5,
#          ('UNK', 'report'): 5,
#          ('no', 'way'): 5,
#          ('no', 'nuclear'): 5,
#          ('at', 'all'): 5,
#          ('say', 'the'): 5,
#          ('and', 'secondly'): 5,
#          ('for', 'instance'): 5,
#          ('<s>', 'then'): 5,
#          ('the', 'only'): 5,
#          ('with', 'this'): 5,
#          ('to', 'which'): 5,
#          ('for', 'example'): 5,
#          ('why', 'i'): 5,
#          ('need', 'a'): 5,
#          ('rather', 'than'): 5,
#          ('aware', 'of'): 5,
#          ('a', 'question'): 5,
#          ('for', 'their'): 5,
#          ('in', 'our'): 5,
#          ('and', 'disposal'): 5,
#          ('the', 'subject'): 5,
#          ('subject', 'of'): 5,
#          ('the', 'year'): 5,
#          ('you', 'to'): 5,
#          ('i', 'want'): 5,
#          ('congratulate', 'the'): 5,
#          ('sources', 'in'): 5,
#          ('the', 'price'): 5,
#          ('case', 'of'): 5,
#          ('their', 'own'): 5,
#          ('the', 'basis'): 5,
#          ('basis', 'of'): 5,
#          ('which', 'i'): 5,
#          ('to', 'continue'): 5,
#          ('just', 'as'): 5,
#          ('into', 'account'): 5,
#          ('proposal', '<e>'): 5,
#          ('for', 'our'): 5,
#          ('the', 'implementation'): 5,
#          ('implementation', 'of'): 5,
#          ('between', 'the'): 5,
#          ('strategy', 'for'): 5,
#          ('the', 'internal'): 5,
#          ('european', 'energy'): 5,
#          ('a', 'real'): 5,
#          ('are', 'to'): 5,
#          ('kind', 'of'): 5,
#          ('rural', 'areas'): 5,
#          ('have', 'a'): 5,
#          ('the', 'sun'): 5,
#          ('of', 'these'): 5,
#          ('we', 'could'): 5,
#          ('we', 'were'): 5,
#          ('<s>', 'just'): 5,
#          ('rollcall', 'vote'): 5,
#          ('your', 'proposal'): 5,
#          ('being', 'voted'): 5,
#          ('the', 'way'): 5,
#          ('and', 'other'): 4,
#          ('<s>', 'today'): 4,
#          ('citizens', 'of'): 4,
#          ('on', 'behalf'): 4,
#          ('behalf', 'of'): 4,
#          ('also', 'a'): 4,
#          ('world', '<e>'): 4,
#          ('had', 'to'): 4,
#          ('country', '<e>'): 4,
#          ('the', 'authorities'): 4,
#          ('the', 'peoples'): 4,
#          ('with', 'its'): 4,
#          ('rules', 'of'): 4,
#          ('of', 'procedure'): 4,
#          ('european', 'parliaments'): 4,
#          ('authorities', 'in'): 4,
#          ('in', 'brussels'): 4,
#          ('UNK', 'in'): 4,
#          ('together', 'with'): 4,
#          ('after', 'the'): 4,
#          ('and', 'more'): 4,
#          ('you', 'that'): 4,
#          ('the', 'minutes'): 4,
#          ('what', 'i'): 4,
#          ('industry', '<e>'): 4,
#          ('if', 'it'): 4,
#          ('clear', 'that'): 4,
#          ('the', 'french'): 4,
#          ('think', 'we'): 4,
#          ('we', 'all'): 4,
#          ('into', 'the'): 4,
#          ('research', 'technological'): 4,
#          ('all', 'i'): 4,
#          ('a', 'UNK'): 4,
#          ('it', 'has'): 4,
#          ('apart', 'from'): 4,
#          ('public', 'opinion'): 4,
#          ('through', 'the'): 4,
#          ('is', 'therefore'): 4,
#          ('states', 'and'): 4,
#          ('and', 'at'): 4,
#          ('because', 'we'): 4,
#          ('<s>', 'of'): 4,
#          ('course', 'we'): 4,
#          ('amendments', 'tabled'): 4,
#          ('states', 'have'): 4,
#          ('for', 'or'): 4,
#          ('be', 'respected'): 4,
#          ('all', 'member'): 4,
#          ('on', 'nuclear'): 4,
#          ('the', 'long'): 4,
#          ('above', 'all'): 4,
#          ('are', 'all'): 4,
#          ('and', 'technological'): 4,
#          ('the', 'present'): 4,
#          ('to', 'get'): 4,
#          ('would', 'not'): 4,
#          ('to', 'european'): 4,
#          ('also', 'in'): 4,
#          ('this', 'area'): 4,
#          ('towards', 'the'): 4,
#          ('europe', 'in'): 4,
#          ('up', 'and'): 4,
#          ('is', 'at'): 4,
#          ('of', 'technology'): 4,
#          ('be', 'able'): 4,
#          ('have', 'not'): 4,
#          ('ageing', 'of'): 4,
#          ('and', 'one'): 4,
#          ('what', 'would'): 4,
#          ('we', 'had'): 4,
#          ('and', 'if'): 4,
#          ('at', 'this'): 4,
#          ('know', 'how'): 4,
#          ('them', 'to'): 4,
#          ('trying', 'to'): 4,
#          ('in', 'its'): 4,
#          ('them', '<e>'): 4,
#          ('the', 'individual'): 4,
#          ('and', 'for'): 4,
#          ('health', 'and'): 4,
#          ('by', 'nuclear'): 4,
#          ('action', 'plan'): 4,
#          ('plan', 'for'): 4,
#          ('and', 'is'): 4,
#          ('it', 'can'): 4,
#          ('the', 'eus'): 4,
#          ('so', 'on'): 4,
#          ('soulier', 'for'): 4,
#          ('future', 'of'): 4,
#          ('it', 'and'): 4,
#          ('no', 'longer'): 4,
#          ('of', 'which'): 4,
#          ('to', 'bring'): 4,
#          ('which', 'would'): 4,
#          ('would', 'have'): 4,
#          ('investment', 'in'): 4,
#          ('a', 'lot'): 4,
#          ('<s>', 'because'): 4,
#          ('the', 'years'): 4,
#          ('come', 'to'): 4,
#          ('in', 'those'): 4,
#          ('the', 'costs'): 4,
#          ('is', 'one'): 4,
#          ('to', 'support'): 4,
#          ('power', 'is'): 4,
#          ('wrong', '<e>'): 4,
#          ('not', 'have'): 4,
#          ('did', 'not'): 4,
#          ('to', 'thank'): 4,
#          ('it', 'UNK'): 4,
#          ('source', 'of'): 4,
#          ('the', 'final'): 4,
#          ('directive', 'on'): 4,
#          ('policy', 'of'): 4,
#          ('security', 'of'): 4,
#          ('so', 'it'): 4,
#          ('each', 'member'): 4,
#          ('come', 'from'): 4,
#          ('decided', 'against'): 4,
#          ('the', 'various'): 4,
#          ('not', 'been'): 4,
#          ('that', 'a'): 4,
#          ('soulier', 'on'): 4,
#          ('resolution', 'on'): 4,
#          ('parts', 'of'): 4,
#          ('air', 'transport'): 4,
#          ('would', 'ask'): 4,
#          ('when', 'we'): 4,
#          ('to', 'know'): 4,
#          ('<s>', 'they'): 4,
#          ('they', 'do'): 4,
#          ('of', 'new'): 4,
#          ('new', 'nuclear'): 4,
#          ('<s>', 'these'): 4,
#          ('issue', 'of'): 4,
#          ('this', 'point'): 4,
#          ('principles', 'of'): 4,
#          ('to', 'a'): 4,
#          ('i', 'therefore'): 4,
#          ('and', 'must'): 4,
#          ('also', 'the'): 4,
#          ('to', 'guarantee'): 4,
#          ('that', 'are'): 4,
#          ('the', 'normal'): 4,
#          ('not', 'know'): 4,
#          ('you', 'say'): 4,
#          ('you', 'are'): 4,
#          ('waste', 'disposal'): 4,
#          ('put', 'the'): 4,
#          ('gentlemen', 'i'): 4,
#          ('the', 'issue'): 4,
#          ('carried', 'out'): 4,
#          ('agree', 'to'): 4,
#          ('the', 'one'): 4,
#          ('to', 'agree'): 4,
#          ('soulier', '<e>'): 4,
#          ('an', 'important'): 4,
#          ('all', 'we'): 4,
#          ('countries', '<e>'): 4,
#          ('UNK', 'with'): 4,
#          ('to', 'refer'): 4,
#          ('throughout', 'the'): 4,
#          ('ask', 'you'): 4,
#          ('can', 'to'): 4,
#          ('should', 'therefore'): 4,
#          ('the', 'commissioner'): 4,
#          ('<s>', 'nor'): 4,
#          ('years', 'ago'): 4,
#          ('all', 'of'): 4,
#          ('calls', 'for'): 4,
#          ('here', 'we'): 4,
#          ('to', 'keep'): 4,
#          ('which', 'will'): 4,
#          ('for', 'all'): 4,
#          ('the', 'real'): 4,
#          ('responsible', 'for'): 4,
#          ('those', 'who'): 4,
#          ('to', 'use'): 4,
#          ('are', 'also'): 4,
#          ('it', 'will'): 4,
#          ('are', 'a'): 4,
#          ('the', 'cost'): 4,
#          ('legal', 'base'): 4,
#          ('paper', 'is'): 4,
#          ('must', 'say'): 4,
#          ('interests', '<e>'): 4,
#          ('third', 'countries'): 4,
#          ('commission', 'has'): 4,
#          ('an', 'area'): 4,
#          ('i', 'read'): 4,
#          ('concerned', '<e>'): 4,
#          ('find', 'that'): 4,
#          ('the', 'potential'): 4,
#          ('what', 'has'): 4,
#          ('money', 'is'): 4,
#          ('make', 'the'): 4,
#          ('a', 'future'): 4,
#          ('to', 'try'): 4,
#          ('try', 'to'): 4,
#          ('energy', 'for'): 4,
#          ('issue', '<e>'): 4,
#          ('share', 'of'): 4,
#          ('sources', 'as'): 4,
#          ('so', 'far'): 4,
#          ('progress', 'in'): 4,
#          ('possibility', 'of'): 4,
#          ('the', 'communitys'): 4,
#          ('of', 'military'): 4,
#          ('industry', 'to'): 4,
#          ('a', 'policy'): 4,
#          ('under', 'the'): 4,
#          ('that', 'not'): 4,
#          ('the', 'specific'): 4,
#          ('for', 'which'): 4,
#          ('at', '12'): 4,
#          ('12', 'noon'): 4,
#          ('community', 'strategy'): 4,
#          ('into', 'a'): 4,
#          ('sources', 'are'): 4,
#          ('development', '<e>'): 4,
#          ('analysis', 'of'): 4,
#          ('see', 'the'): 4,
#          ('paper', '<e>'): 4,
#          ('be', 'given'): 4,
#          ('the', 'us'): 4,
#          ('the', 'great'): 4,
#          ('as', 'an'): 4,
#          ('a', 'better'): 4,
#          ('here', 'and'): 4,
#          ('the', '21st'): 4,
#          ('21st', 'century'): 4,
#          ('at', 'UNK'): 4,
#          ('to', 'mrs'): 4,
#          ('the', 'political'): 4,
#          ('would', 'give'): 4,
#          ('give', 'us'): 4,
#          ('on', 'which'): 4,
#          ('ensure', 'that'): 4,
#          ('the', 'amendment'): 4,
#          ('this', 'way'): 4,
#          ('then', 'we'): 4,
#          ('procedure', '<e>'): 4,
#          ('votes', '<e>'): 4,
#          ('who', 'are'): 4,
#          ('suggest', 'that'): 4,
#          ('this', 'was'): 4,
#          ('committee', '<e>'): 4,
#          ('we', 'voted'): 4,
#          ('proposal', 'for'): 4,
#          ('voting', '<e>'): 4,
#          ('voted', 'upon'): 4,
#          ('security', 'policy'): 4,
#          ('the', 'motion'): 4,
#          ('motion', 'for'): 4,
#          ('a', 'resolution'): 4,
#          ('the', 'rights'): 4,
#          ('next', 'item'): 3,
#          ('item', 'is'): 3,
#          ('plenary', 'session'): 3,
#          ('days', '<e>'): 3,
#          ('earthquake', 'in'): 3,
#          ('which', 'at'): 3,
#          ('where', 'the'): 3,
#          ('is', 'now'): 3,
#          ('all', 'these'): 3,
#          ('expressions', 'of'): 3,
#          ('is', 'more'): 3,
#          ('a', 'tragedy'): 3,
#          ('was', 'the'): 3,
#          ('among', 'the'): 3,
#          ('congratulations', 'to'): 3,
#          ('our', 'fellow'): 3,
#          ('parliament', 'adopted'): 3,
#          ('continue', 'to'): 3,
#          ('to', 'change'): 3,
#          ('to', 'begin'): 3,
#          ('made', 'by'): 3,
#          ('pursuant', 'to'): 3,
#          ('to', 'rule'): 3,
#          ('brussels', 'and'): 3,
#          ('the', 'belgian'): 3,
#          ('the', 'situation'): 3,
#          ('very', 'well'): 3,
#          ('well', '<e>'): 3,
#          ('to', 'create'): 3,
#          ('the', 'central'): 3,
#          ('this', 'matter'): 3,
#          ('few', 'days'): 3,
#          ('to', 'tell'): 3,
#          ('hard', 'to'): 3,
#          ('other', 'european'): 3,
#          ('us', 'all'): 3,
#          ('approval', 'of'): 3,
#          ('i', 'refer'): 3,
#          ('mr', 'titley'): 3,
#          ('is', 'in'): 3,
#          ('a', 'statement'): 3,
#          ('is', 'entirely'): 3,
#          ('untrue', '<e>'): 3,
#          ('report', 'on'): 3,
#          ('be', 'made'): 3,
#          ('many', 'of'): 3,
#          ('<s>', 'she'): 3,
#          ('said', 'that'): 3,
#          ('therefore', 'i'): 3,
#          ('the', 'free'): 3,
#          ('nuclear', 'industries'): 3,
#          ('UNK', 'on'): 3,
#          ('on', 'research'): 3,
#          ('nuclear', 'programme'): 3,
#          ('UNK', 'UNK'): 3,
#          ('remind', 'you'): 3,
#          ('was', 'not'): 3,
#          ('do', 'this'): 3,
#          ('the', 'support'): 3,
#          ('problems', '<e>'): 3,
#          ('union', 'as'): 3,
#          ('unions', 'energy'): 3,
#          ('to', 'what'): 3,
#          ('what', 'was'): 3,
#          ('is', 'still'): 3,
#          ('really', 'think'): 3,
#          ('a', 'time'): 3,
#          ('us', '<e>'): 3,
#          ('industrial', 'policy'): 3,
#          ('report', 'i'): 3,
#          ('that', 'my'): 3,
#          ('about', 'a'): 3,
#          ('for', 'two'): 3,
#          ('<s>', 'first'): 3,
#          ('power', 'and'): 3,
#          ('that', 'their'): 3,
#          ('respected', '<e>'): 3,
#          ('to', 'extend'): 3,
#          ('from', 'that'): 3,
#          ('to', 'mention'): 3,
#          ('the', 'following'): 3,
#          ('europe', 'is'): 3,
#          ('for', 'its'): 3,
#          ('energies', '<e>'): 3,
#          ('to', 'enable'): 3,
#          ('what', 'we'): 3,
#          ('from', 'nuclear'): 3,
#          ('answer', 'to'): 3,
#          ('to', 'that'): 3,
#          ('people', 'in'): 3,
#          ('although', 'i'): 3,
#          ('money', 'on'): 3,
#          ('on', 'it'): 3,
#          ('put', 'an'): 3,
#          ('an', 'end'): 3,
#          ('end', 'to'): 3,
#          ('european', 'nuclear'): 3,
#          ('and', 'then'): 3,
#          ('technology', 'which'): 3,
#          ('to', 'eliminate'): 3,
#          ('for', 'europe'): 3,
#          ('of', 'an'): 3,
#          ('this', 'time'): 3,
#          ('for', 'them'): 3,
#          ('say', 'in'): 3,
#          ('would', 'save'): 3,
#          ('a', 'bit'): 3,
#          ('for', 'me'): 3,
#          ('the', 'previous'): 3,
#          ('energy', 'committee'): 3,
#          ('environment', 'committees'): 3,
#          ('however', 'i'): 3,
#          ('in', 'plenary'): 3,
#          ('are', 'in'): 3,
#          ('can', 'have'): 3,
#          ('to', 'accept'): 3,
#          ('the', 'choice'): 3,
#          ('matter', 'for'): 3,
#          ('individual', 'countries'): 3,
#          ('and', 'safety'): 3,
#          ('the', 'environmental'): 3,
#          ('including', 'the'): 3,
#          ('storage', 'of'): 3,
#          ('maastricht', 'treaty'): 3,
#          ('soulier', 'is'): 3,
#          ('union', 'to'): 3,
#          ('of', 'safety'): 3,
#          ('safety', 'in'): 3,
#          ('improve', 'the'): 3,
#          ('and', 'not'): 3,
#          ('ones', '<e>'): 3,
#          ('to', 'invest'): 3,
#          ('eu', '<e>'): 3,
#          ('efforts', 'should'): 3,
#          ('other', 'words'): 3,
#          ('have', 'tried'): 3,
#          ('but', 'you'): 3,
#          ('that', 'on'): 3,
#          ('in', 'western'): 3,
#          ('western', 'europe'): 3,
#          ('had', 'a'): 3,
#          ('of', 'us'): 3,
#          ('beginning', 'to'): 3,
#          ('that', 'time'): 3,
#          ('not', '<e>'): 3,
#          ('production', 'and'): 3,
#          ('in', 'an'): 3,
#          ('indicative', 'programme'): 3,
#          ('programme', '<e>'): 3,
#          ('they', 'were'): 3,
#          ('to', 'my'): 3,
#          ('france', 'and'): 3,
#          ('why', 'not'): 3,
#          ('costs', 'of'): 3,
#          ('will', 'not'): 3,
#          ('support', '<e>'): 3,
#          ('will', 'vote'): 3,
#          ('vote', 'against'): 3,
#          ('i', 'understand'): 3,
#          ('shows', 'that'): 3,
#          ('the', 'main'): 3,
#          ('power', 'has'): 3,
#          ('the', 'proportion'): 3,
#          ('proportion', 'of'): 3,
#          ('other', 'forms'): 3,
#          ('means', 'of'): 3,
#          ('advantage', 'of'): 3,
#          ('it', 'does'): 3,
#          ('to', 'achieve'): 3,
#          ('power', 'or'): 3,
#          ('whether', 'it'): 3,
#          ('that', 'those'): 3,
#          ('use', 'nuclear'): 3,
#          ('safety', '<e>'): 3,
#          ('view', 'the'): 3,
#          ('the', 'cis'): 3,
#          ('nuclear', 'safety'): 3,
#          ('away', 'from'): 3,
#          ('nuclear', 'research'): 3,
#          ('final', 'storage'): 3,
#          ('reducing', 'the'): 3,
#          ('the', 'radioactivity'): 3,
#          ('report', 'which'): 3,
#          ('union', 'and'): 3,
#          ('supply', 'and'): 3,
#          ('protection', 'of'): 3,
#          ('believe', 'it'): 3,
#          ('free', 'to'): 3,
#          ('i', 'myself'): 3,
#          ('a', 'country'): 3,
#          ('matter', 'of'): 3,
#          ('may', 'have'): 3,
#          ('take', 'a'): 3,
#          ('in', 'conclusion'): 3,
#          ('president', 'the'): 3,
#          ('the', 'citizens'): 3,
#          ('of', 'europe'): 3,
#          ('we', 'agree'): 3,
#          ('great', 'deal'): 3,
#          ('to', 'strengthen'): 3,
#          ('states', 'of'): 3,
#          ('commissioner', '<e>'): 3,
#          ('the', 'liberal'): 3,
#          ('liberal', 'group'): 3,
#          ('on', 'his'): 3,
#          ('subject', 'and'): 3,
#          ('group', 'has'): 3,
#          ('has', 'no'): 3,
#          ('station', 'is'): 3,
#          ('it', 'seems'): 3,
#          ('transport', 'of'): 3,
#          ('involved', 'in'): 3,
#          ('transport', '<e>'): 3,
#          ('but', 'they'): 3,
#          ('there', 'can'): 3,
#          ('be', 'no'): 3,
#          ('the', 'market'): 3,
#          ('market', 'for'): 3,
#          ('group', 'will'): 3,
#          ('export', 'of'): 3,
#          ('offers', 'a'): 3,
#          ('commission', 'communication'): 3,
#          ('a', 'balanced'): 3,
#          ('makes', 'a'): 3,
#          ('the', 'very'): 3,
#          ('or', 'UNK'): 3,
#          ('UNK', 'reactors'): 3,
#          ('welcome', 'the'): 3,
#          ('in', 'committee'): 3,
#          ('group', 'of'): 3,
#          ('the', 'directive'): 3,
#          ('my', 'view'): 3,
#          ('energy', 'market'): 3,
#          ('the', 'principles'): 3,
#          ('of', 'free'): 3,
#          ('social', 'and'): 3,
#          ('of', 'research'): 3,
#          ('view', 'to'): 3,
#          ('supporting', 'the'): 3,
#          ('report', 'drafted'): 3,
#          ('drafted', 'by'): 3,
#          ('in', 'no'): 3,
#          ('have', 'no'): 3,
#          ('that', 'countries'): 3,
#          ('not', 'want'): 3,
#          ('and', 'economic'): 3,
#          ('have', 'already'): 3,
#          ('are', 'now'): 3,
#          ('programme', 'for'): 3,
#          ('i', 'wonder'): 3,
#          ('from', 'UNK'): 3,
#          ('15', 'of'): 3,
#          ('been', 'made'): 3,
#          ('<s>', 'surely'): 3,
#          ('when', 'i'): 3,
#          ('disposal', '<e>'): 3,
#          ('not', 'even'): 3,
#          ('the', 'longterm'): 3,
#          ('world', 'and'): 3,
#          ('safe', 'and'): 3,
#          ('it', 'says'): 3,
#          ('whereas', 'the'): 3,
#          ('co2', 'emissions'): 3,
#          ('is', 'simply'): 3,
#          ('not', 'produce'): 3,
#          ('but', 'the'): 3,
#          ('what', 'are'): 3,
#          ('and', 'there'): 3,
#          ('vote', 'for'): 3,
#          ('nuclear', 'technology'): 3,
#          ('costs', '<e>'): 3,
#          ('to', 'look'): 3,
#          ('industry', 'as'): 3,
#          ('my', 'own'): 3,
#          ('out', 'of'): 3,
#          ('of', 'it'): 3,
#          ('a', 'long'): 3,
#          ('nuclear', 'fuel'): 3,
#          ('used', 'in'): 3,
#          ('this', 'chamber'): 3,
#          ('out', 'that'): 3,
#          ('an', 'objective'): 3,
#          ('expect', 'a'): 3,
#          ('points', 'of'): 3,
#          ('ago', '<e>'): 3,
#          ('to', 'point'): 3,
#          ('role', 'in'): 3,
#          ('economic', 'development'): 3,
#          ('even', 'in'): 3,
#          ('long', 'term'): 3,
#          ('the', 'renewable'): 3,
#          ('gas', '<e>'): 3,
#          ('what', 'will'): 3,
#          ('will', 'happen'): 3,
#          ('to', 'increase'): 3,
#          ('secondly', 'we'): 3,
#          ('are', 'really'): 3,
#          ('will', 'make'): 3,
#          ('to', 'add'): 3,
#          ('especially', 'in'): 3,
#          ('developing', 'countries'): 3,
#          ('soulier', 'report'): 3,
#          ('problem', 'of'): 3,
#          ('the', 'treatment'): 3,
#          ('disposal', 'of'): 3,
#          ('so', 'much'): 3,
#          ('currently', 'being'): 3,
#          ('work', '<e>'): 3,
#          ('do', 'all'): 3,
#          ('you', 'can'): 3,
#          ('public', 'health'): 3,
#          ('talking', 'about'): 3,
#          ('people', 'are'): 3,
#          ('the', 'management'): 3,
#          ('management', 'of'): 3,
#          ('industry', 'which'): 3,
#          ('reduce', 'the'): 3,
#          ('on', 'these'): 3,
#          ('to', 'pursue'): 3,
#          ('the', 'end'): 3,
#          ('it', 'quite'): 3,
#          ('important', 'to'): 3,
#          ('these', 'points'): 3,
#          ('price', 'will'): 3,
#          ('will', 'remain'): 3,
#          ('remain', 'a'): 3,
#          ('long', 'as'): 3,
#          ('which', 'means'): 3,
#          ('as', 'that'): 3,
#          ('is', 'it'): 3,
#          ('a', 'different'): 3,
#          ('to', 'offer'): 3,
#          ('is', 'produced'): 3,
#          ('it', 'makes'): 3,
#          ('point', '<e>'): 3,
#          ('our', 'knowledge'): 3,
#          ('knowledge', 'to'): 3,
#          ('a', 'sense'): 3,
#          ('<s>', 'no'): 3,
#          ('as', 'in'): 3,
#          ('president', 'in'): 3,
#          ('said', 'no'): 3,
#          ('we', 'now'): 3,
#          ('has', 'the'): 3,
#          ('its', 'nuclear'): 3,
#          ('i', 'agree'): 3,
#          ('measures', '<e>'): 3,
#          ('a', 'political'): 3,
#          ('question', '<e>'): 3,
#          ('commissions', 'green'): 3,
#          ('only', 'one'): 3,
#          ('i', 'will'): 3,
#          ('unit', '1'): 3,
#          ('my', 'question'): 3,
#          ('<s>', 'despite'): 3,
#          ('all', 'this'): 3,
#          ('the', 'frontiers'): 3,
#          ('the', 'country'): 3,
#          ('the', 'point'): 3,
#          ('is', 'totally'): 3,
#          ('the', 'people'): 3,
#          ('a', 'point'): 3,
#          ('wants', 'to'): 3,
#          ('<s>', 'after'): 3,
#          ('sources', 'can'): 3,
#          ('energy', 'saving'): 3,
#          ('that', 'UNK'): 3,
#          ('you', 'a'): 3,
#          ('really', 'are'): 3,
#          ('also', 'to'): 3,
#          ('our', 'own'): 3,
#          ('thank', 'the'): 3,
#          ('the', 'members'): 3,
#          ('in', 'parliament'): 3,
#          ('however', 'that'): 3,
#          ('will', 'take'): 3,
#          ('account', 'the'): 3,
#          ('of', 'your'): 3,
#          ('support', 'for'): 3,
#          ('you', 'know'): 3,
#          ('it', 'possible'): 3,
#          ('possible', 'to'): 3,
#          ('the', 'particular'): 3,
#          ('energy', 'source'): 3,
#          ('that', 'way'): 3,
#          ('a', 'significant'): 3,
#          ('the', 'production'): 3,
#          ('far', 'as'): 3,
#          ('sector', 'and'): 3,
#          ('are', 'aware'): 3,
#          ('concerned', 'about'): 3,
#          ('to', 'contribute'): 3,
#          ('contribute', 'towards'): 3,
#          ('cooperation', 'with'): 3,
#          ('be', 'to'): 3,
#          ('however', 'the'): 3,
#          ('mainly', 'to'): 3,
#          ('recall', 'that'): 3,
#          ('packaging', 'and'): 3,
#          ('radioactive', 'wastes'): 3,
#          ('of', 'action'): 3,
#          ('at', 'european'): 3,
#          ('the', 'possibility'): 3,
#          ('undertaken', 'by'): 3,
#          ('of', 'community'): 3,
#          ('now', 'and'): 3,
#          ('for', 'research'): 3,
#          ('along', 'those'): 3,
#          ('those', 'lines'): 3,
#          ('europe', 'should'): 3,
#          ('rothe', 'on'): 3,
#          ('commissioner', 'let'): 3,
#          ('to', 'you'): 3,
#          ('me', 'that'): 3,
#          ('be', 'said'): 3,
#          ('that', 'as'): 3,
#          ('market', '<e>'): 3,
#          ('this', 'has'): 3,
#          ('industry', 'is'): 3,
#          ('those', 'for'): 3,
#          ('noon', '<e>'): 3,
#          ('<s>', 'renewable'): 3,
#          ('the', 'resolution'): 3,
#          ('strategy', '<e>'): 3,
#          ('energy', 'consumption'): 3,
#          ('to', 'set'): 3,
#          ('paper', 'to'): 3,
#          ('of', 'measures'): 3,
#          ('for', 'energy'): 3,
#          ('energy', 'from'): 3,
#          ('very', 'difficult'): 3,
#          ('biomass', 'to'): 3,
#          ('why', 'we'): 3,
#          ('with', 'renewable'): 3,
#          ('this', 'will'): 3,
#          ('given', 'to'): 3,
#          ('we', 'think'): 3,
#          ('the', 'appropriate'): 3,
#          ('a', 'situation'): 3,
#          ('situation', 'where'): 3,
#          ('where', 'we'): 3,
#          ('allocated', 'to'): 3,
#          ('resources', '<e>'): 3,
#          ('appropriations', 'for'): 3,
#          ('done', 'in'): 3,
#          ('president', 'commissioner'): 3,
#          ('sector', '<e>'): 3,
#          ('on', 'her'): 3,
#          ('her', 'report'): 3,
#          ('areas', '<e>'): 3,
#          ('<s>', 'biomass'): 3,
#          ('in', 'future'): 3,
#          ('policy', 'in'): 3,
#          ('the', 'analysis'): 3,
#          ('the', 'money'): 3,
#          ('peace', 'in'): 3,
#          ('system', '<e>'): 3,
#          ('will', 'have'): 3,
#          ('an', 'excellent'): 3,
#          ('mrs', 'rothes'): 3,
#          ('rothes', 'report'): 3,
#          ('rothe', 'for'): 3,
#          ('for', 'an'): 3,
#          ('mr', 'robles'): 3,
#          ('robles', 'piquer'): 3,
#          ('our', 'member'): 3,
#          ('a', 'legal'): 3,
#          ('sort', 'of'): 3,
#          ('have', 'done'): 3,
#          ('that', 'renewable'): 3,
#          ('amendment', 'no'): 3,
#          ('we', 'shall'): 3,
#          ('along', 'with'): 3,
#          ('nature', 'of'): 3,
#          ('instead', 'of'): 3,
#          ('report', 'with'): 3,
#          ('cooperation', '<e>'): 3,
#          ('union', 'should'): 3,
#          ('and', 'would'): 3,
#          ('with', 'you'): 3,
#          ('etc', '<e>'): 3,
#          ('is', 'spent'): 3,
#          ('spent', 'on'): 3,
#          ('at', 'last'): 3,
#          ('you', 'will'): 3,
#          ('has', 'come'): 3,
#          ('quite', 'clear'): 3,
#          ('whole', 'of'): 3,
#          ('and', 'should'): 3,
#          ('or', 'the'): 3,
#          ('it', 'must'): 3,
#          ('house', 'is'): 3,
#          ('adopted', 'the'): 3,
#          ('mrs', 'UNK'): 3,
#          ('<s>', 'since'): 3,
#          ('one', 'speaker'): 3,
#          ('of', 'people'): 3,
#          ('i', 'suggest'): 3,
#          ('the', 'socialist'): 3,
#          ('amendments', '<e>'): 3,
#          ('rapporteur', 'i'): 3,
#          ('the', 'votes'): 3,
#          ('votes', 'together'): 3,
#          ('the', 'text'): 3,
#          ('text', 'on'): 3,
#          ('which', 'there'): 3,
#          ('a', 'rollcall'): 3,
#          ('proposal', 'and'): 3,
#          ('of', 'order'): 3,
#          ('to', 'committee'): 3,
#          ('the', 'proposal'): 3,
#          ('the', 'block'): 3,
#          ('system', 'of'): 3,
#          ('<s>', 'perhaps'): 3,
#          ('the', 'groups'): 3,
#          ('on', 'and'): 3,
#          ('if', 'you'): 3,
#          ('order', '<e>'): 3,
#          ('normal', 'way'): 3,
#          ('our', 'voting'): 3,
#          ('way', 'in'): 3,
#          ('me', '<e>'): 3,
#          ('wanted', 'to'): 3,
#          ('rules', 'and'): 3,
#          ('this', 'text'): 3,
#          ('<s>', 'UNK'): 3,
#          ('mistake', '<e>'): 3,
#          ('rejected', 'the'): 3,
#          ('respect', 'for'): 3,
#          ('crampton', 'report'): 3,
#          ('agreements', 'with'): 3,
#          ('these', 'agreements'): 3,
#          ('weapons', 'industry'): 3,
#          ('produced', 'by'): 3,
#          ('a', 'nonaligned'): 3,
#          ('state', 'and'): 3,
#          ('common', 'defence'): 3,
#          ('and', 'defence'): 3,
#          ('and', 'security'): 3,
#          ('common', 'european'): 3,
#          ('would', 'only'): 3,
#          ('set', 'up'): 3,
#          ('the', 'balkans'): 3,
#          ('of', 'former'): 3,
#          ('former', 'yugoslavia'): 3,
#          ('the', 'decision'): 3,
#          ('to', 'impose'): 3,
#          ('UNK', 'for'): 3,
#          ('rights', 'or'): 3,
#          ('or', 'wrongs'): 3,
#          ('wrongs', 'of'): 3,
#          ('the', 'luxembourg'): 3,
#          ('the', 'results'): 2,
#          ('results', 'and'): 2,
#          ('say', 'at'): 2,
#          ('session', '<e>'): 2,
#          ('to', 'inform'): 2,
#          ('inform', 'you'): 2,
#          ('you', 'of'): 2,
#          ('there', 'was'): 2,
#          ('was', 'an'): 2,
#          ('an', 'earthquake'): 2,
#          ('in', 'turkey'): 2,
#          ('died', '<e>'): 2,
#          ('last', 'week'): 2,
#          ('was', 'also'): 2,
#          ('of', 'over'): 2,
#          ('not', 'forget'): 2,
#          ('000', 'people'): 2,
#          ('people', '<e>'): 2,
#          ('<s>', 'every'): 2,
#          ('tragedy', 'for'): 2,
#          ('the', 'families'): 2,
#          ('whole', 'world'): 2,
#          ('of', 'solidarity'): 2,
#          ('11', 'march'): 2,
#          ('march', 'marks'): 2,
#          ('marks', 'the'): 2,
#          ('the', '20th'): 2,
#          ('anniversary', 'of'): 2,
#          ('independence', '<e>'): 2,
#          ('to', 'declare'): 2,
#          ('independence', 'from'): 2,
#          ('<s>', 'among'): 2,
#          ('declaration', 'of'): 2,
#          ('fellow', 'members'): 2,
#          ('members', 'from'): 2,
#          ('50', 'years'): 2,
#          ('years', 'of'): 2,
#          ('also', 'congratulate'): 2,
#          ('to', 'hope'): 2,
#          ('hope', 'and'): 2,
#          ('appeal', 'to'): 2,
#          ('authorities', 'of'): 2,
#          ('representatives', '<e>'): 2,
#          ('mr', 'farage'): 2,
#          ('have', 'spoken'): 2,
#          ('to', 'mr'): 2,
#          ('and', 'have'): 2,
#          ('have', 'decided'): 2,
#          ('period', 'of'): 2,
#          ('applause', 'i'): 2,
#          ('something', 'else'): 2,
#          ('the', 'theft'): 2,
#          ('a', 'member'): 2,
#          ('<s>', 'our'): 2,
#          ('as', 'UNK'): 2,
#          ('in', 'these'): 2,
#          ('in', 'belgium'): 2,
#          ('create', 'a'): 2,
#          ('a', 'special'): 2,
#          ('the', 'premises'): 2,
#          ('premises', 'of'): 2,
#          ('be', 'provided'): 2,
#          ('under', 'way'): 2,
#          ('next', 'few'): 2,
#          ('tell', 'you'): 2,
#          ('very', 'hard'): 2,
#          ('this', 'as'): 2,
#          ('concerns', 'us'): 2,
#          ('<s>', 'approval'): 2,
#          ('minutes', 'the'): 2,
#          ('<s>', 'are'): 2,
#          ('a', 'personal'): 2,
#          ('following', 'the'): 2,
#          ('a', 'lobbyist'): 2,
#          ('lobbyist', 'for'): 2,
#          ('for', 'what'): 2,
#          ('call', 'the'): 2,
#          ('merchants', 'of'): 2,
#          ('of', 'death'): 2,
#          ('in', 'line'): 2,
#          ('line', 'with'): 2,
#          ('entirely', 'untrue'): 2,
#          ('not', 'in'): 2,
#          ('interests', 'of'): 2,
#          ('when', 'debating'): 2,
#          ('debating', 'the'): 2,
#          ('this', 'nature'): 2,
#          ('and', 'as'): 2,
#          ('of', 'them'): 2,
#          ('should', 'contribute'): 2,
#          ('contribute', 'to'): 2,
#          ('UNK', 'a'): 2,
#          ('were', 'in'): 2,
#          ('<s>', 'therefore'): 2,
#          ('it', 'clear'): 2,
#          ('that', 'these'): 2,
#          ('these', 'statements'): 2,
#          ('certain', 'number'): 2,
#          ('of', 'goods'): 2,
#          ('to', 'remind'): 2,
#          ('ensure', 'the'): 2,
#          ('free', 'circulation'): 2,
#          ('circulation', 'of'): 2,
#          ('goods', '<e>'): 2,
#          ('unfortunately', 'we'): 2,
#          ('time', 'in'): 2,
#          ('years', 'and'): 2,
#          ('all', 'ought'): 2,
#          ('national', 'authorities'): 2,
#          ('authorities', 'should'): 2,
#          ('movement', 'of'): 2,
#          ('from', 'other'): 2,
#          ('countries', 'who'): 2,
#          ('come', 'into'): 2,
#          ('industries', 'the'): 2,
#          ('energy', 'on'): 2,
#          ('illustrative', 'nuclear'): 2,
#          ('article', '40'): 2,
#          ('40', 'of'): 2,
#          ('debate', 'is'): 2,
#          ('commission', 'was'): 2,
#          ('bound', 'by'): 2,
#          ('of', 'article'): 2,
#          ('treaty', 'to'): 2,
#          ('to', 'consult'): 2,
#          ('consult', 'the'): 2,
#          ('<s>', 'apart'): 2,
#          ('have', 'shown'): 2,
#          ('parliament', 'i'): 2,
#          ('you', 'commissioner'): 2,
#          ('commissioner', 'that'): 2,
#          ('you', 'were'): 2,
#          ('were', 'right'): 2,
#          ('to', 'energy'): 2,
#          ('see', 'that'): 2,
#          ('last', '40'): 2,
#          ('years', 'nuclear'): 2,
# ...
#          ('until', '1994'): 1,
#          ('1994', 'the'): 1,
#          ('the', 'far'): 1,
#          ('for', 'taking'): 1,
#          ('taking', 'the'): 1,
#          ('camps', 'hostage'): 1,
#          ('hostage', 'the'): 1,
#          ('french', 'government'): 1,
#          ('the', 'execution'): 1,
#          ('execution', 'and'): 1,
#          ('UNK', 'government'): 1,
#          ('the', 'rear'): 1,
#          ('rear', 'bases'): 1,
#          ('bases', 'launched'): 1,
#          ('launched', 'together'): 1,
#          ('together', 'in'): 1,
#          ('the', 'famous'): 1,
#          ('famous', 'operation'): 1,
#          ('operation', 'UNK'): 1,
#          ('really', 'responsible'): 1,
#          ('refugees', 'over'): 1,
#          ('last', 'two'): 1,
#          ('two', 'and'): 1,
#          ('a', 'half'): 1,
#          ('half', 'years'): 1,
#          ('years', 'the'): 1,
#          ('new', 'authorities'): 1,
#          ('in', 'kigali'): 1,
#          ('kigali', 'repeated'): 1,
#          ('repeated', 'to'): 1,
#          ('to', 'deaf'): 1,
#          ('deaf', 'ears'): 1,
#          ('ears', 'that'): 1,
#          ('camps', 'in'): 1,
#          ('eastern', 'zaire'): 1,
#          ('zaire', 'were'): 1,
#          ('were', 'a'): 1,
#          ('a', 'threat'): 1,
#          ('the', 'security'): 1,
#          ('their', 'state'): 1,
#          ('a', 'timebomb'): 1,
#          ('timebomb', 'for'): 1,
#          ('central', 'africa'): 1,
#          ('africa', '<e>'): 1,
#          ('noone', 'ever'): 1,
#          ('ever', 'listened'): 1,
#          ('listened', 'to'): 1,
#          ('these', 'warnings'): 1,
#          ('warnings', 'which'): 1,
#          ('which', 'were'): 1,
#          ('were', 'full'): 1,
#          ('sense', 'and'): 1,
#          ('and', 'realism'): 1,
#          ('realism', '<e>'): 1,
#          ('what', 'happened'): 1,
#          ('happened', 'next'): 1,
#          ('next', '<e>'): 1,
#          ('today', 'the'): 1,
#          ('the', 'record'): 1,
#          ('record', 'of'): 1,
#          ('we', 'entrusted'): 1,
#          ('entrusted', 'our'): 1,
#          ('our', 'common'): 1,
#          ('common', 'diplomacy'): 1,
#          ('diplomacy', 'to'): 1,
#          ('to', 'two'): 1,
#          ('two', 'member'): 1,
#          ('states', 'france'): 1,
#          ('and', 'belgium'): 1,
#          ('belgium', 'the'): 1,
#          ('union', 'was'): 1,
#          ('was', 'committed'): 1,
#          ('committed', 'to'): 1,
#          ('of', 'blindness'): 1,
#          ('blindness', 'to'): 1,
#          ('to', 'supporting'): 1,
#          ('supporting', 'mobutu'): 1,
#          ('mobutu', 'who'): 1,
#          ('was', 'held'): 1,
#          ('held', 'up'): 1,
#          ('up', 'as'): 1,
#          ('a', 'guarantor'): 1,
#          ('guarantor', 'of'): 1,
#          ('of', 'stability'): 1,
#          ('stability', 'and'): 1,
#          ('and', 'territorial'): 1,
#          ('territorial', 'integrity'): 1,
#          ('integrity', 'in'): 1,
#          ('in', 'zaire'): 1,
#          ('zaire', '<e>'): 1,
#          ('despite', 'the'): 1,
#          ('the', 'realism'): 1,
#          ('realism', 'of'): 1,
#          ('states', 'external'): 1,
#          ('external', 'policy'): 1,
#          ('policy', 'european'): 1,
#          ('european', 'influence'): 1,
#          ('influence', 'is'): 1,
#          ('being', 'completely'): 1,
#          ('completely', 'wiped'): 1,
#          ('huge', 'area'): 1,
#          ('area', 'stretching'): 1,
#          ('stretching', 'from'): 1,
#          ('the', 'southern'): 1,
#          ('southern', 'sudan'): 1,
#          ('sudan', 'to'): 1,
#          ('the', 'atlantic'): 1,
#          ('atlantic', '<e>'): 1,
#          ('zaire', 'reveals'): 1,
#          ('reveals', 'the'): 1,
#          ('the', 'complete'): 1,
#          ('complete', 'and'): 1,
#          ('and', 'utter'): 1,
#          ('utter', 'failure'): 1,
#          ('failure', 'of'): 1,
#          ('european', 'diplomacy'): 1,
#          ('diplomacy', 'which'): 1,
#          ('been', 'conspicuous'): 1,
#          ('conspicuous', 'by'): 1,
#          ('by', 'its'): 1,
#          ('its', 'absence'): 1,
#          ('absence', 'in'): 1,
#          ('this', 'crisis'): 1,
#          ('crisis', 'and'): 1,
#          ('its', 'probable'): 1,
#          ('probable', 'settlement'): 1,
#          ('settlement', '<e>'): 1,
#          ('similarly', 'european'): 1,
#          ('european', 'development'): 1,
#          ('development', 'aid'): 1,
#          ('aid', 'policy'): 1,
#          ('has', 'revealed'): 1,
#          ('revealed', 'itself'): 1,
#          ('itself', 'to'): 1,
#          ('be', 'incapable'): 1,
#          ('incapable', 'of'): 1,
#          ('of', 'imposing'): 1,
#          ('imposing', 'as'): 1,
#          ('a', 'condition'): 1,
#          ('condition', 'the'): 1,
#          ('the', 'minimum'): 1,
#          ('minimum', 'degree'): 1,
#          ('degree', 'of'): 1,
#          ('of', 'democracy'): 1,
#          ('democracy', 'which'): 1,
#          ('which', 'might'): 1,
#          ('might', 'have'): 1,
#          ('had', 'some'): 1,
#          ('some', 'effect'): 1,
#          ('effect', 'on'): 1,
#          ('the', 'regions'): 1,
#          ('regions', 'dictatorships'): 1,
#          ('dictatorships', 'nowadays'): 1,
#          ('union', 'wants'): 1,
#          ('impose', 'maximalist'): 1,
#          ('maximalist', 'democratic'): 1,
#          ('democratic', 'conditions'): 1,
#          ('conditions', 'on'): 1,
#          ('new', 'zairean'): 1,
#          ('zairean', 'authority'): 1,
#          ('authority', 'emerging'): 1,
#          ('emerging', 'from'): 1,
#          ('civil', 'war'): 1,
#          ('and', 'having'): 1,
#          ('having', 'to'): 1,
#          ('over', 'a'): 1,
#          ('country', 'devastated'): 1,
#          ('devastated', 'by'): 1,
#          ('by', 'dictatorship'): 1,
#          ('dictatorship', '<e>'): 1,
#          ('this', 'painful'): 1,
#          ('painful', 'affair'): 1,
#          ('affair', 'calls'): 1,
#          ('a', 'farreaching'): 1,
#          ('farreaching', 'review'): 1,
#          ('review', 'of'): 1,
#          ('our', 'diplomacy'): 1,
#          ('diplomacy', 'and'): 1,
#          ('and', 'our'): 1,
#          ('our', 'development'): 1,
#          ('development', 'policy'): 1,
#          ('i', 'only'): 1,
#          ('the', 'crisis'): 1,
#          ('crisis', 'of'): 1,
#          ('great', 'lakes'): 1,
#          ('lakes', 'of'): 1,
#          ('of', 'africa'): 1,
#          ('africa', 'will'): 1,
#          ('be', 'aware'): 1,
#          ('need', '<e>'): 1,
#          ('<s>', 'soulier'): 1,
#          ('first', 'time'): 1,
#          ('has', 'submitted'): 1,
#          ('submitted', 'to'): 1,
#          ('parliament', 'this'): 1,
#          ('this', 'indicative'): 1,
#          ('programme', 'on'): 1,
#          ('only', 'welcome'): 1,
#          ('welcome', 'this'): 1,
#          ('this', 'consultation'): 1,
#          ('consultation', '<e>'): 1,
#          ('not', 'about'): 1,
#          ('about', 'to'): 1,
#          ('to', 'discuss'): 1,
#          ('discuss', 'the'): 1,
#          ('energy', 'industry'): 1,
#          ('individual', 'states'): 1,
#          ('therefore', 'it'): 1,
#          ('of', 'knowing'): 1,
#          ('knowing', 'whether'): 1,
#          ('whether', 'the'): 1,
#          ('energy', 'produced'): 1,
#          ('reactors', 'should'): 1,
#          ('should', 'increase'): 1,
#          ('increase', 'or'): 1,
#          ('or', 'decrease'): 1,
#          ('decrease', '<e>'): 1,
#          ('my', 'consideration'): 1,
#          ('consideration', 'here'): 1,
#          ('here', 'is'): 1,
#          ('its', 'consequences'): 1,
#          ('consequences', 'in'): 1,
#          ('particular', 'for'): 1,
#          ('rapporteur', 'is'): 1,
#          ('is', 'right'): 1,
#          ('to', 'concentrate'): 1,
#          ('concentrate', 'his'): 1,
#          ('his', 'thoughts'): 1,
#          ('thoughts', 'on'): 1,
#          ('<s>', 'nowadays'): 1,
#          ('main', 'challenges'): 1,
#          ('challenges', 'of'): 1,
#          ('industry', 'come'): 1,
#          ('from', 'waste'): 1,
#          ('of', 'structures'): 1,
#          ('structures', '<e>'): 1,
#          ('they', 'call'): 1,
#          ('of', 'increased'): 1,
#          ('increased', 'safety'): 1,
#          ('operation', 'of'): 1,
#          ('particular', 'an'): 1,
#          ('agreement', 'on'): 1,
#          ('the', 'fight'): 1,
#          ('against', 'their'): 1,
#          ('their', 'uncontrolled'): 1,
#          ('uncontrolled', 'transport'): 1,
#          ('transport', 'within'): 1,
#          ('safety', 'imperative'): 1,
#          ('imperative', 'should'): 1,
#          ('limited', 'to'): 1,
#          ('union', 'since'): 1,
#          ('since', 'radioactive'): 1,
#          ('radioactive', 'risks'): 1,
#          ('risks', 'have'): 1,
#          ('have', 'willingly'): 1,
#          ('willingly', 'accepted'): 1,
#          ('accepted', 'the'): 1,
#          ('course', 'important'): 1,
#          ('important', 'work'): 1,
#          ('work', 'has'): 1,
#          ('to', 'countries'): 1,
#          ('finally', 'and'): 1,
#          ('since', 'inevitably'): 1,
#          ('inevitably', 'the'): 1,
#          ('subject', 'tackled'): 1,
#          ('tackled', 'does'): 1,
#          ('does', 'concern'): 1,
#          ('energy', 'i'): 1,
#          ('lend', 'my'): 1,
#          ('principles', 'in'): 1,
#          ('power', 'national'): 1,
#          ('should', 'decide'): 1,
#          ('whether', 'or'): 1,
#          ('power', 'this'): 1,
#          ('choice', 'should'): 1,
#          ('respected', 'by'): 1,
#          ('whole', 'high'): 1,
#          ('high', 'levels'): 1,
#          ('levels', 'of'): 1,
#          ('of', 'security'): 1,
#          ('security', 'should'): 1,
#          ('be', 'guaranteed'): 1,
#          ('guaranteed', 'member'): 1,
#          ('states', 'take'): 1,
#          ('take', 'coresponsibility'): 1,
#          ('coresponsibility', 'with'): 1,
#          ('with', 'those'): 1,
#          ('those', 'running'): 1,
#          ('running', 'nuclear'): 1,
#          ('installations', 'towards'): 1,
#          ('towards', 'european'): 1,
#          ('citizens', 'when'): 1,
#          ('<s>', 'other'): 1,
#          ('other', 'reports'): 1,
#          ('reports', 'will'): 1,
#          ('of', 'various'): 1,
#          ('various', 'different'): 1,
#          ('different', 'types'): 1,
#          ('that', '30'): 1,
#          ('nuclear', 'means'): 1,
#          ('means', 'we'): 1,
#          ('must', 'therefore'): 1,
#          ('therefore', 'take'): 1,
#          ('take', 'any'): 1,
#          ('any', 'measure'): 1,
#          ('measure', 'necessary'): 1,
#          ('guarantee', 'the'): 1,
#          ('i', 'wanted'): 1,
#          ('to', 'explain'): 1,
#          ('explain', 'to'): 1,
#          ('you', 'why'): 1,
#          ('why', 'as'): 1,
#          ('UNK', 'i'): 1,
#          ('which', 'in'): 1,
#          ('the', '1970s'): 1,
#          ('1970s', 'made'): 1,
#          ('a', 'choice'): 1,
#          ('choice', 'the'): 1,
#          ('choice', 'not'): 1,
#          ('single', 'nuclear'): 1,
#          ('station', 'on'): 1,
#          ('the', 'river'): 1,
#          ('river', 'moselle'): 1,
#          ('moselle', '<e>'): 1,
#          ('choice', 'was'): 1,
#          ('was', 'broadly'): 1,
#          ('broadly', 'the'): 1,
#          ('luxembourg', 'socialists'): 1,
#          ('socialists', 'who'): 1,
#          ('who', 'were'): 1,
#          ('in', 'power'): 1,
#          ('years', 'afterwards'): 1,
#          ('afterwards', 'our'): 1,
#          ('our', 'great'): 1,
#          ('great', 'neighbour'): 1,
#          ('neighbour', 'france'): 1,
#          ('france', 'whose'): 1,
#          ('whose', 'nuclear'): 1,
#          ('nuclear', 'options'): 1,
#          ('options', 'are'): 1,
#          ('are', 'well'): 1,
#          ('well', 'known'): 1,
#          ('to', 'everyone'): 1,
#          ('everyone', 'decided'): 1,
#          ('huge', 'nuclear'): 1,
#          ('station', 'at'): 1,
#          ('the', 'border'): 1,
#          ('border', 'with'): 1,
#          ('with', 'luxembourg'): 1,
#          ('luxembourg', 'and'): 1,
#          ('and', 'germany'): 1,
#          ('germany', 'without'): 1,
#          ('without', 'asking'): 1,
#          ('asking', 'anyone'): 1,
#          ('anyone', 'for'): 1,
#          ('their', 'opinion'): 1,
#          ('it', 'took'): 1,
#          ('took', 'years'): 1,
#          ('and', 'years'): 1,
#          ('years', 'toplevel'): 1,
#          ('toplevel', 'state'): 1,
#          ('state', 'visits'): 1,
#          ('visits', 'and'): 1,
#          ('and', 'countless'): 1,
#          ('countless', 'diplomatic'): 1,
#          ('diplomatic', 'interventions'): 1,
#          ('interventions', 'for'): 1,
#          ('french', 'nuclear'): 1,
#          ('to', 'supply'): 1,
#          ('supply', 'information'): 1,
#          ('information', 'albeit'): 1,
#          ('albeit', 'hardly'): 1,
#          ('hardly', 'credible'): 1,
#          ('credible', 'on'): 1,
#          ('the', 'emissions'): 1,
#          ('emissions', 'of'): 1,
#          ('the', 'power'): 1,
#          ('station', 'and'): 1,
#          ('to', 'install'): 1,
#          ('install', 'an'): 1,
#          ('an', 'alarm'): 1,
#          ('alarm', 'system'): 1,
#          ('present', 'another'): 1,
#          ('another', 'nuclear'): 1,
#          ('nuclear', 'state'): 1,
#          ('state', 'belgium'): 1,
#          ('belgium', 'is'): 1,
#          ('is', 'mentioning'): 1,
#          ('mentioning', 'the'): 1,
#          ('storing', 'its'): 1,
#          ('belgian', 'UNK'): 1,
#          ('UNK', 'only'): 1,
#          ('only', 'six'): 1,
#          ('six', 'kilometres'): 1,
#          ('kilometres', 'away'): 1,
#          ('border', 'in'): 1,
#          ('a', 'nature'): 1,
#          ('nature', 'reserve'): 1,
#          ('reserve', 'and'): 1,
#          ('and', 'tourism'): 1,
#          ('tourism', 'area'): 1,
#          ('<s>', 'during'): 1,
#          ('during', 'that'): 1,
#          ('the', 'railway'): 1,
#          ('railway', 'accident'): 1,
#          ('accident', 'at'): 1,
#          ('in', 'lorraine'): 1,
#          ('lorraine', 'very'): 1,
#          ('very', 'close'): 1,
#          ('close', 'to'): 1,
#          ('border', 'revealed'): 1,
#          ('revealed', 'that'): 1,
#          ('that', 'convoys'): 1,
#          ('convoys', 'of'): 1,
#          ('of', 'trains'): 1,
#          ('trains', 'UNK'): 1,
#          ('UNK', 'europe'): 1,
#          ('every', 'direction'): 1,
#          ('direction', 'transporting'): 1,
#          ('transporting', 'nuclear'): 1,
#          ('waste', 'towards'): 1,
#          ('towards', 'reprocessing'): 1,
#          ('reprocessing', 'plants'): 1,
#          ('plants', 'without'): 1,
#          ('without', 'anyones'): 1,
#          ('anyones', 'knowledge'): 1,
#          ('knowledge', 'without'): 1,
#          ('without', 'our'): 1,
#          ('our', 'knowing'): 1,
#          ('knowing', 'what'): 1,
#          ('what', 'safety'): 1,
#          ('measures', 'have'): 1,
#          ('been', 'taken'): 1,
#          ('taken', 'and'): 1,
#          ('what', 'conditions'): 1,
#          ('conditions', 'this'): 1,
#          ('this', 'transportation'): 1,
#          ('transportation', 'takes'): 1,
#          ('takes', 'place'): 1,
#          ('<s>', 'whole'): 1,
#          ('whole', 'communities'): 1,
#          ('communities', 'could'): 1,
#          ('be', 'contaminated'): 1,
#          ('contaminated', 'overnight'): 1,
#          ('overnight', '<e>'): 1,
#          ('therefore', 'against'): 1,
#          ('power', 'practised'): 1,
#          ('practised', 'in'): 1,
#          ('way', 'without'): 1,
#          ('any', 'nuance'): 1,
#          ('nuance', '<e>'): 1,
#          ('go', 'along'): 1,
#          ('the', 'attitude'): 1,
#          ('attitude', 'of'): 1,
#          ('group', 'on'): 1,
#          ('for', 'everything'): 1,
#          ('everything', 'to'): 1,
#          ('in', 'face'): 1,
#          ('face', 'of'): 1,
#          ('the', 'dangers'): 1,
#          ('dangers', 'of'): 1,
#          ('power', 'to'): 1,
#          ('introduce', 'maximum'): 1,
#          ('maximum', 'safety'): 1,
#          ('therefore', 'profoundly'): 1,
#          ('profoundly', 'amend'): 1,
#          ('amend', 'the'): 1,
#          ('treaty', 'the'): 1,
#          ('the', 'relic'): 1,
#          ('relic', 'of'): 1,
#          ('time', 'when'): 1,
#          ('when', 'everyone'): 1,
#          ('everyone', 'was'): 1,
#          ('was', 'full'): 1,
#          ('of', 'admiration'): 1,
#          ('admiration', 'for'): 1,
#          ('guarantee', 'safety'): 1,
#          ('and', 'control'): 1,
#          ('control', 'every'): 1,
#          ('every', 'aspect'): 1})

# %%
trigram_counter = Counter()
sample = corpus_clean_no_OOV[0:1000]
for sent in sample:
    trigram_counter.update([gram for gram in ngrams(sent, 3, pad_left=True, pad_right=True,
                                                   left_pad_symbol='<s>',right_pad_symbol='<e>') ])
pprint(trigram_counter)
# Out:
# Counter({('<s>', '<s>', 'i'): 109,
#          ('<s>', '<s>', 'the'): 87,
#          ('<s>', '<s>', 'it'): 68,
#          ('<s>', '<s>', 'we'): 66,
#          ('<s>', '<s>', 'mr'): 58,
#          ('<s>', 'mr', 'president'): 52,
#          ('<s>', '<s>', 'in'): 42,
#          ('the', 'european', 'union'): 39,
#          ('renewable', 'energy', 'sources'): 38,
#          ('<s>', '<s>', 'that'): 37,
#          ('<s>', 'it', 'is'): 35,
#          ('<s>', '<s>', 'this'): 35,
#          ('energy', '<e>', '<e>'): 32,
#          ('nuclear', 'power', 'stations'): 26,
#          ('of', 'the', 'european'): 25,
#          ('report', '<e>', '<e>'): 24,
#          ('<s>', '<s>', 'if'): 23,
#          ('<s>', '<s>', 'and'): 21,
#          ('<s>', 'that', 'is'): 20,
#          ('<s>', '<s>', 'but'): 20,
#          ('the', 'european', 'parliament'): 19,
#          ('<s>', '<s>', 'there'): 19,
#          ('mr', 'president', 'i'): 18,
#          ('policy', '<e>', '<e>'): 17,
#          ('of', 'nuclear', 'power'): 17,
#          ('of', 'renewable', 'energy'): 17,
#          ('the', 'member', 'states'): 16,
#          ('the', 'use', 'of'): 16,
#          ('<s>', '<s>', 'for'): 15,
#          ('<s>', '<s>', 'as'): 15,
#          ('<s>', '<s>', 'so'): 15,
#          ('<s>', 'i', 'would'): 14,
#          ('it', 'is', 'not'): 14,
#          ('i', 'should', 'like'): 14,
#          ('the', 'committee', 'on'): 13,
#          ('the', 'euratom', 'treaty'): 13,
#          ('ladies', 'and', 'gentlemen'): 13,
#          ('the', 'nuclear', 'industry'): 13,
#          ('that', 'the', 'european'): 12,
#          ('in', 'favour', 'of'): 12,
#          ('nuclear', 'energy', '<e>'): 12,
#          ('<s>', 'i', 'am'): 12,
#          ('i', 'wish', 'to'): 11,
#          ('there', 'is', 'no'): 11,
#          ('union', '<e>', '<e>'): 11,
#          ('in', 'the', 'european'): 11,
#          ('UNK', '<e>', '<e>'): 11,
#          ('should', 'like', 'to'): 11,
#          ('power', '<e>', '<e>'): 11,
#          ('of', 'nuclear', 'energy'): 11,
#          ('in', 'order', 'to'): 11,
#          ('here', '<e>', '<e>'): 11,
#          ('the', 'green', 'paper'): 11,
#          ('it', 'is', 'also'): 10,
#          ('<s>', 'we', 'are'): 10,
#          ('the', 'question', 'of'): 10,
#          ('<s>', 'in', 'the'): 10,
#          ('sources', '<e>', '<e>'): 10,
#          ('the', 'fact', 'that'): 10,
#          ('and', 'that', 'is'): 10,
#          ('the', 'european', 'commission'): 10,
#          ('states', '<e>', '<e>'): 10,
#          ('<s>', '<s>', 'my'): 10,
#          ('it', 'is', 'a'): 10,
#          ('that', 'is', 'why'): 10,
#          ('<s>', '<s>', 'a'): 10,
#          ('<s>', 'the', 'european'): 10,
#          ('<s>', '<s>', 'let'): 9,
#          ('<s>', 'there', 'is'): 9,
#          ('european', 'union', '<e>'): 9,
#          ('mr', 'president', 'ladies'): 9,
#          ('president', 'ladies', 'and'): 9,
#          ('the', 'european', 'unions'): 9,
#          ('<s>', 'this', 'is'): 9,
#          ('it', '<e>', '<e>'): 9,
#          ('<s>', '<s>', 'at'): 9,
#          ('and', 'i', 'would'): 9,
#          ('we', 'want', 'to'): 8,
#          ('parliament', '<e>', '<e>'): 8,
#          ('one', '<e>', '<e>'): 8,
#          ('i', 'think', 'that'): 8,
#          ('we', 'have', 'to'): 8,
#          ('europe', '<e>', '<e>'): 8,
#          ('of', 'the', 'nuclear'): 8,
#          ('power', 'stations', '<e>'): 8,
#          ('stations', '<e>', '<e>'): 8,
#          ('<s>', '<s>', 'however'): 8,
#          ('the', 'promotion', 'of'): 8,
#          ('the', 'safety', 'of'): 8,
#          ('<s>', 'we', 'have'): 8,
#          ('member', 'states', '<e>'): 8,
#          ('<s>', 'i', 'believe'): 8,
#          ('nuclear', 'power', 'station'): 8,
#          ('i', 'do', 'not'): 8,
#          ('technology', '<e>', '<e>'): 8,
#          ('nuclear', 'energy', 'is'): 8,
#          ('energy', 'sources', '<e>'): 8,
#          ('<s>', '<s>', 'here'): 8,
#          ('<s>', '<s>', 'commissioner'): 8,
#          ('for', 'renewable', 'energy'): 8,
#          ('the', 'titley', 'report'): 8,
#          ('would', 'like', 'to'): 7,
#          ('<s>', '<s>', 'unfortunately'): 7,
#          ('and', 'i', 'think'): 7,
#          ('first', 'of', 'all'): 7,
#          ('<s>', 'the', 'commission'): 7,
#          ('this', '<e>', '<e>'): 7,
#          ('in', 'terms', 'of'): 7,
#          ('question', 'of', 'the'): 7,
#          ('years', '<e>', '<e>'): 7,
#          ('<s>', '<s>', 'on'): 7,
#          ('nuclear', 'power', 'in'): 7,
#          ('i', 'would', 'say'): 7,
#          ('time', '<e>', '<e>'): 7,
#          ('a', 'number', 'of'): 7,
#          ('nuclear', 'power', '<e>'): 7,
#          ('central', 'and', 'eastern'): 7,
#          ('there', 'is', 'a'): 7,
#          ('the', 'liberalization', 'of'): 7,
#          ('for', 'the', 'european'): 7,
#          ('in', 'any', 'case'): 7,
#          ('that', 'nuclear', 'energy'): 7,
#          ('<s>', 'as', 'for'): 7,
#          ('the', 'development', 'of'): 7,
#          ('<s>', '<s>', 'yet'): 7,
#          ('<s>', '<s>', 'to'): 7,
#          ('has', 'to', 'be'): 7,
#          ('<s>', 'there', 'are'): 7,
#          ('on', 'renewable', 'energy'): 7,
#          ('part', 'of', 'the'): 7,
#          ('wastes', '<e>', '<e>'): 7,
#          ('in', 'the', 'area'): 7,
#          ('<s>', 'we', 'also'): 6,
#          ('in', 'relation', 'to'): 6,
#          ('also', 'like', 'to'): 6,
#          ('as', 'well', 'as'): 6,
#          ('all', '<e>', '<e>'): 6,
#          ('we', 'do', 'not'): 6,
#          ('i', 'would', 'like'): 6,
#          ('technological', 'development', 'and'): 6,
#          ('of', 'the', 'euratom'): 6,
#          ('<s>', '<s>', 'what'): 6,
#          ('that', 'it', 'is'): 6,
#          ('point', 'of', 'view'): 6,
#          ('<s>', 'i', 'should'): 6,
#          ('<s>', '<s>', 'finally'): 6,
#          ('the', 'countries', 'of'): 6,
#          ('<s>', 'if', 'we'): 6,
#          ('<s>', 'i', 'have'): 6,
#          ('waste', '<e>', '<e>'): 6,
#          ('<s>', 'that', 'would'): 6,
#          ('use', 'of', 'nuclear'): 6,
#          ('<s>', 'it', 'would'): 6,
#          ('and', 'eastern', 'europe'): 6,
#          ('at', 'the', 'same'): 6,
#          ('the', 'same', 'time'): 6,
#          ('the', 'framework', 'of'): 6,
#          ('the', 'white', 'paper'): 6,
#          ('because', 'of', 'the'): 6,
#          ('in', 'my', 'opinion'): 6,
#          ('as', 'for', 'the'): 6,
#          ('energy', 'policy', '<e>'): 6,
#          ('committee', 'on', 'energy'): 6,
#          ('let', 'me', 'say'): 6,
#          ('that', '<e>', '<e>'): 6,
#          ('<s>', '<s>', 'all'): 6,
#          ('european', 'union', 'is'): 6,
#          ('vote', '<e>', '<e>'): 5,
#          ('we', 'should', 'not'): 5,
#          ('<s>', 'let', 'us'): 5,
#          ('<s>', '<s>', 'applause'): 5,
#          ('as', 'a', 'result'): 5,
#          ('a', 'result', 'of'): 5,
#          ('i', 'would', 'also'): 5,
#          ('would', 'also', 'like'): 5,
#          ('the', 'commission', 'and'): 5,
#          ('commission', 'and', 'the'): 5,
#          ('the', 'debate', 'on'): 5,
#          ('house', '<e>', '<e>'): 5,
#          ('i', 'am', 'not'): 5,
#          ('<s>', '<s>', 'parliament'): 5,
#          ('debate', 'on', 'the'): 5,
#          ('the', 'report', 'by'): 5,
#          ('so', '<e>', '<e>'): 5,
#          ('when', 'it', 'comes'): 5,
#          ('it', 'comes', 'to'): 5,
#          ('as', 'a', 'whole'): 5,
#          ('that', 'is', 'the'): 5,
#          ('against', 'nuclear', 'power'): 5,
#          ('in', 'keeping', 'with'): 5,
#          ('progress', '<e>', '<e>'): 5,
#          ('<s>', '<s>', 'secondly'): 5,
#          ('no', '<e>', '<e>'): 5,
#          ('the', 'united', 'states'): 5,
#          ('for', 'us', 'to'): 5,
#          ('area', '<e>', '<e>'): 5,
#          ('future', '<e>', '<e>'): 5,
#          ('of', 'the', 'environment'): 5,
#          ('it', 'would', 'be'): 5,
#          ('energy', 'sources', 'and'): 5,
#          ('<s>', '<s>', 'you'): 5,
#          ('to', 'build', 'a'): 5,
#          ('to', 'do', 'so'): 5,
#          ('that', 'in', 'the'): 5,
#          ('should', 'not', 'be'): 5,
#          ('of', 'energy', '<e>'): 5,
#          ('<s>', '<s>', 'from'): 5,
#          ('research', '<e>', '<e>'): 5,
#          ('because', 'it', 'is'): 5,
#          ('the', 'rapporteur', 'mr'): 5,
#          ('rapporteur', 'mr', 'soulier'): 5,
#          ('the', 'field', 'of'): 5,
#          ('we', 'need', 'to'): 5,
#          ('<s>', 'my', 'group'): 5,
#          ('<s>', '<s>', 'nuclear'): 5,
#          ('i', 'hope', 'that'): 5,
#          ('by', 'the', 'european'): 5,
#          ('is', 'not', 'a'): 5,
#          ('the', 'commission', 'is'): 5,
#          ('<s>', '<s>', 'then'): 5,
#          ('this', 'report', '<e>'): 5,
#          ('is', 'why', 'i'): 5,
#          ('a', 'question', 'of'): 5,
#          ('<s>', 'i', 'think'): 5,
#          ('<s>', 'i', 'also'): 5,
#          ('by', 'the', 'year'): 5,
#          ('in', 'the', 'committee'): 5,
#          ('i', 'want', 'to'): 5,
#          ('we', 'are', 'not'): 5,
#          ('that', 'the', 'commission'): 5,
#          ('and', 'in', 'the'): 5,
#          ('congratulate', 'the', 'rapporteur'): 5,
#          ('energy', 'sources', 'in'): 5,
#          ('of', 'my', 'group'): 5,
#          ('the', 'basis', 'of'): 5,
#          ('<s>', 'this', 'would'): 5,
#          ('can', 'only', 'be'): 5,
#          ('proposal', '<e>', '<e>'): 5,
#          ('the', 'implementation', 'of'): 5,
#          ('renewable', 'sources', 'of'): 5,
#          ('sources', 'of', 'energy'): 5,
#          ('needs', 'to', 'be'): 5,
#          ('renewable', 'energy', '<e>'): 5,
#          ('use', 'of', 'renewable'): 5,
#          ('<s>', '<s>', 'just'): 5,
#          ('rollcall', 'vote', 'on'): 5,
#          ('the', 'vote', '<e>'): 4,
#          ('i', 'have', 'to'): 4,
#          ('<s>', '<s>', 'today'): 4,
#          ('on', 'behalf', 'of'): 4,
#          ('behalf', 'of', 'the'): 4,
#          ('is', 'also', 'a'): 4,
#          ('world', '<e>', '<e>'): 4,
#          ('which', 'have', 'been'): 4,
#          ('members', 'of', 'the'): 4,
#          ('result', 'of', 'the'): 4,
#          ('country', '<e>', '<e>'): 4,
#          ('rules', 'of', 'procedure'): 4,
#          ('the', 'european', 'parliaments'): 4,
#          ('wish', 'to', 'make'): 4,
#          ('this', 'house', '<e>'): 4,
#          ('industry', '<e>', '<e>'): 4,
#          ('the', 'need', 'to'): 4,
#          ('in', 'recent', 'years'): 4,
#          ('by', 'mr', 'soulier'): 4,
#          ('research', 'technological', 'development'): 4,
#          ('is', 'that', 'the'): 4,
#          ('and', 'it', 'is'): 4,
#          ('most', 'of', 'the'): 4,
#          ('we', 'would', 'be'): 4,
#          ('would', 'be', 'in'): 4,
#          ('<s>', '<s>', 'of'): 4,
#          ('<s>', 'of', 'course'): 4,
#          ('of', 'course', 'we'): 4,
#          ('we', 'must', 'also'): 4,
#          ('on', 'this', 'subject'): 4,
#          ('to', 'say', 'that'): 4,
#          ('of', 'the', 'amendments'): 4,
#          ('member', 'states', 'have'): 4,
#          ('for', 'or', 'against'): 4,
#          ('or', 'against', 'nuclear'): 4,
#          ('all', 'member', 'states'): 4,
#          ('in', 'the', 'long'): 4,
#          ('this', 'is', 'not'): 4,
#          ('keeping', 'with', 'the'): 4,
#          ('we', 'are', 'all'): 4,
#          ('of', 'renewable', 'energies'): 4,
#          ('in', 'this', 'area'): 4,
#          ('be', 'able', 'to'): 4,
#          ('that', 'we', 'must'): 4,
#          ('the', 'ageing', 'of'): 4,
#          ('<s>', 'but', 'we'): 4,
#          ('that', 'we', 'can'): 4,
#          ('them', '<e>', '<e>'): 4,
#          ('fact', 'that', 'the'): 4,
#          ('that', 'we', 'UNK'): 4,
#          ('of', 'radioactive', 'waste'): 4,
#          ('is', 'not', 'the'): 4,
#          ('in', 'the', 'eu'): 4,
#          ('in', 'nuclear', 'power'): 4,
#          ('mr', 'soulier', 'for'): 4,
#          ('the', 'future', 'of'): 4,
#          ('<s>', 'it', 'was'): 4,
#          ('<s>', '<s>', 'because'): 4,
#          ('for', 'nuclear', 'power'): 4,
#          ('forms', 'of', 'energy'): 4,
#          ('nuclear', 'power', 'is'): 4,
#          ('wrong', '<e>', '<e>'): 4,
#          ('excellent', 'report', '<e>'): 4,
#          ('<s>', 'at', 'present'): 4,
#          ('<s>', 'the', 'report'): 4,
#          ('it', 'should', 'be'): 4,
#          ('of', 'central', 'and'): 4,
#          ('eastern', 'europe', 'and'): 4,
#          ('of', 'nuclear', 'waste'): 4,
#          ('industry', 'in', 'the'): 4,
#          ('of', 'the', 'new'): 4,
#          ('on', 'the', 'liberalization'): 4,
#          ('liberalization', 'of', 'the'): 4,
#          ('so', 'it', 'is'): 4,
#          ('agree', 'with', 'mr'): 4,
#          ('<s>', '<s>', 'they'): 4,
#          ('new', 'nuclear', 'power'): 4,
#          ('<s>', '<s>', 'these'): 4,
#          ('linked', 'to', 'the'): 4,
#          ('mr', 'UNK', 'report'): 4,
#          ('but', 'also', 'the'): 4,
#          ('at', 'all', '<e>'): 4,
#          ('do', 'not', 'know'): 4,
#          ('in', 'the', 'world'): 4,
#          ('and', 'gentlemen', 'i'): 4,
#          ('mr', 'soulier', '<e>'): 4,
#          ('soulier', '<e>', '<e>'): 4,
#          ('we', 'need', 'a'): 4,
#          ('favour', 'of', 'the'): 4,
#          ('countries', '<e>', '<e>'): 4,
#          ('some', 'of', 'the'): 4,
#          ('that', 'we', 'have'): 4,
#          ('the', 'subject', 'of'): 4,
#          ('waste', 'and', 'the'): 4,
#          ('<s>', 'we', 'must'): 4,
#          ('<s>', '<s>', 'nor'): 4,
#          ('<s>', 'we', 'need'): 4,
#          ('<s>', 'let', 'me'): 4,
#          ('in', 'this', 'sector'): 4,
#          ('the', 'cost', 'of'): 4,
#          ('the', 'case', 'of'): 4,
#          ('basis', 'of', 'the'): 4,
#          ('green', 'paper', 'is'): 4,
#          ('i', 'must', 'say'): 4,
#          ('interests', '<e>', '<e>'): 4,
#          ('the', 'commission', 'has'): 4,
#          ('concerned', '<e>', '<e>'): 4,
#          ('to', 'make', 'the'): 4,
#          ('we', 'can', 'only'): 4,
#          ('say', 'that', 'the'): 4,
#          ('issue', '<e>', '<e>'): 4,
#          ('<s>', 'in', 'that'): 4,
#          ('energy', 'sources', 'as'): 4,
#          ('on', 'the', 'basis'): 4,
#          ('green', 'paper', 'on'): 4,
#          ('agree', 'with', 'me'): 4,
#          ('at', '12', 'noon'): 4,
#          ('for', 'the', 'future'): 4,
#          ('i', 'believe', 'that'): 4,
#          ('energy', 'sources', 'are'): 4,
#          ('development', '<e>', '<e>'): 4,
#          ('<s>', 'so', 'we'): 4,
#          ('paper', '<e>', '<e>'): 4,
#          ('this', 'is', 'a'): 4,
#          ('to', 'be', 'done'): 4,
#          ('the', '21st', 'century'): 4,
#          ('<s>', 'if', 'the'): 4,
#          ('seems', 'to', 'be'): 4,
#          ('in', 'this', 'way'): 4,
#          ('procedure', '<e>', '<e>'): 4,
#          ('there', 'are', 'still'): 4,
#          ('votes', '<e>', '<e>'): 4,
#          ('committee', '<e>', '<e>'): 4,
#          ('voting', '<e>', '<e>'): 4,
#          ('know', 'what', 'is'): 4,
#          ('what', 'is', 'being'): 4,
#          ('is', 'being', 'voted'): 4,
#          ('being', 'voted', 'upon'): 4,
#          ('the', 'motion', 'for'): 4,
#          ('motion', 'for', 'a'): 4,
#          ('for', 'a', 'resolution'): 4,
#          ('the', 'next', 'item'): 3,
#          ('next', 'item', 'is'): 3,
#          ('item', 'is', 'the'): 3,
#          ('<s>', 'for', 'the'): 3,
#          ('days', '<e>', '<e>'): 3,
#          ('pursuant', 'to', 'rule'): 3,
#          ('the', 'rules', 'of'): 3,
#          ('in', 'brussels', 'and'): 3,
#          ('well', '<e>', '<e>'): 3,
#          ('with', 'the', 'commission'): 3,
#          ('and', 'the', 'european'): 3,
#          ('like', 'to', 'tell'): 3,
#          ('approval', 'of', 'the'): 3,
#          ('i', 'refer', 'to'): 3,
#          ('<s>', 'i', 'wish'): 3,
#          ('i', 'know', 'that'): 3,
#          ('untrue', '<e>', '<e>'): 3,
#          ('<s>', '<s>', 'she'): 3,
#          ('in', 'my', 'report'): 3,
#          ('to', 'make', 'it'): 3,
#          ('president', 'i', 'wish'): 3,
#          ('of', 'the', 'committee'): 3,
#          ('committee', 'on', 'research'): 3,
#          ('on', 'research', 'technological'): 3,
#          ('development', 'and', 'energy'): 3,
#          ('on', 'the', 'nuclear'): 3,
#          ('european', 'parliament', '<e>'): 3,
#          ('to', 'the', 'european'): 3,
#          ('to', 'do', 'this'): 3,
#          ('problems', '<e>', '<e>'): 3,
#          ('it', 'is', 'quite'): 3,
#          ('over', 'the', 'last'): 3,
#          ('member', 'states', 'and'): 3,
#          ('union', 'as', 'a'): 3,
#          ('<s>', 'the', 'second'): 3,
#          ('european', 'unions', 'energy'): 3,
#          ('us', '<e>', '<e>'): 3,
#          ('<s>', 'in', 'my'): 3,
#          ('have', 'to', 'be'): 3,
#          ('the', 'amendments', 'tabled'): 3,
#          ('amendments', 'tabled', 'by'): 3,
#          ('<s>', '<s>', 'first'): 3,
#          ('<s>', 'first', 'of'): 3,
#          ('nuclear', 'power', 'and'): 3,
#          ('be', 'respected', '<e>'): 3,
#          ('respected', '<e>', '<e>'): 3,
#          ('power', 'in', 'the'): 3,
#          ('renewable', 'energies', '<e>'): 3,
#          ('energies', '<e>', '<e>'): 3,
#          ('in', 'europe', '<e>'): 3,
#          ('put', 'an', 'end'): 3,
#          ('an', 'end', 'to'): 3,
#          ('it', 'is', 'our'): 3,
#          ('i', 'have', 'not'): 3,
#          ('<s>', 'but', 'i'): 3,
#          ('fact', 'that', 'we'): 3,
#          ('<s>', 'we', 'UNK'): 3,
#          ('<s>', 'what', 'would'): 3,
#          ('would', 'be', 'the'): 3,
#          ('that', 'would', 'save'): 3,
#          ('the', 'energy', 'committee'): 3,
#          ('the', 'environment', 'committees'): 3,
#          ('<s>', 'however', 'i'): 3,
#          ('agree', 'with', 'the'): 3,
#          ('of', 'energy', 'sources'): 3,
#          ('mr', 'soulier', 'is'): 3,
#          ('<s>', 'on', 'the'): 3,
#          ('action', 'plan', 'for'): 3,
#          ('not', 'to', 'build'): 3,
#          ('ones', '<e>', '<e>'): 3,
#          ('of', 'the', 'eu'): 3,
#          ('the', 'eu', '<e>'): 3,
#          ('eu', '<e>', '<e>'): 3,
#          ('in', 'other', 'words'): 3,
#          ('and', 'so', 'on'): 3,
#          ('future', 'of', 'nuclear'): 3,
#          ('in', 'western', 'europe'): 3,
#          ('not', '<e>', '<e>'): 3,
#          ('programme', '<e>', '<e>'): 3,
#          ('in', 'the', 'years'): 3,
#          ('that', 'there', 'is'): 3,
#          ('the', 'costs', 'of'): 3,
#          ('liberalization', 'of', 'electricity'): 3,
#          ('around', 'the', 'world'): 3,
#          ('support', '<e>', '<e>'): 3,
#          ('<s>', 'i', 'UNK'): 3,
#          ('to', 'nuclear', 'power'): 3,
#          ('will', 'vote', 'against'): 3,
#          ('his', 'report', '<e>'): 3,
#          ('do', 'not', 'have'): 3,
#          ('<s>', 'i', 'understand'): 3,
#          ('and', 'i', 'hope'): 3,
#          ('form', 'of', 'energy'): 3,
#          ('president', 'i', 'should'): 3,
#          ('like', 'to', 'thank'): 3,
#          ('the', 'proportion', 'of'): 3,
#          ('other', 'forms', 'of'): 3,
#          ('in', 'the', 'nuclear'): 3,
#          ('nuclear', 'industry', 'and'): 3,
#          ('it', 'does', 'not'): 3,
#          ('safety', '<e>', '<e>'): 3,
#          ('countries', 'of', 'central'): 3,
#          ('nuclear', 'waste', '<e>'): 3,
#          ('directive', 'on', 'the'): 3,
#          ('framework', 'of', 'the'): 3,
#          ('european', 'union', 'and'): 3,
#          ('<s>', 'so', 'it'): 3,
#          ('each', 'member', 'state'): 3,
#          ('with', 'mr', 'soulier'): 3,
#          ('<s>', 'we', 'really'): 3,
#          ('has', 'not', 'been'): 3,
#          ('mr', 'president', 'the'): 3,
#          ('the', 'citizens', 'of'): 3,
#          ('a', 'great', 'deal'): 3,
#          ('commissioner', '<e>', '<e>'): 3,
#          ('the', 'liberal', 'group'): 3,
#          ('mr', 'soulier', 'on'): 3,
#          ('soulier', 'on', 'his'): 3,
#          ('to', 'nuclear', 'energy'): 3,
#          ('a', 'nuclear', 'power'): 3,
#          ('power', 'station', 'is'): 3,
#          ('it', 'seems', 'to'): 3,
#          ('transport', 'of', 'nuclear'): 3,
#          ('transport', '<e>', '<e>'): 3,
#          ('i', 'would', 'ask'): 3,
#          ('this', 'is', 'what'): 3,
#          ('but', 'they', 'do'): 3,
#          ('there', 'can', 'be'): 3,
#          ('can', 'be', 'no'): 3,
#          ('on', 'the', 'commission'): 3,
#          ('the', 'commission', 'communication'): 3,
#          ('<s>', 'at', 'the'): 3,
#          ('the', 'directive', 'on'): 3,
#          ('the', 'principles', 'of'): 3,
#          ('report', 'drafted', 'by'): 3,
#          ('by', 'the', 'committee'): 3,
#          ('on', 'energy', '<e>'): 3,
#          ('in', 'no', 'way'): 3,
#          ('no', 'nuclear', 'power'): 3,
#          ('do', 'not', 'want'): 3,
#          ('to', 'say', 'the'): 3,
#          ('<s>', '<s>', 'surely'): 3,
#          ('disposal', '<e>', '<e>'): 3,
#          ('safety', 'of', 'nuclear'): 3,
#          ('the', 'world', 'and'): 3,
#          ('in', 'the', 'report'): 3,
#          ('back', 'to', 'the'): 3,
#          ('i', 'can', 'only'): 3,
#          ('of', 'the', 'use'): 3,
#          ('costs', '<e>', '<e>'): 3,
#          ('can', 'be', 'used'): 3,
#          ('be', 'used', 'in'): 3,
#          ('in', 'this', 'chamber'): 3,
#          ('ago', '<e>', '<e>'): 3,
#          ('countries', 'in', 'the'): 3,
#          ('the', 'long', 'term'): 3,
#          ('gas', '<e>', '<e>'): 3,
#          ('<s>', 'in', 'this'): 3,
#          ('<s>', 'we', 'should'): 3,
#          ('and', 'disposal', 'of'): 3,
#          ('like', 'to', 'congratulate'): 3,
#          ('of', 'the', 'commission'): 3,
#          ('work', '<e>', '<e>'): 3,
#          ('ask', 'you', 'to'): 3,
#          ('public', 'health', 'and'): 3,
#          ('such', 'as', 'the'): 3,
#          ('energy', 'is', 'a'): 3,
#          ('and', 'we', 'should'): 3,
#          ('of', 'nuclear', 'installations'): 3,
#          ('the', 'management', 'of'): 3,
#          ('of', 'the', 'whole'): 3,
#          ('of', 'the', 'UNK'): 3,
#          ('one', 'of', 'the'): 3,
#          ('the', 'price', 'will'): 3,
#          ('which', 'means', 'that'): 3,
#          ('<s>', 'so', 'i'): 3,
#          ('which', 'is', 'why'): 3,
#          ('<s>', 'in', 'any'): 3,
#          ('point', '<e>', '<e>'): 3,
#          ('there', 'are', 'a'): 3,
#          ('are', 'a', 'number'): 3,
#          ('<s>', 'the', 'question'): 3,
#          ('in', 'a', 'sense'): 3,
#          ('<s>', '<s>', 'no'): 3,
#          ('mr', 'president', 'in'): 3,
#          ('in', 'the', 'case'): 3,
#          ('i', 'agree', 'with'): 3,
#          ('calls', 'for', 'a'): 3,
#          ('measures', '<e>', '<e>'): 3,
#          ('question', '<e>', '<e>'): 3,
#          ('in', 'the', 'commissions'): 3,
#          ('the', 'commissions', 'green'): 3,
#          ('commissions', 'green', 'paper'): 3,
#          ('not', 'know', 'what'): 3,
#          ('<s>', '<s>', 'despite'): 3,
#          ('a', 'point', 'of'): 3,
#          ('<s>', '<s>', 'after'): 3,
#          ('energy', 'sources', 'can'): 3,
#          ('and', 'if', 'we'): 3,
#          ('and', 'i', 'must'): 3,
#          ('into', 'account', 'the'): 3,
#          ('make', 'it', 'possible'): 3,
#          ('in', 'that', 'way'): 3,
#          ('nuclear', 'energy', 'and'): 3,
#          ('to', 'european', 'citizens'): 3,
#          ('are', 'aware', 'of'): 3,
#          ('and', 'of', 'course'): 3,
#          ('mainly', 'to', 'the'): 3,
#          ('research', 'and', 'technological'): 3,
#          ('and', 'technological', 'development'): 3,
#          ('packaging', 'and', 'disposal'): 3,
#          ('radioactive', 'wastes', '<e>'): 3,
#          ('the', 'possibility', 'of'): 3,
#          ('the', 'world', '<e>'): 3,
#          ('that', 'we', 'will'): 3,
#          ('for', 'research', 'and'): 3,
#          ('a', 'policy', 'of'): 3,
#          ('along', 'those', 'lines'): 3,
#          ('by', 'mrs', 'rothe'): 3,
#          ('mrs', 'rothe', 'on'): 3,
#          ('of', 'the', 'green'): 3,
#          ('paper', 'on', 'renewable'): 3,
#          ('<s>', 'commissioner', 'let'): 3,
#          ('commissioner', 'let', 'me'): 3,
#          ('to', 'be', 'said'): 3,
#          ('want', 'to', 'know'): 3,
#          ('the', 'internal', 'market'): 3,
#          ('market', '<e>', '<e>'): 3,
#          ('that', 'is', 'an'): 3,
#          ('12', 'noon', '<e>'): 3,
#          ('noon', '<e>', '<e>'): 3,
#          ('<s>', '<s>', 'renewable'): 3,
#          ('a', 'community', 'strategy'): 3,
#          ('european', 'energy', 'policy'): 3,
#          ('in', 'the', 'green'): 3,
#          ('strategy', '<e>', '<e>'): 3,
#          ('analysis', 'of', 'the'): 3,
#          ('are', 'to', 'be'): 3,
#          ('is', 'why', 'we'): 3,
#          ('with', 'renewable', 'energy'): 3,
#          ('promotion', 'of', 'renewable'): 3,
#          ('of', 'the', 'internal'): 3,
#          ('in', 'the', 'field'): 3,
#          ('<s>', 'for', 'instance'): 3,
#          ('a', 'situation', 'where'): 3,
#          ('resources', '<e>', '<e>'): 3,
#          ('be', 'done', 'in'): 3,
#          ('mr', 'president', 'commissioner'): 3,
#          ('on', 'renewable', 'sources'): 3,
#          ('sector', '<e>', '<e>'): 3,
#          ('her', 'report', '<e>'): 3,
#          ('areas', '<e>', '<e>'): 3,
#          ('<s>', '<s>', 'biomass'): 3,
#          ('and', 'the', 'promotion'): 3,
#          ('system', '<e>', '<e>'): 3,
#          ('and', 'we', 'must'): 3,
#          ('mrs', 'rothes', 'report'): 3,
#          ('mrs', 'rothe', 'for'): 3,
#          ('mr', 'robles', 'piquer'): 3,
#          ('to', 'give', 'us'): 3,
#          ('we', 'have', 'done'): 3,
#          ('that', 'renewable', 'energy'): 3,
#          ('is', 'a', 'very'): 3,
#          ('going', 'to', 'vote'): 3,
#          ('to', 'vote', 'in'): 3,
#          ('partly', 'because', 'the'): 3,
#          ('they', 'do', 'not'): 3,
#          ('hope', 'that', 'the'): 3,
#          ('that', 'the', 'house'): 3,
#          ('cooperation', '<e>', '<e>'): 3,
#          ('european', 'union', 'should'): 3,
#          ('agree', 'with', 'you'): 3,
#          ('from', 'the', 'fact'): 3,
#          ('etc', '<e>', '<e>'): 3,
#          ('money', 'is', 'spent'): 3,
#          ('is', 'spent', 'on'): 3,
#          ('if', 'we', 'want'): 3,
#          ('believe', 'that', 'the'): 3,
#          ('we', 'should', 'be'): 3,
#          ('the', 'whole', 'of'): 3,
#          ('up', 'to', 'the'): 3,
#          ('for', 'the', 'implementation'): 3,
#          ('<s>', '<s>', 'since'): 3,
#          ('<s>', 'i', 'suggest'): 3,
#          ('amendments', '<e>', '<e>'): 3,
#          ('president', 'i', 'am'): 3,
#          ('vote', 'on', 'all'): 3,
#          ('parts', 'of', 'the'): 3,
#          ('of', 'the', 'text'): 3,
#          ('the', 'text', 'on'): 3,
#          ('text', 'on', 'which'): 3,
#          ('on', 'which', 'there'): 3,
#          ('which', 'there', 'are'): 3,
#          ('a', 'rollcall', 'vote'): 3,
#          ('back', 'to', 'committee'): 3,
#          ('in', 'this', 'house'): 3,
#          ('<s>', '<s>', 'perhaps'): 3,
#          ('the', 'committee', '<e>'): 3,
#          ('that', 'i', 'am'): 3,
#          ('order', '<e>', '<e>'): 3,
#          ('the', 'normal', 'way'): 3,
#          ('our', 'voting', '<e>'): 3,
#          ('way', 'in', 'which'): 3,
#          ('the', 'way', 'we'): 3,
#          ('me', '<e>', '<e>'): 3,
#          ('<s>', '<s>', 'UNK'): 3,
#          ('mistake', '<e>', '<e>'): 3,
#          ('which', 'is', 'a'): 3,
#          ('in', 'the', 'framework'): 3,
#          ('a', 'common', 'defence'): 3,
#          ('in', 'which', 'the'): 3,
#          ('a', 'common', 'european'): 3,
#          ('of', 'a', 'european'): 3,
#          ('european', 'defence', 'industry'): 3,
#          ('in', 'the', 'balkans'): 3,
#          ('of', 'former', 'yugoslavia'): 3,
#          ('<s>', 'just', 'as'): 3,
#          ('the', 'rights', 'or'): 3,
#          ('rights', 'or', 'wrongs'): 3,
#          ('or', 'wrongs', 'of'): 3,
#          ('the', 'results', 'and'): 2,
#          ('the', 'president', 'i'): 2,
#          ('session', '<e>', '<e>'): 2,
#          ('to', 'inform', 'you'): 2,
#          ('an', 'earthquake', 'in'): 2,
#          ('died', '<e>', '<e>'): 2,
#          ('people', '<e>', '<e>'): 2,
#          ('<s>', '<s>', 'every'): 2,
#          ('is', 'more', 'than'): 2,
#          ('a', 'tragedy', 'for'): 2,
#          ('the', 'whole', 'world'): 2,
#          ('march', 'marks', 'the'): 2,
#          ('anniversary', 'of', 'the'): 2,
#          ('independence', '<e>', '<e>'): 2,
#          ('<s>', '<s>', 'among'): 2,
#          ('<s>', 'among', 'the'): 2,
#          ('our', 'fellow', 'members'): 2,
#          ('fellow', 'members', 'from'): 2,
#          ('<s>', 'as', 'a'): 2,
#          ('appeal', 'to', 'the'): 2,
#          ('authorities', 'of', 'the'): 2,
#          ('of', 'the', 'peoples'): 2,
#          ('representatives', '<e>', '<e>'): 2,
#          ('<s>', 'applause', 'i'): 2,
#          ('by', 'a', 'member'): 2,
#          ('the', 'authorities', 'in'): 2,
#          ('authorities', 'in', 'brussels'): 2,
#          ('<s>', '<s>', 'our'): 2,
#          ('brussels', 'and', 'in'): 2,
#          ('to', 'create', 'a'): 2,
#          ('around', 'the', 'premises'): 2,
#          ('the', 'premises', 'of'): 2,
#          ('in', 'the', 'next'): 2,
#          ('the', 'next', 'few'): 2,
#          ('to', 'tell', 'you'): 2,
#          ('very', 'hard', 'to'): 2,
#          ('concerns', 'us', 'all'): 2,
#          ('us', 'all', '<e>'): 2,
#          ('<s>', '<s>', 'approval'): 2,
#          ('<s>', 'approval', 'of'): 2,
#          ('of', 'the', 'minutes'): 2,
#          ('the', 'minutes', 'the'): 2,
#          ('<s>', '<s>', 'are'): 2,
#          ('my', 'report', '<e>'): 2,
#          ('to', 'make', 'a'): 2,
#          ('make', 'a', 'personal'): 2,
#          ('a', 'lobbyist', 'for'): 2,
#          ('merchants', 'of', 'death'): 2,
#          ('in', 'line', 'with'): 2,
#          ('it', 'is', 'entirely'): 2,
#          ('entirely', 'untrue', '<e>'): 2,
#          ('is', 'not', 'in'): 2,
#          ('interests', 'of', 'the'): 2,
#          ('of', 'this', 'nature'): 2,
#          ('to', 'be', 'made'): 2,
#          ('of', 'this', 'house'): 2,
#          ('<s>', 'i', 'can'): 2,
#          ('<s>', '<s>', 'therefore'): 2,
#          ('therefore', 'i', 'would'): 2,
#          ('like', 'to', 'make'): 2,
#          ('make', 'it', 'clear'): 2,
#          ('make', 'a', 'statement'): 2,
#          ('a', 'certain', 'number'): 2,
#          ('certain', 'number', 'of'): 2,
#          ('to', 'ensure', 'the'): 2,
#          ('free', 'circulation', 'of'): 2,
#          ('goods', '<e>', '<e>'): 2,
#          ('<s>', 'unfortunately', 'we'): 2,
#          ('i', 'think', 'we'): 2,
#          ('we', 'all', 'ought'): 2,
#          ('all', 'ought', 'to'): 2,
#          ('national', 'authorities', 'should'): 2,
#          ('other', 'european', 'countries'): 2,
#          ('european', 'countries', 'who'): 2,
#          ('nuclear', 'industries', 'the'): 2,
#          ('report', 'by', 'mr'): 2,
#          ('and', 'energy', 'on'): 2,
#          ('energy', 'on', 'the'): 2,
#          ('illustrative', 'nuclear', 'programme'): 2,
#          ('article', '40', 'of'): 2,
#          ('40', 'of', 'the'): 2,
#          ('UNK', 'UNK', '<e>'): 2,
#          ('of', 'all', 'i'): 2,
#          ('remind', 'you', 'that'): 2,
#          ('a', 'UNK', '<e>'): 2,
#          ('to', 'consult', 'the'): 2,
#          ('<s>', 'it', 'has'): 2,
#          ('<s>', '<s>', 'apart'): 2,
#          ('<s>', 'apart', 'from'): 2,
#          ('that', 'you', 'have'): 2,
#          ('european', 'parliament', 'i'): 2,
#          ('commissioner', 'that', 'you'): 2,
#          ('were', 'right', 'to'): 2,
#          ('<s>', 'we', 'all'): 2,
#          ('comes', 'to', 'energy'): 2,
#          ('the', 'last', '40'): 2,
#          ('last', '40', 'years'): 2,
#          ('it', 'is', 'therefore'): 2,
#          ('is', 'therefore', 'a'): 2,
#          ('of', 'member', 'states'): 2,
#          ('and', 'at', 'the'): 2,
#          ('the', 'level', 'of'): 2,
#          ('european', 'union', 'as'): 2,
#          ('a', 'whole', '<e>'): 2,
#          ('whole', '<e>', '<e>'): 2,
#          ('well', 'as', 'the'): 2,
#          ('contrary', 'to', 'what'): 2,
#          ('of', 'the', 'member'): 2,
#          ('<s>', '<s>', 'do'): 2,
#          ('of', 'a', 'nuclear'): 2,
#          ('industrial', 'policy', '<e>'): 2,
#          ('report', 'i', 'have'): 2,
#          ('to', 'come', 'in'): 2,
#          ('<s>', '<s>', 'how'): 2,
#          ('course', 'we', 'must'): 2,
#          ('but', 'we', 'must'): 2,
#          ('<s>', 'on', 'this'): 2,
#          ('like', 'to', 'say'): 2,
#          ('tabled', 'by', 'mrs'): 2,
#          ('by', 'mrs', 'mcnally'): 2,
#          ('mrs', 'mcnally', 'for'): 2,
#          ('reasons', '<e>', '<e>'): 2,
#          ('that', 'the', 'member'): 2,
#          ('states', 'have', 'the'): 2,
#          ('have', 'the', 'sovereign'): 2,
#          ('the', 'sovereign', 'right'): 2,
#          ('sovereign', 'right', 'to'): 2,
#          ('right', 'to', 'opt'): 2,
#          ('to', 'opt', 'for'): 2,
#          ('opt', 'for', 'or'): 2,
#          ('that', 'their', 'choice'): 2,
#          ('the', 'plenary', 'session'): 2,
#          ('on', 'nuclear', 'power'): 2,
#          ('but', 'above', 'all'): 2,
#          ('all', 'i', 'should'): 2,
#          ('to', 'mention', 'the'): 2,
#          ('points', '<e>', '<e>'): 2,
#          ('<s>', '<s>', 'europe'): 2,
#          ('or', 'in', 'the'): 2,
#          ('and', 'therefore', 'i'): 2,
#          ('enable', 'us', 'to'): 2,
#          ('at', 'the', 'moment'): 2,
#          ('at', 'the', 'present'): 2,
#          ('the', 'present', 'time'): 2,
#          ('directly', 'or', 'indirectly'): 2,
#          ('<s>', 'and', 'we'): 2,
#          ('amendment', '<e>', '<e>'): 2,
#          ('i', 'would', 'not'): 2,
#          ('of', 'eastern', 'europe'): 2,
#          ('we', 'would', 'also'): 2,
#          ('safety', 'which', 'is'): 2,
#          ('is', 'at', 'stake'): 2,
#          ('think', 'that', 'therefore'): 2,
#          ('technology', 'which', 'is'): 2,
#          ('us', 'to', 'be'): 2,
#          ('to', 'be', 'able'): 2,
#          ('nuclear', 'policy', '<e>'): 2,
#          ('emphasis', 'on', 'the'): 2,
#          ('on', 'the', 'need'): 2,
#          ('as', 'they', 'are'): 2,
#          ('<s>', '<s>', 'everyone'): 2,
#          ('<s>', 'everyone', 'talks'): 2,
#          ('everyone', 'talks', 'about'): 2,
#          ('<s>', 'but', 'what'): 2,
#          ('be', 'without', 'energy'): 2,
#          ('without', 'energy', '<e>'): 2,
#          ('what', 'would', 'be'): 2,
#          ('be', 'the', 'use'): 2,
#          ('an', 'internal', 'market'): 2,
#          ('if', 'we', 'had'): 2,
#          ('of', 'a', 'single'): 2,
#          ('at', 'this', 'time'): 2,
#          ('we', 'know', 'how'): 2,
#          ('it', 'is', 'for'): 2,
#          ('of', 'time', '<e>'): 2,
#          ('mr', 'president', 'it'): 2,
#          ('president', 'it', 'is'): 2,
#          ('for', 'me', 'to'): 2,
#          ('to', 'ask', 'for'): 2,
#          ('the', 'previous', 'speaker'): 2,
#          ('do', 'without', 'it'): 2,
#          ('without', 'it', '<e>'): 2,
#          ('like', 'to', 'begin'): 2,
#          ('to', 'begin', 'by'): 2,
#          ('in', 'trying', 'to'): 2,
#          ('however', 'i', 'would'): 2,
#          ('so', 'that', 'we'): 2,
#          ('we', 'can', 'have'): 2,
#          ('can', 'have', 'the'): 2,
#          ('that', 'the', 'energy'): 2,
#          ('was', 'unable', 'to'): 2,
#          ('the', 'choice', 'of'): 2,
#          ('choice', 'of', 'energy'): 2,
#          ('energy', 'sources', 'is'): 2,
#          ('matter', 'for', 'the'): 2,
#          ('for', 'the', 'individual'): 2,
#          ('individual', 'countries', 'and'): 2,
#          ('this', 'is', 'therefore'): 2,
#          ('the', 'aim', 'of'): 2,
#          ('euratom', 'treaty', 'is'): 2,
#          ('<s>', 'it', 'should'): 2,
#          ('in', 'such', 'a'): 2,
#          ('health', 'and', 'safety'): 2,
#          ('and', 'safety', 'are'): 2,
#          ('<s>', 'the', 'resources'): 2,
#          ('should', 'be', 'used'): 2,
#          ('be', 'used', 'for'): 2,
#          ('on', 'the', 'environmental'): 2,
#          ('associated', 'with', 'the'): 2,
#          ('the', 'storage', 'of'): 2,
#          ('storage', 'of', 'radioactive'): 2,
#          ('the', 'maastricht', 'treaty'): 2,
#          ('promotion', 'of', 'nuclear'): 2,
#          ('by', 'nuclear', 'power'): 2,
#          ('nuclear', 'power', 'but'): 2,
#          ('but', 'it', 'is'): 2,
#          ('on', 'the', 'other'): 2,
#          ('the', 'other', 'hand'): 2,
#          ('the', 'environment', '<e>'): 2,
#          ('environment', '<e>', '<e>'): 2,
#          ('in', 'central', 'and'): 2,
#          ('the', 'eu', 'and'): 2,
#          ('is', 'also', 'in'): 2,
#          ('in', 'accordance', 'with'): 2,
#          ('to', 'improve', 'the'): 2,
#          ('and', 'the', 'safety'): 2,
#          ('to', 'build', 'new'): 2,
#          ('new', 'ones', '<e>'): 2,
#          ('to', 'invest', 'in'): 2,
#          ('power', 'stations', 'that'): 2,
#          ('can', 'never', 'be'): 2,
#          ('efforts', 'should', 'be'): 2,
#          ('aspect', 'of', 'the'): 2,
#          ('of', 'the', 'energy'): 2,
#          ('so', 'on', '<e>'): 2,
#          ('on', '<e>', '<e>'): 2,
#          ('<s>', 'you', 'have'): 2,
#          ('that', 'on', 'the'): 2,
#          ('power', 'in', 'western'): 2,
#          ('western', 'europe', '<e>'): 2,
#          ('it', 'was', 'a'): 2,
#          ('of', 'which', 'have'): 2,
#          ('on', 'the', 'european'): 2,
#          ('<s>', '<s>', 'why'): 2,
#          ('the', 'years', 'since'): 2,
#          ('years', 'since', 'the'): 2,
#          ('to', 'be', 'paid'): 2,
#          ('be', 'paid', 'for'): 2,
#          ('in', 'those', '40'): 2,
#          ('those', '40', 'years'): 2,
#          ('and', 'how', 'to'): 2,
#          ('of', 'decommissioning', '<e>'): 2,
#          ('decommissioning', '<e>', '<e>'): 2,
#          ('that', 'is', 'a'): 2,
#          ('is', 'a', 'matter'): 2,
#          ('a', 'matter', 'for'): 2,
#          ('european', 'union', 'to'): 2,
#          ('available', '<e>', '<e>'): 2,
#          ('is', 'no', 'alternative'): 2,
#          ('alternative', '<e>', '<e>'): 2,
#          ('was', 'wrong', '<e>'): 2,
#          ('<s>', 'mr', 'soulier'): 2,
#          ('use', 'of', 'energy'): 2,
#          ('if', 'research', 'into'): 2,
#          ('research', 'into', 'renewable'): 2,
#          ('as', 'nuclear', 'energy'): 2,
#          ('nuclear', 'energy', 'has'): 2,
#          ('<s>', 'we', 'do'): 2,
#          ('have', 'to', 'decide'): 2,
#          ('to', 'decide', 'for'): 2,
#          ('were', 'unable', 'to'): 2,
#          ('in', 'the', 'future'): 2,
#          ('nuclear', 'power', 'should'): 2,
#          ('energy', 'in', 'this'): 2,
#          ('his', 'excellent', 'report'): 2,
#          ('nuclear', 'power', 'has'): 2,
#          ('it', 'UNK', 'be'): 2,
#          ('the', 'report', 'takes'): 2,
#          ('nuclear', 'power', 'or'): 2,
#          ('or', 'of', 'the'): 2,
#          ('the', 'question', 'whether'): 2,
#          ('a', 'source', 'of'): 2,
#          ('source', 'of', 'energy'): 2,
#          ('of', 'energy', 'and'): 2,
#          ('member', 'states', 'must'): 2,
#          ('the', 'most', 'important'): 2,
#          ('use', 'nuclear', 'power'): 2,
#          ('their', 'safety', '<e>'): 2,
#          ('of', 'view', 'the'): 2,
#          ('of', 'the', 'cis'): 2,
#          ('in', 'the', 'energy'): 2,
#          ('for', 'this', 'purpose'): 2,
#          ('nuclear', 'research', '<e>'): 2,
#          ('<s>', 'the', 'nuclear'): 2,
#          ('the', 'final', 'storage'): 2,
#          ('the', 'radioactivity', 'of'): 2,
#          ('radioactivity', 'of', 'waste'): 2,
#          ('must', 'continue', 'and'): 2,
#          ('must', 'be', 'increased'): 2,
#          ('congratulating', 'the', 'rapporteur'): 2,
#          ('nuclear', 'industry', 'in'): 2,
#          ('the', 'electricity', 'market'): 2,
#          ('that', 'is', 'very'): 2,
#          ('is', 'very', 'important'): 2,
#          ('within', 'the', 'framework'): 2,
#          ('white', 'paper', 'on'): 2,
#          ('of', 'supply', 'and'): 2,
#          ('protection', 'of', 'the'): 2,
#          ('it', 'is', 'an'): 2,
#          ('is', 'an', 'extremely'): 2,
#          ('i', 'believe', 'it'): 2,
#          ('believe', 'it', 'is'): 2,
#          ('free', 'to', 'decide'): 2,
#          ('<s>', 'i', 'myself'): 2,
#          ('i', 'come', 'from'): 2,
#          ('come', 'from', 'a'): 2,
#          ('from', 'a', 'country'): 2,
#          ('a', 'country', 'which'): 2,
#          ('decided', 'against', 'the'): 2,
#          ('against', 'the', 'use'): 2,
#          ('activities', 'of', 'the'): 2,
#          ('a', 'matter', 'of'): 2,
#          ('on', 'this', 'sector'): 2,
#          ('partly', 'because', 'of'): 2,
#          ('in', 'agreement', 'with'): 2,
#          ('that', 'we', 'need'): 2,
#          ('reactors', '<e>', '<e>'): 2,
#          ('and', 'the', 'ageing'): 2,
#          ('a', 'look', 'at'): 2,
#          ('fact', 'that', 'this'): 2,
#          ('by', 'the', 'commission'): 2,
#          ('we', 'agree', 'with'): 2,
#          ('in', 'connection', 'with'): 2,
#          ('connection', 'with', 'the'): 2,
#          ('europe', 'and', 'the'): 2,
#          ('the', 'cis', '<e>'): 2,
#          ('cis', '<e>', '<e>'): 2,
#          ('and', 'gentlemen', 'commissioner'): 2,
#          ('gentlemen', 'commissioner', '<e>'): 2,
#          ('to', 'congratulate', 'mr'): 2,
#          ('congratulate', 'mr', 'soulier'): 2,
#          ('on', 'his', 'report'): 2,
#          ('<s>', '<s>', 'he'): 2,
#          ('resolution', 'on', 'a'): 2,
#          ('subject', 'and', 'i'): 2,
#          ('electricity', '<e>', '<e>'): 2,
#          ('<s>', '<s>', 'accidents'): 2,
#          ('the', 'transport', 'of'): 2,
#          ('of', 'nuclear', 'material'): 2,
#          ('not', 'to', 'mention'): 2,
#          ('air', 'transport', '<e>'): 2,
#          ('<s>', 'for', 'this'): 2,
#          ('in', 'economic', 'terms'): 2,
#          ('<s>', 'this', 'means'): 2,
#          ('this', 'means', 'that'): 2,
#          ('that', 'there', 'can'): 2,
#          ('group', 'will', 'vote'): 2,
#          ('which', 'we', 'are'): 2,
#          ('we', 'are', 'debating'): 2,
#          ('the', 'nuclear', 'power'): 2,
#          ('nuclear', 'power', 'industry'): 2,
#          ('is', 'based', 'on'): 2,
#          ('<s>', 'these', 'are'): 2,
#          ('<s>', 'it', 'shows'): 2,
#          ('it', 'shows', 'that'): 2,
#          ('supplies', 'in', 'europe'): 2,
#          ('in', 'europe', 'and'): 2,
#          ('dependence', '<e>', '<e>'): 2,
#          ('to', 'the', 'environment'): 2,
#          ('in', 'particular', 'the'): 2,
#          ('that', 'member', 'states'): 2,
#          ('must', 'be', 'respected'): 2,
#          ('hope', 'that', 'this'): 2,
#          ('<s>', 'from', 'this'): 2,
#          ('from', 'this', 'point'): 2,
#          ('this', 'point', 'of'): 2,
#          ('i', 'welcome', 'the'): 2,
#          ('committee', 'of', 'the'): 2,
#          ('tabled', 'by', 'the'): 2,
#          ('by', 'the', 'greens'): 2,
#          ('based', 'on', 'scientific'): 2,
#          ('group', 'of', 'the'): 2,
#          ('the', 'commission', 'document'): 2,
#          ('of', 'electricity', 'and'): 2,
#          ('framework', 'of', 'a'): 2,
#          ('of', 'a', 'common'): 2,
#          ('a', 'common', 'energy'): 2,
#          ('common', 'energy', 'policy'): 2,
#          ('in', 'my', 'view'): 2,
#          ('of', 'free', 'trade'): 2,
#          ('which', 'would', 'be'): 2,
#          ('would', 'be', 'a'): 2,
#          ('threat', 'to', 'the'): 2,
#          ('to', 'the', 'member'): 2,
#          ('energy', 'is', 'not'): 2,
#          ('and', 'must', 'not'): 2,
#          ('not', 'obey', 'the'): 2,
#          ('the', 'principle', 'of'): 2,
#          ('principle', 'of', 'free'): 2,
#          ('calling', 'into', 'question'): 2,
#          ('of', 'each', 'country'): 2,
#          ('each', 'country', 'and'): 2,
#          ('<s>', '<s>', 'with'): 2,
#          ('i', 'shall', 'be'): 2,
#          ('the', 'report', 'drafted'): 2,
#          ('drafted', 'by', 'the'): 2,
#          ('let', 'me', 'just'): 2,
#          ('have', 'no', 'nuclear'): 2,
#          ('not', 'want', 'to'): 2,
#          ('also', 'because', 'it'): 2,
#          ('we', 'have', 'already'): 2,
#          ('and', 'we', 'are'): 2,
#          ('we', 'are', 'now'): 2,
#          ('<s>', '<s>', 'your'): 2,
#          ('conditions', '<e>', '<e>'): 2,
#          ('i', 'wonder', 'how'): 2,
#          ('and', 'i', 'wonder'): 2,
#          ('<s>', '<s>', 'even'): 2,
#          ('nonsense', '<e>', '<e>'): 2,
#          ('we', 'have', 'only'): 2,
#          ('<s>', '<s>', 'now'): 2,
#          ('is', 'doing', 'so'): 2,
#          ('<s>', 'then', 'you'): 2,
#          ('you', 'say', 'that'): 2,
#          ('has', 'been', 'made'): 2,
#          ('nuclear', 'installations', '<e>'): 2,
#          ('installations', '<e>', '<e>'): 2,
#          ('that', 'is', 'not'): 2,
#          ('world', 'and', 'that'): 2,
#          ('the', 'commission', 'says'): 2,
#          ('fuel', '<e>', '<e>'): 2,
#          ('and', 'that', 'the'): 2,
#          ('safely', '<e>', '<e>'): 2,
#          ('to', 'be', 'drawn'): 2,
#          ('the', 'UNK', 'and'): 2,
#          ('<s>', 'i', 'shall'): 2,
#          ('the', 'issue', 'of'): 2,
#          ('issue', 'of', 'the'): 2,
#          ('development', 'of', 'the'): 2,
#          ('the', 'nuclear', 'sector'): 2,
#          ('reduction', 'in', 'co2'): 2,
#          ('<s>', 'yet', 'this'): 2,
#          ('to', 'what', 'is'): 2,
#          ('in', 'this', 'report'): 2,
#          ('do', 'not', 'produce'): 2,
#          ('<s>', 'what', 'are'): 2,
#          ('<s>', 'for', 'example'): 2,
#          ('and', 'there', 'are'): 2,
#          ('this', 'type', 'of'): 2,
#          ('why', 'i', 'can'): 2,
#          ('vote', 'for', 'the'): 2,
#          ('to', 'agree', 'with'): 2,
#          ('discussion', 'of', 'the'): 2,
#          ('recent', 'years', '<e>'): 2,
#          ('of', 'that', '<e>'): 2,
#          ('of', 'costs', '<e>'): 2,
#          ('nuclear', 'industry', 'as'): 2,
#          ('say', 'that', 'we'): 2,
#          ('<s>', 'in', 'fact'): 2,
#          ('also', 'a', 'question'): 2,
#          ('in', 'the', 'foreseeable'): 2,
#          ('the', 'foreseeable', 'future'): 2,
#          ('of', 'it', '<e>'): 2,
#          ('energy', 'is', 'an'): 2,
#          ('for', 'thousands', 'of'): 2,
#          ('thousands', 'of', 'years'): 2,
#          ('<s>', 'and', 'the'): 2,
#          ('<s>', '<s>', 'not'): 2,
#          ('<s>', 'not', 'only'): 2,
#          ('points', 'of', 'view'): 2,
#          ('role', 'in', 'the'): 2,
#          ('the', 'economic', 'development'): 2,
#          ('economic', 'development', 'of'): 2,
#          ('countries', 'which', 'are'): 2,
#          ('<s>', 'my', 'second'): 2,
#          ('of', 'course', 'there'): 2,
#          ('of', 'our', 'energy'): 2,
#          ('our', 'energy', 'needs'): 2,
#          ('energy', 'needs', '<e>'): 2,
#          ('needs', '<e>', '<e>'): 2,
#          ('of', 'all', 'we'): 2,
#          ('we', 'are', 'going'): 2,
#          ('are', 'going', 'to'): 2,
#          ('<s>', 'secondly', 'we'): 2,
#          ('we', 'are', 'really'): 2,
#          ('are', 'really', 'going'): 2,
#          ('really', 'going', 'to'): 2,
#          ('prices', '<e>', '<e>'): 2,
#          ('of', 'employment', '<e>'): 2,
#          ('employment', '<e>', '<e>'): 2,
#          ('this', 'area', 'we'): 2,
#          ('is', 'going', 'to'): 2,
#          ('and', 'especially', 'in'): 2,
#          ('especially', 'in', 'the'): 2,
#          ('in', 'developing', 'countries'): 2,
#          ('the', 'soulier', 'report'): 2,
#          ('the', 'amendments', 'which'): 2,
#          ('amendments', 'which', 'have'): 2,
#          ('have', 'been', 'tabled'): 2,
#          ('but', 'first', 'of'): 2,
#          ('of', 'the', 'treatment'): 2,
#          ('the', 'treatment', 'and'): 2,
#          ('treatment', 'and', 'disposal'): 2,
#          ('wish', 'to', 'refer'): 2,
#          ('to', 'refer', 'to'): 2,
#          ('subject', 'of', 'the'): 2,
#          ('services', 'and', 'engineering'): 2,
#          ('and', 'engineering', '<e>'): 2,
#          ('engineering', '<e>', '<e>'): 2,
#          ('there', 'are', 'many'): 2,
#          ('throughout', 'the', 'world'): 2,
#          ('it', 'is', 'the'): 2,
#          ('a', 'very', 'important'): 2,
#          ('the', 'export', 'of'): 2,
#          ('and', 'energy', 'and'): 2,
#          ('nuclear', 'energy', 'does'): 2,
#          ('is', 'the', 'only'): 2,
#          ('the', 'only', 'energy'): 2,
#          ('in', 'which', 'we'): 2,
#          ('the', 'current', 'and'): 2,
#          ('of', 'waste', 'and'): 2,
#          ('power', 'stations', 'which'): 2,
#          ('like', 'to', 'see'): 2,
#          ('not', 'a', 'question'): 2,
#          ('against', 'nuclear', 'energy'): 2,
#          ('nuclear', 'energy', 'nuclear'): 2,
#          ('<s>', '<s>', 'although'): 2,
#          ('some', 'people', 'are'): 2,
#          ('nuclear', 'power', 'we'): 2,
#          ('and', 'above', 'all'): 2,
#          ('above', 'all', 'the'): 2,
#          ('UNK', 'of', 'a'): 2,
#          ('industry', 'which', 'is'): 2,
#          ('in', 'the', 'east'): 2,
#          ('rapporteur', 'in', 'the'): 2,
#          ('in', 'the', 'light'): 2,
#          ('the', 'light', 'of'): 2,
#          ('years', 'ago', '<e>'): 2,
#          ('<s>', 'that', 'will'): 2,
#          ('and', 'i', 'know'): 2,
#          ('know', 'that', 'the'): 2,
#          ('these', '<e>', '<e>'): 2,
#          ('we', 'must', 'do'): 2,
#          ('must', 'do', 'all'): 2,
#          ('do', 'all', 'we'): 2,
#          ('all', 'we', 'can'): 2,
#          ('we', 'can', 'to'): 2,
#          ('order', 'to', 'ensure'): 2,
# ...
#          ('have', 'willingly', 'accepted'): 1,
#          ('willingly', 'accepted', 'the'): 1,
#          ('accepted', 'the', 'principle'): 1,
#          ('of', 'free', 'circulation'): 1,
#          ('circulation', 'of', 'course'): 1,
#          ('of', 'course', 'important'): 1,
#          ('course', 'important', 'work'): 1,
#          ('important', 'work', 'has'): 1,
#          ('work', 'has', 'to'): 1,
#          ('relation', 'to', 'countries'): 1,
#          ('to', 'countries', 'of'): 1,
#          ('eastern', 'europe', '<e>'): 1,
#          ('<s>', 'finally', 'and'): 1,
#          ('finally', 'and', 'since'): 1,
#          ('and', 'since', 'inevitably'): 1,
#          ('since', 'inevitably', 'the'): 1,
#          ('inevitably', 'the', 'subject'): 1,
#          ('the', 'subject', 'tackled'): 1,
#          ('subject', 'tackled', 'does'): 1,
#          ('tackled', 'does', 'concern'): 1,
#          ('does', 'concern', 'the'): 1,
#          ('concern', 'the', 'rights'): 1,
#          ('wrongs', 'of', 'nuclear'): 1,
#          ('nuclear', 'energy', 'i'): 1,
#          ('energy', 'i', 'wish'): 1,
#          ('wish', 'to', 'lend'): 1,
#          ('to', 'lend', 'my'): 1,
#          ('lend', 'my', 'support'): 1,
#          ('my', 'support', 'to'): 1,
#          ('to', 'the', 'common'): 1,
#          ('the', 'common', 'principles'): 1,
#          ('common', 'principles', 'in'): 1,
#          ('principles', 'in', 'favour'): 1,
#          ('favour', 'of', 'nuclear'): 1,
#          ('nuclear', 'power', 'national'): 1,
#          ('power', 'national', 'authorities'): 1,
#          ('authorities', 'should', 'decide'): 1,
#          ('should', 'decide', 'whether'): 1,
#          ('decide', 'whether', 'or'): 1,
#          ('whether', 'or', 'not'): 1,
#          ('or', 'not', 'to'): 1,
#          ('not', 'to', 'use'): 1,
#          ('nuclear', 'power', 'this'): 1,
#          ('power', 'this', 'choice'): 1,
#          ('this', 'choice', 'should'): 1,
#          ('choice', 'should', 'be'): 1,
#          ('should', 'be', 'respected'): 1,
#          ('be', 'respected', 'by'): 1,
#          ('respected', 'by', 'the'): 1,
#          ('by', 'the', 'union'): 1,
#          ('the', 'union', 'as'): 1,
#          ('a', 'whole', 'high'): 1,
#          ('whole', 'high', 'levels'): 1,
#          ('high', 'levels', 'of'): 1,
#          ('levels', 'of', 'security'): 1,
#          ('of', 'security', 'should'): 1,
#          ('security', 'should', 'be'): 1,
#          ('should', 'be', 'guaranteed'): 1,
#          ('be', 'guaranteed', 'member'): 1,
#          ('guaranteed', 'member', 'states'): 1,
#          ('member', 'states', 'take'): 1,
#          ('states', 'take', 'coresponsibility'): 1,
#          ('take', 'coresponsibility', 'with'): 1,
#          ('coresponsibility', 'with', 'those'): 1,
#          ('with', 'those', 'running'): 1,
#          ('those', 'running', 'nuclear'): 1,
#          ('running', 'nuclear', 'installations'): 1,
#          ('nuclear', 'installations', 'towards'): 1,
#          ('installations', 'towards', 'european'): 1,
#          ('towards', 'european', 'citizens'): 1,
#          ('european', 'citizens', 'when'): 1,
#          ('citizens', 'when', 'it'): 1,
#          ('comes', 'to', 'nuclear'): 1,
#          ('to', 'nuclear', 'safety'): 1,
#          ('nuclear', 'safety', '<e>'): 1,
#          ('<s>', '<s>', 'other'): 1,
#          ('<s>', 'other', 'reports'): 1,
#          ('other', 'reports', 'will'): 1,
#          ('reports', 'will', 'make'): 1,
#          ('possible', 'to', 'look'): 1,
#          ('look', 'at', 'the'): 1,
#          ('at', 'the', 'rights'): 1,
#          ('wrongs', 'of', 'various'): 1,
#          ('of', 'various', 'different'): 1,
#          ('various', 'different', 'types'): 1,
#          ('different', 'types', 'of'): 1,
#          ('sources', 'in', 'europe'): 1,
#          ('here', 'we', 'have'): 1,
#          ('have', 'to', 'accept'): 1,
#          ('to', 'accept', 'that'): 1,
#          ('accept', 'that', '30'): 1,
#          ('that', '30', 'of'): 1,
#          ('30', 'of', 'european'): 1,
#          ('european', 'energy', 'is'): 1,
#          ('energy', 'is', 'produced'): 1,
#          ('is', 'produced', 'by'): 1,
#          ('by', 'nuclear', 'means'): 1,
#          ('nuclear', 'means', 'we'): 1,
#          ('means', 'we', 'must'): 1,
#          ('we', 'must', 'therefore'): 1,
#          ('must', 'therefore', 'take'): 1,
#          ('therefore', 'take', 'any'): 1,
#          ('take', 'any', 'measure'): 1,
#          ('any', 'measure', 'necessary'): 1,
#          ('measure', 'necessary', 'to'): 1,
#          ('necessary', 'to', 'guarantee'): 1,
#          ('to', 'guarantee', 'the'): 1,
#          ('guarantee', 'the', 'future'): 1,
#          ('future', 'of', 'european'): 1,
#          ('of', 'european', 'citizens'): 1,
#          ('european', 'citizens', 'and'): 1,
#          ('citizens', 'and', 'their'): 1,
#          ('and', 'their', 'safety'): 1,
#          ('<s>', 'i', 'wanted'): 1,
#          ('i', 'wanted', 'to'): 1,
#          ('wanted', 'to', 'explain'): 1,
#          ('to', 'explain', 'to'): 1,
#          ('explain', 'to', 'you'): 1,
#          ('to', 'you', 'why'): 1,
#          ('you', 'why', 'as'): 1,
#          ('why', 'as', 'a'): 1,
#          ('as', 'a', 'UNK'): 1,
#          ('a', 'UNK', 'i'): 1,
#          ('UNK', 'i', 'shall'): 1,
#          ('shall', 'be', 'voting'): 1,
#          ('be', 'voting', 'against'): 1,
#          ('voting', 'against', 'the'): 1,
#          ('against', 'the', 'soulier'): 1,
#          ('soulier', 'report', '<e>'): 1,
#          ('<s>', 'i', 'come'): 1,
#          ('country', 'which', 'in'): 1,
#          ('which', 'in', 'the'): 1,
#          ('in', 'the', '1970s'): 1,
#          ('the', '1970s', 'made'): 1,
#          ('1970s', 'made', 'a'): 1,
#          ('made', 'a', 'choice'): 1,
#          ('a', 'choice', 'the'): 1,
#          ('choice', 'the', 'choice'): 1,
#          ('the', 'choice', 'not'): 1,
#          ('choice', 'not', 'to'): 1,
#          ('build', 'a', 'single'): 1,
#          ('a', 'single', 'nuclear'): 1,
#          ('single', 'nuclear', 'power'): 1,
#          ('power', 'station', 'on'): 1,
#          ('station', 'on', 'the'): 1,
#          ('on', 'the', 'river'): 1,
#          ('the', 'river', 'moselle'): 1,
#          ('river', 'moselle', '<e>'): 1,
#          ('moselle', '<e>', '<e>'): 1,
#          ('<s>', 'this', 'choice'): 1,
#          ('this', 'choice', 'was'): 1,
#          ('choice', 'was', 'broadly'): 1,
#          ('was', 'broadly', 'the'): 1,
#          ('broadly', 'the', 'decision'): 1,
#          ('of', 'the', 'luxembourg'): 1,
#          ('the', 'luxembourg', 'socialists'): 1,
#          ('luxembourg', 'socialists', 'who'): 1,
#          ('socialists', 'who', 'were'): 1,
#          ('who', 'were', 'in'): 1,
#          ('were', 'in', 'power'): 1,
#          ('in', 'power', 'at'): 1,
#          ('power', 'at', 'the'): 1,
#          ('at', 'the', 'time'): 1,
#          ('the', 'time', '<e>'): 1,
#          ('a', 'few', 'years'): 1,
#          ('few', 'years', 'afterwards'): 1,
#          ('years', 'afterwards', 'our'): 1,
#          ('afterwards', 'our', 'great'): 1,
#          ('our', 'great', 'neighbour'): 1,
#          ('great', 'neighbour', 'france'): 1,
#          ('neighbour', 'france', 'whose'): 1,
#          ('france', 'whose', 'nuclear'): 1,
#          ('whose', 'nuclear', 'options'): 1,
#          ('nuclear', 'options', 'are'): 1,
#          ('options', 'are', 'well'): 1,
#          ('are', 'well', 'known'): 1,
#          ('well', 'known', 'to'): 1,
#          ('known', 'to', 'everyone'): 1,
#          ('to', 'everyone', 'decided'): 1,
#          ('everyone', 'decided', 'to'): 1,
#          ('decided', 'to', 'build'): 1,
#          ('build', 'a', 'huge'): 1,
#          ('a', 'huge', 'nuclear'): 1,
#          ('huge', 'nuclear', 'power'): 1,
#          ('power', 'station', 'at'): 1,
#          ('station', 'at', 'UNK'): 1,
#          ('at', 'UNK', 'on'): 1,
#          ('UNK', 'on', 'the'): 1,
#          ('on', 'the', 'border'): 1,
#          ('the', 'border', 'with'): 1,
#          ('border', 'with', 'luxembourg'): 1,
#          ('with', 'luxembourg', 'and'): 1,
#          ('luxembourg', 'and', 'germany'): 1,
#          ('and', 'germany', 'without'): 1,
#          ('germany', 'without', 'asking'): 1,
#          ('without', 'asking', 'anyone'): 1,
#          ('asking', 'anyone', 'for'): 1,
#          ('anyone', 'for', 'their'): 1,
#          ('for', 'their', 'opinion'): 1,
#          ('their', 'opinion', '<e>'): 1,
#          ('<s>', 'it', 'took'): 1,
#          ('it', 'took', 'years'): 1,
#          ('took', 'years', 'and'): 1,
#          ('years', 'and', 'years'): 1,
#          ('and', 'years', 'toplevel'): 1,
#          ('years', 'toplevel', 'state'): 1,
#          ('toplevel', 'state', 'visits'): 1,
#          ('state', 'visits', 'and'): 1,
#          ('visits', 'and', 'countless'): 1,
#          ('and', 'countless', 'diplomatic'): 1,
#          ('countless', 'diplomatic', 'interventions'): 1,
#          ('diplomatic', 'interventions', 'for'): 1,
#          ('interventions', 'for', 'the'): 1,
#          ('for', 'the', 'french'): 1,
#          ('the', 'french', 'nuclear'): 1,
#          ('french', 'nuclear', 'industry'): 1,
#          ('industry', 'to', 'agree'): 1,
#          ('to', 'agree', 'to'): 1,
#          ('agree', 'to', 'supply'): 1,
#          ('to', 'supply', 'information'): 1,
#          ('supply', 'information', 'albeit'): 1,
#          ('information', 'albeit', 'hardly'): 1,
#          ('albeit', 'hardly', 'credible'): 1,
#          ('hardly', 'credible', 'on'): 1,
#          ('credible', 'on', 'the'): 1,
#          ('on', 'the', 'emissions'): 1,
#          ('the', 'emissions', 'of'): 1,
#          ('emissions', 'of', 'the'): 1,
#          ('of', 'the', 'power'): 1,
#          ('the', 'power', 'station'): 1,
#          ('power', 'station', 'and'): 1,
#          ('station', 'and', 'to'): 1,
#          ('and', 'to', 'install'): 1,
#          ('to', 'install', 'an'): 1,
#          ('install', 'an', 'alarm'): 1,
#          ('an', 'alarm', 'system'): 1,
#          ('alarm', 'system', '<e>'): 1,
#          ('at', 'present', 'another'): 1,
#          ('present', 'another', 'nuclear'): 1,
#          ('another', 'nuclear', 'state'): 1,
#          ('nuclear', 'state', 'belgium'): 1,
#          ('state', 'belgium', 'is'): 1,
#          ('belgium', 'is', 'mentioning'): 1,
#          ('is', 'mentioning', 'the'): 1,
#          ('mentioning', 'the', 'possibility'): 1,
#          ('possibility', 'of', 'storing'): 1,
#          ('of', 'storing', 'its'): 1,
#          ('storing', 'its', 'nuclear'): 1,
#          ('nuclear', 'waste', 'in'): 1,
#          ('waste', 'in', 'the'): 1,
#          ('in', 'the', 'belgian'): 1,
#          ('the', 'belgian', 'UNK'): 1,
#          ('belgian', 'UNK', 'only'): 1,
#          ('UNK', 'only', 'six'): 1,
#          ('only', 'six', 'kilometres'): 1,
#          ('six', 'kilometres', 'away'): 1,
#          ('kilometres', 'away', 'from'): 1,
#          ('from', 'the', 'luxembourg'): 1,
#          ('luxembourg', 'border', 'in'): 1,
#          ('border', 'in', 'a'): 1,
#          ('in', 'a', 'nature'): 1,
#          ('a', 'nature', 'reserve'): 1,
#          ('nature', 'reserve', 'and'): 1,
#          ('reserve', 'and', 'tourism'): 1,
#          ('and', 'tourism', 'area'): 1,
#          ('tourism', 'area', '<e>'): 1,
#          ('<s>', '<s>', 'during'): 1,
#          ('<s>', 'during', 'that'): 1,
#          ('during', 'that', 'time'): 1,
#          ('that', 'time', 'the'): 1,
#          ('time', 'the', 'railway'): 1,
#          ('the', 'railway', 'accident'): 1,
#          ('railway', 'accident', 'at'): 1,
#          ('accident', 'at', 'UNK'): 1,
#          ('at', 'UNK', 'in'): 1,
#          ('UNK', 'in', 'lorraine'): 1,
#          ('in', 'lorraine', 'very'): 1,
#          ('lorraine', 'very', 'close'): 1,
#          ('very', 'close', 'to'): 1,
#          ('close', 'to', 'the'): 1,
#          ('to', 'the', 'luxembourg'): 1,
#          ('luxembourg', 'border', 'revealed'): 1,
#          ('border', 'revealed', 'that'): 1,
#          ('revealed', 'that', 'convoys'): 1,
#          ('that', 'convoys', 'of'): 1,
#          ('convoys', 'of', 'trains'): 1,
#          ('of', 'trains', 'UNK'): 1,
#          ('trains', 'UNK', 'europe'): 1,
#          ('UNK', 'europe', 'in'): 1,
#          ('europe', 'in', 'every'): 1,
#          ('in', 'every', 'direction'): 1,
#          ('every', 'direction', 'transporting'): 1,
#          ('direction', 'transporting', 'nuclear'): 1,
#          ('transporting', 'nuclear', 'waste'): 1,
#          ('nuclear', 'waste', 'towards'): 1,
#          ('waste', 'towards', 'reprocessing'): 1,
#          ('towards', 'reprocessing', 'plants'): 1,
#          ('reprocessing', 'plants', 'without'): 1,
#          ('plants', 'without', 'anyones'): 1,
#          ('without', 'anyones', 'knowledge'): 1,
#          ('anyones', 'knowledge', 'without'): 1,
#          ('knowledge', 'without', 'our'): 1,
#          ('without', 'our', 'knowing'): 1,
#          ('our', 'knowing', 'what'): 1,
#          ('knowing', 'what', 'safety'): 1,
#          ('what', 'safety', 'measures'): 1,
#          ('safety', 'measures', 'have'): 1,
#          ('measures', 'have', 'been'): 1,
#          ('have', 'been', 'taken'): 1,
#          ('been', 'taken', 'and'): 1,
#          ('taken', 'and', 'what'): 1,
#          ('and', 'what', 'conditions'): 1,
#          ('what', 'conditions', 'this'): 1,
#          ('conditions', 'this', 'transportation'): 1,
#          ('this', 'transportation', 'takes'): 1,
#          ('transportation', 'takes', 'place'): 1,
#          ('takes', 'place', 'in'): 1,
#          ('place', 'in', '<e>'): 1,
#          ('<s>', '<s>', 'whole'): 1,
#          ('<s>', 'whole', 'communities'): 1,
#          ('whole', 'communities', 'could'): 1,
#          ('communities', 'could', 'be'): 1,
#          ('could', 'be', 'contaminated'): 1,
#          ('be', 'contaminated', 'overnight'): 1,
#          ('contaminated', 'overnight', '<e>'): 1,
#          ('overnight', '<e>', '<e>'): 1,
#          ('am', 'therefore', 'against'): 1,
#          ('therefore', 'against', 'nuclear'): 1,
#          ('nuclear', 'power', 'practised'): 1,
#          ('power', 'practised', 'in'): 1,
#          ('practised', 'in', 'this'): 1,
#          ('this', 'way', 'without'): 1,
#          ('way', 'without', 'any'): 1,
#          ('without', 'any', 'nuance'): 1,
#          ('any', 'nuance', '<e>'): 1,
#          ('nuance', '<e>', '<e>'): 1,
#          ('but', 'i', 'also'): 1,
#          ('i', 'also', 'go'): 1,
#          ('also', 'go', 'along'): 1,
#          ('go', 'along', 'with'): 1,
#          ('along', 'with', 'the'): 1,
#          ('with', 'the', 'attitude'): 1,
#          ('the', 'attitude', 'of'): 1,
#          ('attitude', 'of', 'my'): 1,
#          ('my', 'group', 'on'): 1,
#          ('group', 'on', 'the'): 1,
#          ('need', 'for', 'everything'): 1,
#          ('for', 'everything', 'to'): 1,
#          ('everything', 'to', 'be'): 1,
#          ('done', 'in', 'face'): 1,
#          ('in', 'face', 'of'): 1,
#          ('face', 'of', 'the'): 1,
#          ('of', 'the', 'dangers'): 1,
#          ('the', 'dangers', 'of'): 1,
#          ('dangers', 'of', 'nuclear'): 1,
#          ('nuclear', 'power', 'to'): 1,
#          ('power', 'to', 'introduce'): 1,
#          ('to', 'introduce', 'maximum'): 1,
#          ('introduce', 'maximum', 'safety'): 1,
#          ('maximum', 'safety', 'and'): 1,
#          ('safety', 'and', 'therefore'): 1,
#          ('and', 'therefore', 'profoundly'): 1,
#          ('therefore', 'profoundly', 'amend'): 1,
#          ('profoundly', 'amend', 'the'): 1,
#          ('amend', 'the', 'euratom'): 1,
#          ('euratom', 'treaty', 'the'): 1,
#          ('treaty', 'the', 'relic'): 1,
#          ('the', 'relic', 'of'): 1,
#          ('relic', 'of', 'a'): 1,
#          ('of', 'a', 'time'): 1,
#          ('a', 'time', 'when'): 1,
#          ('time', 'when', 'everyone'): 1,
#          ('when', 'everyone', 'was'): 1,
#          ('everyone', 'was', 'full'): 1,
#          ('was', 'full', 'of'): 1,
#          ('full', 'of', 'admiration'): 1,
#          ('of', 'admiration', 'for'): 1,
#          ('admiration', 'for', 'nuclear'): 1,
#          ('power', 'in', 'order'): 1,
#          ('order', 'to', 'guarantee'): 1,
#          ('to', 'guarantee', 'safety'): 1,
#          ('guarantee', 'safety', 'and'): 1,
#          ('safety', 'and', 'control'): 1,
#          ('and', 'control', 'every'): 1,
#          ('control', 'every', 'aspect'): 1,
#          ('every', 'aspect', 'of'): 1,
#          ('power', 'industry', '<e>'): 1})
